# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
from scipy import stats
from scipy.stats import linregress

from citipy import citipy
from datetime import date
import scipy.stats as st


# Import API key
from api_keys import weather_api_key
from citipy import citipy

# %%
#create a list of lattitute and longitiutde and cities
lat_range = (-90,90)
lon_range = (-180,180)

cities = []
lat_lon = []
unique_cities = []

#import cities datafile 
cities_pd = pd.read_csv("../output_data/cities.csv")
cities_pd.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ## Generate Cities List

# %%
#lat and long combination 
lat = np.random.uniform(lat_range[0], lat_range[1],size = 2000)
lon = np.random.uniform(lon_range[0], lon_range[1],size = 2000)

#map the lat and lon
lat_lon = zip(lat,lon)

#find the nearest city for a given coordinate

for coordinates in lat_lon:
    location_data = citipy.nearest_city(coordinates[0], coordinates[1])
    city = location_data.city_name
    country_name = location_data.country_code
    
    #if the location is unique add the new city into the cities list 
    if city not in unique_cities:
        unique_cities.append(city)
        cities.append(city)

print(len(cities))
# Out:
# 745

# %%
#creating a dataframe for cities
weather_by_city_df = pd.DataFrame({"City":cities})

#adding columns to store weather variables
weather_by_city_df["Country"] = ""
weather_by_city_df["Date"] = ""      
weather_by_city_df["Latitude"] = ""
weather_by_city_df["Longitude"] = ""
weather_by_city_df["Cloudiness (%)"] = ""
weather_by_city_df["Humidity"] = ""
weather_by_city_df["Max Temp (F)"] = ""
weather_by_city_df["Wind Speed (mph)"] = ""

weather_by_city_df.head()
# Out:
#             City Country Date Latitude Longitude Cloudiness (%) Humidity  \
# 0  san cristobal
# 1        ushuaia
# 2   punta arenas
# 3     nikolskoye
# 4      taolanaro
#
#   Max Temp (F) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#URL
units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"
API_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
#create lists to store the variable data 
lat = []
lng = []
temp = []
hum = []
cld = []
wind = []
dt =[]
city_list = []
country = []

# %%
number = 0
group = 1
for index, row in weather_by_city_df.iterrows():
    
    city = row["City"]
    
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
    try:
        print(f"Processing the file {number} of Group {group} | {city}.")
        
        
        weather_by_city_df.loc[index, "Country"] = response["sys"]["country"]    
        weather_by_city_df.loc[index, "Date"] = response["dt"]
        weather_by_city_df.loc[index, "Latitude"] = response["coord"]["lat"]
        weather_by_city_df.loc[index, "Longitude"] = response["coord"]["lon"]
        weather_by_city_df.loc[index, "Cloudiness (%)"] = response["clouds"]["all"]
        weather_by_city_df.loc[index, "Humidity"] = response["main"]["humidity"]
        weather_by_city_df.loc[index, "Max Temp (F)"] = 1.8 * (response["main"]["temp_max"] - 273) + 32
        weather_by_city_df.loc[index, "Wind Speed (mph)"] = response["wind"]["speed"]
        
    except:
        
        (f"Weather for the city is unavaliable, checking next city: {city}.")
            
            
    number = number + 1
    if number == 50:
        number= 0
        group = group + 1   
        
print ("-------------------------------")
print ("API Retrieval is complete")
print(API_url)
print(f"city name: {city_list}")
print (f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# Processing the file 0 of Group 1 | san cristobal.
# Processing the file 1 of Group 1 | ushuaia.
# Processing the file 2 of Group 1 | punta arenas.
# Processing the file 3 of Group 1 | nikolskoye.
# Processing the file 4 of Group 1 | taolanaro.
# Processing the file 5 of Group 1 | upernavik.
# Processing the file 6 of Group 1 | sucua.
# Processing the file 7 of Group 1 | mackay.
# Processing the file 8 of Group 1 | saurimo.
# Processing the file 9 of Group 1 | hilo.
# Processing the file 10 of Group 1 | gilbues.
# Processing the file 11 of Group 1 | sentyabrskiy.
# Processing the file 12 of Group 1 | kapaa.
# Processing the file 13 of Group 1 | mogadishu.
# Processing the file 14 of Group 1 | tapaua.
# Processing the file 15 of Group 1 | havre-saint-pierre.
# Processing the file 16 of Group 1 | new norfolk.
# Processing the file 17 of Group 1 | castro.
# Processing the file 18 of Group 1 | guerrero negro.
# Processing the file 19 of Group 1 | huarmey.
# Processing the file 20 of Group 1 | teruel.
# Processing the file 21 of Group 1 | georgetown.
# Processing the file 22 of Group 1 | impfondo.
# Processing the file 23 of Group 1 | tuktoyaktuk.
# Processing the file 24 of Group 1 | menongue.
# Processing the file 25 of Group 1 | sioux lookout.
# Processing the file 26 of Group 1 | narsaq.
# Processing the file 27 of Group 1 | busselton.
# Processing the file 28 of Group 1 | honningsvag.
# Processing the file 29 of Group 1 | butaritari.
# Processing the file 30 of Group 1 | umzimvubu.
# Processing the file 31 of Group 1 | ahipara.
# Processing the file 32 of Group 1 | maralal.
# Processing the file 33 of Group 1 | avarua.
# Processing the file 34 of Group 1 | yambio.
# Processing the file 35 of Group 1 | illoqqortoormiut.
# Processing the file 36 of Group 1 | soroti.
# Processing the file 37 of Group 1 | tasiilaq.
# Processing the file 38 of Group 1 | salalah.
# Processing the file 39 of Group 1 | tiksi.
# Processing the file 40 of Group 1 | ust-maya.
# Processing the file 41 of Group 1 | batagay-alyta.
# Processing the file 42 of Group 1 | puerto ayora.
# Processing the file 43 of Group 1 | rikitea.
# Processing the file 44 of Group 1 | sur.
# Processing the file 45 of Group 1 | mahebourg.
# Processing the file 46 of Group 1 | vila velha.
# Processing the file 47 of Group 1 | lebu.
# Processing the file 48 of Group 1 | requena.
# Processing the file 49 of Group 1 | jamestown.
# Processing the file 0 of Group 2 | madingou.
# Processing the file 1 of Group 2 | paamiut.
# Processing the file 2 of Group 2 | mataura.
# Processing the file 3 of Group 2 | bredasdorp.
# Processing the file 4 of Group 2 | fukue.
# Processing the file 5 of Group 2 | katsuura.
# Processing the file 6 of Group 2 | lorengau.
# Processing the file 7 of Group 2 | east london.
# Processing the file 8 of Group 2 | vaini.
# Processing the file 9 of Group 2 | samusu.
# Processing the file 10 of Group 2 | kavieng.
# Processing the file 11 of Group 2 | fort portal.
# Processing the file 12 of Group 2 | hermanus.
# Processing the file 13 of Group 2 | pisco.
# Processing the file 14 of Group 2 | havoysund.
# Processing the file 15 of Group 2 | gdov.
# Processing the file 16 of Group 2 | majene.
# Processing the file 17 of Group 2 | hobart.
# Processing the file 18 of Group 2 | bokovskaya.
# Processing the file 19 of Group 2 | cape town.
# Processing the file 20 of Group 2 | belushya guba.
# Processing the file 21 of Group 2 | barentsburg.
# Processing the file 22 of Group 2 | esperance.
# Processing the file 23 of Group 2 | alofi.
# Processing the file 24 of Group 2 | albany.
# Processing the file 25 of Group 2 | sedhiou.
# Processing the file 26 of Group 2 | constitucion.
# Processing the file 27 of Group 2 | port alfred.
# Processing the file 28 of Group 2 | eyl.
# Processing the file 29 of Group 2 | punto fijo.
# Processing the file 30 of Group 2 | narauli.
# Processing the file 31 of Group 2 | kilindoni.
# Processing the file 32 of Group 2 | airai.
# Processing the file 33 of Group 2 | bolshegrivskoye.
# Processing the file 34 of Group 2 | luderitz.
# Processing the file 35 of Group 2 | durusu.
# Processing the file 36 of Group 2 | totness.
# Processing the file 37 of Group 2 | acapulco.
# Processing the file 38 of Group 2 | hesla.
# Processing the file 39 of Group 2 | severo-kurilsk.
# Processing the file 40 of Group 2 | komsomolskiy.
# Processing the file 41 of Group 2 | nanortalik.
# Processing the file 42 of Group 2 | blagoveshchenka.
# Processing the file 43 of Group 2 | ponta do sol.
# Processing the file 44 of Group 2 | nadvoitsy.
# Processing the file 45 of Group 2 | saldanha.
# Processing the file 46 of Group 2 | bishop auckland.
# Processing the file 47 of Group 2 | wenchi.
# Processing the file 48 of Group 2 | carnarvon.
# Processing the file 49 of Group 2 | baykit.
# Processing the file 0 of Group 3 | bizhbulyak.
# Processing the file 1 of Group 3 | masumbwe.
# Processing the file 2 of Group 3 | kamalganj.
# Processing the file 3 of Group 3 | deputatskiy.
# Processing the file 4 of Group 3 | shingu.
# Processing the file 5 of Group 3 | dakar.
# Processing the file 6 of Group 3 | bluff.
# Processing the file 7 of Group 3 | breytovo.
# Processing the file 8 of Group 3 | cabo san lucas.
# Processing the file 9 of Group 3 | sault sainte marie.
# Processing the file 10 of Group 3 | ribeira grande.
# Processing the file 11 of Group 3 | trabzon.
# Processing the file 12 of Group 3 | grand river south east.
# Processing the file 13 of Group 3 | havelock.
# Processing the file 14 of Group 3 | atuona.
# Processing the file 15 of Group 3 | saint-augustin.
# Processing the file 16 of Group 3 | faya.
# Processing the file 17 of Group 3 | esso.
# Processing the file 18 of Group 3 | ilulissat.
# Processing the file 19 of Group 3 | yellowknife.
# Processing the file 20 of Group 3 | chuy.
# Processing the file 21 of Group 3 | severodvinsk.
# Processing the file 22 of Group 3 | port hedland.
# Processing the file 23 of Group 3 | codrington.
# Processing the file 24 of Group 3 | fort saint john.
# Processing the file 25 of Group 3 | bethel.
# Processing the file 26 of Group 3 | kenai.
# Processing the file 27 of Group 3 | mys shmidta.
# Processing the file 28 of Group 3 | dunedin.
# Processing the file 29 of Group 3 | kaitangata.
# Processing the file 30 of Group 3 | chokurdakh.
# Processing the file 31 of Group 3 | benguela.
# Processing the file 32 of Group 3 | port elizabeth.
# Processing the file 33 of Group 3 | pacific grove.
# Processing the file 34 of Group 3 | mazyr.
# Processing the file 35 of Group 3 | geraldton.
# Processing the file 36 of Group 3 | barrow.
# Processing the file 37 of Group 3 | quebo.
# Processing the file 38 of Group 3 | amga.
# Processing the file 39 of Group 3 | grafton.
# Processing the file 40 of Group 3 | dikson.
# Processing the file 41 of Group 3 | carbondale.
# Processing the file 42 of Group 3 | iskateley.
# Processing the file 43 of Group 3 | bonavista.
# Processing the file 44 of Group 3 | saint-philippe.
# Processing the file 45 of Group 3 | srednekolymsk.
# Processing the file 46 of Group 3 | cherskiy.
# Processing the file 47 of Group 3 | nioro.
# Processing the file 48 of Group 3 | gimli.
# Processing the file 49 of Group 3 | bathsheba.
# Processing the file 0 of Group 4 | borba.
# Processing the file 1 of Group 4 | souillac.
# Processing the file 2 of Group 4 | rio gallegos.
# Processing the file 3 of Group 4 | okha.
# Processing the file 4 of Group 4 | mar del plata.
# Processing the file 5 of Group 4 | daru.
# Processing the file 6 of Group 4 | makakilo city.
# Processing the file 7 of Group 4 | sao filipe.
# Processing the file 8 of Group 4 | kibuye.
# Processing the file 9 of Group 4 | kruisfontein.
# Processing the file 10 of Group 4 | bengkulu.
# Processing the file 11 of Group 4 | isangel.
# Processing the file 12 of Group 4 | fortuna.
# Processing the file 13 of Group 4 | iqaluit.
# Processing the file 14 of Group 4 | raga.
# Processing the file 15 of Group 4 | hit.
# Processing the file 16 of Group 4 | faanui.
# Processing the file 17 of Group 4 | mega.
# Processing the file 18 of Group 4 | itarema.
# Processing the file 19 of Group 4 | verkhnyaya inta.
# Processing the file 20 of Group 4 | zapresic.
# Processing the file 21 of Group 4 | saskylakh.
# Processing the file 22 of Group 4 | dzilam gonzalez.
# Processing the file 23 of Group 4 | pondicherry.
# Processing the file 24 of Group 4 | shimanovsk.
# Processing the file 25 of Group 4 | hithadhoo.
# Processing the file 26 of Group 4 | sorvag.
# Processing the file 27 of Group 4 | arraial do cabo.
# Processing the file 28 of Group 4 | xudat.
# Processing the file 29 of Group 4 | maniwaki.
# Processing the file 30 of Group 4 | thompson.
# Processing the file 31 of Group 4 | qiongshan.
# Processing the file 32 of Group 4 | aden.
# Processing the file 33 of Group 4 | asau.
# Processing the file 34 of Group 4 | orlik.
# Processing the file 35 of Group 4 | tigil.
# Processing the file 36 of Group 4 | merrill.
# Processing the file 37 of Group 4 | toliary.
# Processing the file 38 of Group 4 | taksimo.
# Processing the file 39 of Group 4 | chagda.
# Processing the file 40 of Group 4 | masjed-e soleyman.
# Processing the file 41 of Group 4 | beni mazar.
# Processing the file 42 of Group 4 | caravelas.
# Processing the file 43 of Group 4 | lezhe.
# Processing the file 44 of Group 4 | riyadh.
# Processing the file 45 of Group 4 | victoria.
# Processing the file 46 of Group 4 | turukhansk.
# Processing the file 47 of Group 4 | porto novo.
# Processing the file 48 of Group 4 | ambulu.
# Processing the file 49 of Group 4 | longyearbyen.
# Processing the file 0 of Group 5 | yar-sale.
# Processing the file 1 of Group 5 | kholm.
# Processing the file 2 of Group 5 | jabiru.
# Processing the file 3 of Group 5 | athabasca.
# Processing the file 4 of Group 5 | katherine.
# Processing the file 5 of Group 5 | dharchula.
# Processing the file 6 of Group 5 | beloha.
# Processing the file 7 of Group 5 | akyab.
# Processing the file 8 of Group 5 | tuatapere.
# Processing the file 9 of Group 5 | energetik.
# Processing the file 10 of Group 5 | coahuayana.
# Processing the file 11 of Group 5 | paredon.
# Processing the file 12 of Group 5 | pangnirtung.
# Processing the file 13 of Group 5 | kalengwa.
# Processing the file 14 of Group 5 | izhma.
# Processing the file 15 of Group 5 | khatanga.
# Processing the file 16 of Group 5 | ust-kuyga.
# Processing the file 17 of Group 5 | pevek.
# Processing the file 18 of Group 5 | yichang.
# Processing the file 19 of Group 5 | hamilton.
# Processing the file 20 of Group 5 | nemuro.
# Processing the file 21 of Group 5 | riom.
# Processing the file 22 of Group 5 | mayor pablo lagerenza.
# Processing the file 23 of Group 5 | hobyo.
# Processing the file 24 of Group 5 | male.
# Processing the file 25 of Group 5 | nipawin.
# Processing the file 26 of Group 5 | northam.
# Processing the file 27 of Group 5 | attawapiskat.
# Processing the file 28 of Group 5 | filadelfia.
# Processing the file 29 of Group 5 | lumphat.
# Processing the file 30 of Group 5 | gamba.
# Processing the file 31 of Group 5 | marzuq.
# Processing the file 32 of Group 5 | priiskovyy.
# Processing the file 33 of Group 5 | hambantota.
# Processing the file 34 of Group 5 | norman wells.
# Processing the file 35 of Group 5 | kamenskoye.
# Processing the file 36 of Group 5 | marsa matruh.
# Processing the file 37 of Group 5 | taoudenni.
# Processing the file 38 of Group 5 | yulara.
# Processing the file 39 of Group 5 | sao joao da barra.
# Processing the file 40 of Group 5 | praia da vitoria.
# Processing the file 41 of Group 5 | nantucket.
# Processing the file 42 of Group 5 | avera.
# Processing the file 43 of Group 5 | irtyshskiy.
# Processing the file 44 of Group 5 | dingle.
# Processing the file 45 of Group 5 | lompoc.
# Processing the file 46 of Group 5 | wierden.
# Processing the file 47 of Group 5 | buala.
# Processing the file 48 of Group 5 | gilazi.
# Processing the file 49 of Group 5 | cairns.
# Processing the file 0 of Group 6 | inhambane.
# Processing the file 1 of Group 6 | antalaha.
# Processing the file 2 of Group 6 | isla mujeres.
# Processing the file 3 of Group 6 | moron.
# Processing the file 4 of Group 6 | sinegorye.
# Processing the file 5 of Group 6 | korla.
# Processing the file 6 of Group 6 | bontang.
# Processing the file 7 of Group 6 | saint-pierre.
# Processing the file 8 of Group 6 | changde.
# Processing the file 9 of Group 6 | jumla.
# Processing the file 10 of Group 6 | hirara.
# Processing the file 11 of Group 6 | penzance.
# Processing the file 12 of Group 6 | sitka.
# Processing the file 13 of Group 6 | san bartolome.
# Processing the file 14 of Group 6 | alexandria.
# Processing the file 15 of Group 6 | kenora.
# Processing the file 16 of Group 6 | haines junction.
# Processing the file 17 of Group 6 | ust-kulom.
# Processing the file 18 of Group 6 | enugu.
# Processing the file 19 of Group 6 | la estrella.
# Processing the file 20 of Group 6 | safranbolu.
# Processing the file 21 of Group 6 | waw.
# Processing the file 22 of Group 6 | xai-xai.
# Processing the file 23 of Group 6 | sistranda.
# Processing the file 24 of Group 6 | rungata.
# Processing the file 25 of Group 6 | talnakh.
# Processing the file 26 of Group 6 | washington.
# Processing the file 27 of Group 6 | berlevag.
# Processing the file 28 of Group 6 | bambous virieux.
# Processing the file 29 of Group 6 | nsanje.
# Processing the file 30 of Group 6 | vanimo.
# Processing the file 31 of Group 6 | andijon.
# Processing the file 32 of Group 6 | broken hill.
# Processing the file 33 of Group 6 | same.
# Processing the file 34 of Group 6 | inderborskiy.
# Processing the file 35 of Group 6 | torbay.
# Processing the file 36 of Group 6 | chanika.
# Processing the file 37 of Group 6 | inverness.
# Processing the file 38 of Group 6 | roald.
# Processing the file 39 of Group 6 | kodiak.
# Processing the file 40 of Group 6 | amderma.
# Processing the file 41 of Group 6 | orange.
# Processing the file 42 of Group 6 | nadym.
# Processing the file 43 of Group 6 | beringovskiy.
# Processing the file 44 of Group 6 | ammon.
# Processing the file 45 of Group 6 | saryshagan.
# Processing the file 46 of Group 6 | marcona.
# Processing the file 47 of Group 6 | rawson.
# Processing the file 48 of Group 6 | san patricio.
# Processing the file 49 of Group 6 | aquiraz.
# Processing the file 0 of Group 7 | carutapera.
# Processing the file 1 of Group 7 | klaksvik.
# Processing the file 2 of Group 7 | gushikawa.
# Processing the file 3 of Group 7 | port blair.
# Processing the file 4 of Group 7 | ellsworth.
# Processing the file 5 of Group 7 | poole.
# Processing the file 6 of Group 7 | ostersund.
# Processing the file 7 of Group 7 | santiago.
# Processing the file 8 of Group 7 | oranjestad.
# Processing the file 9 of Group 7 | rabak.
# Processing the file 10 of Group 7 | nizhneyansk.
# Processing the file 11 of Group 7 | alamosa.
# Processing the file 12 of Group 7 | kegayli.
# Processing the file 13 of Group 7 | grindavik.
# Processing the file 14 of Group 7 | naze.
# Processing the file 15 of Group 7 | port hardy.
# Processing the file 16 of Group 7 | kloulklubed.
# Processing the file 17 of Group 7 | digha.
# Processing the file 18 of Group 7 | fort nelson.
# Processing the file 19 of Group 7 | hastings.
# Processing the file 20 of Group 7 | viedma.
# Processing the file 21 of Group 7 | la cruz.
# Processing the file 22 of Group 7 | sao gabriel da cachoeira.
# Processing the file 23 of Group 7 | boyolangu.
# Processing the file 24 of Group 7 | saint-leu.
# Processing the file 25 of Group 7 | leningradskiy.
# Processing the file 26 of Group 7 | aguas formosas.
# Processing the file 27 of Group 7 | maldonado.
# Processing the file 28 of Group 7 | babanusah.
# Processing the file 29 of Group 7 | ziniare.
# Processing the file 30 of Group 7 | qaanaaq.
# Processing the file 31 of Group 7 | karaul.
# Processing the file 32 of Group 7 | huilong.
# Processing the file 33 of Group 7 | boa vista.
# Processing the file 34 of Group 7 | ternate.
# Processing the file 35 of Group 7 | kerema.
# Processing the file 36 of Group 7 | juigalpa.
# Processing the file 37 of Group 7 | galle.
# Processing the file 38 of Group 7 | manggar.
# Processing the file 39 of Group 7 | college.
# Processing the file 40 of Group 7 | vestmannaeyjar.
# Processing the file 41 of Group 7 | katobu.
# Processing the file 42 of Group 7 | winnemucca.
# Processing the file 43 of Group 7 | pio ix.
# Processing the file 44 of Group 7 | mount gambier.
# Processing the file 45 of Group 7 | kihurio.
# Processing the file 46 of Group 7 | calama.
# Processing the file 47 of Group 7 | cayenne.
# Processing the file 48 of Group 7 | limbang.
# Processing the file 49 of Group 7 | richards bay.
# Processing the file 0 of Group 8 | methoni.
# Processing the file 1 of Group 8 | sompeta.
# Processing the file 2 of Group 8 | petropavlovsk-kamchatskiy.
# Processing the file 3 of Group 8 | roma.
# Processing the file 4 of Group 8 | pierre.
# Processing the file 5 of Group 8 | palabuhanratu.
# Processing the file 6 of Group 8 | muhos.
# Processing the file 7 of Group 8 | tarija.
# Processing the file 8 of Group 8 | sao miguel dos campos.
# Processing the file 9 of Group 8 | erenhot.
# Processing the file 10 of Group 8 | wanning.
# Processing the file 11 of Group 8 | lolua.
# Processing the file 12 of Group 8 | opatovice nad labem.
# Processing the file 13 of Group 8 | antofagasta.
# Processing the file 14 of Group 8 | luorong.
# Processing the file 15 of Group 8 | wenling.
# Processing the file 16 of Group 8 | midland.
# Processing the file 17 of Group 8 | lubango.
# Processing the file 18 of Group 8 | rio grande.
# Processing the file 19 of Group 8 | santa cruz.
# Processing the file 20 of Group 8 | natal.
# Processing the file 21 of Group 8 | monrovia.
# Processing the file 22 of Group 8 | arkhangelsk.
# Processing the file 23 of Group 8 | kahului.
# Processing the file 24 of Group 8 | ayan.
# Processing the file 25 of Group 8 | half moon bay.
# Processing the file 26 of Group 8 | vilhena.
# Processing the file 27 of Group 8 | vanavara.
# Processing the file 28 of Group 8 | san rafael del sur.
# Processing the file 29 of Group 8 | porto santo.
# Processing the file 30 of Group 8 | marakkanam.
# Processing the file 31 of Group 8 | ponta delgada.
# Processing the file 32 of Group 8 | shelburne.
# Processing the file 33 of Group 8 | mehamn.
# Processing the file 34 of Group 8 | santa vitoria do palmar.
# Processing the file 35 of Group 8 | high rock.
# Processing the file 36 of Group 8 | matay.
# Processing the file 37 of Group 8 | karratha.
# Processing the file 38 of Group 8 | hasaki.
# Processing the file 39 of Group 8 | hovd.
# Processing the file 40 of Group 8 | zholymbet.
# Processing the file 41 of Group 8 | huaihua.
# Processing the file 42 of Group 8 | kuryk.
# Processing the file 43 of Group 8 | kupang.
# Processing the file 44 of Group 8 | sarangani.
# Processing the file 45 of Group 8 | pokrovsk-uralskiy.
# Processing the file 46 of Group 8 | valdosta.
# Processing the file 47 of Group 8 | chicama.
# Processing the file 48 of Group 8 | gambela.
# Processing the file 49 of Group 8 | yanam.
# Processing the file 0 of Group 9 | mildura.
# Processing the file 1 of Group 9 | carballo.
# Processing the file 2 of Group 9 | margate.
# Processing the file 3 of Group 9 | yirol.
# Processing the file 4 of Group 9 | kaspiyskiy.
# Processing the file 5 of Group 9 | tsaratanana.
# Processing the file 6 of Group 9 | mananara.
# Processing the file 7 of Group 9 | vaasa.
# Processing the file 8 of Group 9 | grand gaube.
# Processing the file 9 of Group 9 | xichang.
# Processing the file 10 of Group 9 | prudentopolis.
# Processing the file 11 of Group 9 | lagoa.
# Processing the file 12 of Group 9 | kungurtug.
# Processing the file 13 of Group 9 | thayetmyo.
# Processing the file 14 of Group 9 | abha.
# Processing the file 15 of Group 9 | guaruja.
# Processing the file 16 of Group 9 | elat.
# Processing the file 17 of Group 9 | shumskiy.
# Processing the file 18 of Group 9 | plouzane.
# Processing the file 19 of Group 9 | vagur.
# Processing the file 20 of Group 9 | sturgeon bay.
# Processing the file 21 of Group 9 | takoradi.
# Processing the file 22 of Group 9 | jalu.
# Processing the file 23 of Group 9 | provideniya.
# Processing the file 24 of Group 9 | coquimbo.
# Processing the file 25 of Group 9 | halifax.
# Processing the file 26 of Group 9 | am timan.
# Processing the file 27 of Group 9 | takanabe.
# Processing the file 28 of Group 9 | ucluelet.
# Processing the file 29 of Group 9 | alcudia.
# Processing the file 30 of Group 9 | ballarat.
# Processing the file 31 of Group 9 | flinders.
# Processing the file 32 of Group 9 | necochea.
# Processing the file 33 of Group 9 | taburi.
# Processing the file 34 of Group 9 | arica.
# Processing the file 35 of Group 9 | ha tinh.
# Processing the file 36 of Group 9 | bolotnoye.
# Processing the file 37 of Group 9 | auki.
# Processing the file 38 of Group 9 | mkushi.
# Processing the file 39 of Group 9 | hofn.
# Processing the file 40 of Group 9 | jardim.
# Processing the file 41 of Group 9 | qarqin.
# Processing the file 42 of Group 9 | manicore.
# Processing the file 43 of Group 9 | lotung.
# Processing the file 44 of Group 9 | nador.
# Processing the file 45 of Group 9 | sala consilina.
# Processing the file 46 of Group 9 | maraa.
# Processing the file 47 of Group 9 | kulaman.
# Processing the file 48 of Group 9 | kendari.
# Processing the file 49 of Group 9 | america dourada.
# Processing the file 0 of Group 10 | husavik.
# Processing the file 1 of Group 10 | wamba.
# Processing the file 2 of Group 10 | barawe.
# Processing the file 3 of Group 10 | sao paulo de olivenca.
# Processing the file 4 of Group 10 | kamaishi.
# Processing the file 5 of Group 10 | laguna.
# Processing the file 6 of Group 10 | vaitupu.
# Processing the file 7 of Group 10 | sobolevo.
# Processing the file 8 of Group 10 | labuhan.
# Processing the file 9 of Group 10 | kiama.
# Processing the file 10 of Group 10 | morinville.
# Processing the file 11 of Group 10 | aklavik.
# Processing the file 12 of Group 10 | goure.
# Processing the file 13 of Group 10 | jaciara.
# Processing the file 14 of Group 10 | tabarqah.
# Processing the file 15 of Group 10 | saint george.
# Processing the file 16 of Group 10 | jiaonan.
# Processing the file 17 of Group 10 | tilichiki.
# Processing the file 18 of Group 10 | general roca.
# Processing the file 19 of Group 10 | channel-port aux basques.
# Processing the file 20 of Group 10 | ambilobe.
# Processing the file 21 of Group 10 | bhum.
# Processing the file 22 of Group 10 | yacuiba.
# Processing the file 23 of Group 10 | tokamachi.
# Processing the file 24 of Group 10 | los negros.
# Processing the file 25 of Group 10 | killybegs.
# Processing the file 26 of Group 10 | khash.
# Processing the file 27 of Group 10 | padang.
# Processing the file 28 of Group 10 | lasa.
# Processing the file 29 of Group 10 | praia.
# Processing the file 30 of Group 10 | ruatoria.
# Processing the file 31 of Group 10 | adrar.
# Processing the file 32 of Group 10 | tazovskiy.
# Processing the file 33 of Group 10 | tabas.
# Processing the file 34 of Group 10 | pasighat.
# Processing the file 35 of Group 10 | christchurch.
# Processing the file 36 of Group 10 | batagay.
# Processing the file 37 of Group 10 | olinda.
# Processing the file 38 of Group 10 | kayes.
# Processing the file 39 of Group 10 | khandyga.
# Processing the file 40 of Group 10 | chubbuck.
# Processing the file 41 of Group 10 | kuche.
# Processing the file 42 of Group 10 | armacao dos buzios.
# Processing the file 43 of Group 10 | rabo de peixe.
# Processing the file 44 of Group 10 | dongsheng.
# Processing the file 45 of Group 10 | mikasa.
# Processing the file 46 of Group 10 | wuwei.
# Processing the file 47 of Group 10 | bengkalis.
# Processing the file 48 of Group 10 | digby.
# Processing the file 49 of Group 10 | taloqan.
# Processing the file 0 of Group 11 | bodden town.
# Processing the file 1 of Group 11 | vardo.
# Processing the file 2 of Group 11 | kismayo.
# Processing the file 3 of Group 11 | praxedis guerrero.
# Processing the file 4 of Group 11 | jackson.
# Processing the file 5 of Group 11 | xuddur.
# Processing the file 6 of Group 11 | tsumeb.
# Processing the file 7 of Group 11 | mikuni.
# Processing the file 8 of Group 11 | gorno-chuyskiy.
# Processing the file 9 of Group 11 | atocha.
# Processing the file 10 of Group 11 | louisbourg.
# Processing the file 11 of Group 11 | kankan.
# Processing the file 12 of Group 11 | sabang.
# Processing the file 13 of Group 11 | lavrentiya.
# Processing the file 14 of Group 11 | sechura.
# Processing the file 15 of Group 11 | tura.
# Processing the file 16 of Group 11 | tyukhtet.
# Processing the file 17 of Group 11 | saint-georges.
# Processing the file 18 of Group 11 | kainantu.
# Processing the file 19 of Group 11 | grootfontein.
# Processing the file 20 of Group 11 | mercedes.
# Processing the file 21 of Group 11 | mount isa.
# Processing the file 22 of Group 11 | grand-lahou.
# Processing the file 23 of Group 11 | road town.
# Processing the file 24 of Group 11 | matamoros.
# Processing the file 25 of Group 11 | starotimoshkino.
# Processing the file 26 of Group 11 | boende.
# Processing the file 27 of Group 11 | thinadhoo.
# Processing the file 28 of Group 11 | onguday.
# Processing the file 29 of Group 11 | clonakilty.
# Processing the file 30 of Group 11 | corralillo.
# Processing the file 31 of Group 11 | fairbanks.
# Processing the file 32 of Group 11 | anadyr.
# Processing the file 33 of Group 11 | bone.
# Processing the file 34 of Group 11 | saleaula.
# Processing the file 35 of Group 11 | hualmay.
# Processing the file 36 of Group 11 | plettenberg bay.
# Processing the file 37 of Group 11 | port macquarie.
# Processing the file 38 of Group 11 | mlonggo.
# Processing the file 39 of Group 11 | aksarka.
# Processing the file 40 of Group 11 | porto walter.
# Processing the file 41 of Group 11 | siocon.
# Processing the file 42 of Group 11 | lima.
# Processing the file 43 of Group 11 | nizamabad.
# Processing the file 44 of Group 11 | bairiki.
# Processing the file 45 of Group 11 | yerbogachen.
# Processing the file 46 of Group 11 | salym.
# Processing the file 47 of Group 11 | vincennes.
# Processing the file 48 of Group 11 | portland.
# Processing the file 49 of Group 11 | kalevala.
# Processing the file 0 of Group 12 | arona.
# Processing the file 1 of Group 12 | pochutla.
# Processing the file 2 of Group 12 | opobo.
# Processing the file 3 of Group 12 | dalvik.
# Processing the file 4 of Group 12 | intipuca.
# Processing the file 5 of Group 12 | cidreira.
# Processing the file 6 of Group 12 | cagliari.
# Processing the file 7 of Group 12 | san-pedro.
# Processing the file 8 of Group 12 | tsihombe.
# Processing the file 9 of Group 12 | comodoro rivadavia.
# Processing the file 10 of Group 12 | nurota.
# Processing the file 11 of Group 12 | shestakovo.
# Processing the file 12 of Group 12 | tiznit.
# Processing the file 13 of Group 12 | pemberton.
# Processing the file 14 of Group 12 | xanxere.
# Processing the file 15 of Group 12 | katoro.
# Processing the file 16 of Group 12 | louis trichardt.
# Processing the file 17 of Group 12 | southbridge.
# Processing the file 18 of Group 12 | puerto escondido.
# Processing the file 19 of Group 12 | dubuque.
# Processing the file 20 of Group 12 | meulaboh.
# Processing the file 21 of Group 12 | harper.
# Processing the file 22 of Group 12 | araouane.
# Processing the file 23 of Group 12 | huangcun.
# Processing the file 24 of Group 12 | aswan.
# Processing the file 25 of Group 12 | waipawa.
# Processing the file 26 of Group 12 | rolim de moura.
# Processing the file 27 of Group 12 | yushan.
# Processing the file 28 of Group 12 | sumbawanga.
# Processing the file 29 of Group 12 | dekar.
# Processing the file 30 of Group 12 | vila franca do campo.
# Processing the file 31 of Group 12 | tagab.
# Processing the file 32 of Group 12 | adoni.
# Processing the file 33 of Group 12 | zhigansk.
# Processing the file 34 of Group 12 | acajutla.
# Processing the file 35 of Group 12 | burnie.
# Processing the file 36 of Group 12 | guasdualito.
# Processing the file 37 of Group 12 | mandal.
# Processing the file 38 of Group 12 | arlit.
# Processing the file 39 of Group 12 | tual.
# Processing the file 40 of Group 12 | rascani.
# Processing the file 41 of Group 12 | ancud.
# Processing the file 42 of Group 12 | tiarei.
# Processing the file 43 of Group 12 | warqla.
# Processing the file 44 of Group 12 | khristoforovo.
# Processing the file 45 of Group 12 | jardinopolis.
# Processing the file 46 of Group 12 | sandwick.
# Processing the file 47 of Group 12 | clyde river.
# Processing the file 48 of Group 12 | sironj.
# Processing the file 49 of Group 12 | sumbe.
# Processing the file 0 of Group 13 | yantzaza.
# Processing the file 1 of Group 13 | qui nhon.
# Processing the file 2 of Group 13 | kavaratti.
# Processing the file 3 of Group 13 | ixtapa.
# Processing the file 4 of Group 13 | paradwip.
# Processing the file 5 of Group 13 | qafsah.
# Processing the file 6 of Group 13 | dicabisagan.
# Processing the file 7 of Group 13 | stornoway.
# Processing the file 8 of Group 13 | kitimat.
# Processing the file 9 of Group 13 | goderich.
# Processing the file 10 of Group 13 | lata.
# Processing the file 11 of Group 13 | bria.
# Processing the file 12 of Group 13 | rorvik.
# Processing the file 13 of Group 13 | luangwa.
# Processing the file 14 of Group 13 | lundazi.
# Processing the file 15 of Group 13 | bandarbeyla.
# Processing the file 16 of Group 13 | los llanos de aridane.
# Processing the file 17 of Group 13 | cururupu.
# Processing the file 18 of Group 13 | matadi.
# Processing the file 19 of Group 13 | tinskoy.
# Processing the file 20 of Group 13 | chivolo.
# Processing the file 21 of Group 13 | boddam.
# Processing the file 22 of Group 13 | olafsvik.
# Processing the file 23 of Group 13 | dong hoi.
# Processing the file 24 of Group 13 | beyneu.
# Processing the file 25 of Group 13 | vredendal.
# Processing the file 26 of Group 13 | axim.
# Processing the file 27 of Group 13 | anjiang.
# Processing the file 28 of Group 13 | buin.
# Processing the file 29 of Group 13 | namibe.
# Processing the file 30 of Group 13 | dwarka.
# Processing the file 31 of Group 13 | hami.
# Processing the file 32 of Group 13 | acarau.
# Processing the file 33 of Group 13 | massaguet.
# Processing the file 34 of Group 13 | lucapa.
# Processing the file 35 of Group 13 | xadani.
# Processing the file 36 of Group 13 | asfi.
# Processing the file 37 of Group 13 | tomatlan.
# Processing the file 38 of Group 13 | noyabrsk.
# Processing the file 39 of Group 13 | urumqi.
# Processing the file 40 of Group 13 | hokitika.
# Processing the file 41 of Group 13 | nazarovo.
# Processing the file 42 of Group 13 | mimongo.
# Processing the file 43 of Group 13 | causapscal.
# Processing the file 44 of Group 13 | fortuna foothills.
# Processing the file 45 of Group 13 | dubbo.
# Processing the file 46 of Group 13 | sawai madhopur.
# Processing the file 47 of Group 13 | stephenville.
# Processing the file 48 of Group 13 | kuah.
# Processing the file 49 of Group 13 | xinglongshan.
# Processing the file 0 of Group 14 | fernandez.
# Processing the file 1 of Group 14 | gari.
# Processing the file 2 of Group 14 | chara.
# Processing the file 3 of Group 14 | warrnambool.
# Processing the file 4 of Group 14 | busing.
# Processing the file 5 of Group 14 | quatre cocos.
# Processing the file 6 of Group 14 | narathiwat.
# Processing the file 7 of Group 14 | phek.
# Processing the file 8 of Group 14 | erzin.
# Processing the file 9 of Group 14 | bagojo.
# Processing the file 10 of Group 14 | ennis.
# Processing the file 11 of Group 14 | touros.
# Processing the file 12 of Group 14 | barcelos.
# Processing the file 13 of Group 14 | benito juarez.
# Processing the file 14 of Group 14 | konevo.
# Processing the file 15 of Group 14 | oriximina.
# Processing the file 16 of Group 14 | cap-aux-meules.
# Processing the file 17 of Group 14 | bubaque.
# Processing the file 18 of Group 14 | angoche.
# Processing the file 19 of Group 14 | sinnamary.
# Processing the file 20 of Group 14 | madimba.
# Processing the file 21 of Group 14 | cap malheureux.
# Processing the file 22 of Group 14 | nybro.
# Processing the file 23 of Group 14 | fairfield.
# Processing the file 24 of Group 14 | irawan.
# Processing the file 25 of Group 14 | biak.
# Processing the file 26 of Group 14 | columbus.
# Processing the file 27 of Group 14 | katangli.
# Processing the file 28 of Group 14 | karamay.
# Processing the file 29 of Group 14 | evensk.
# Processing the file 30 of Group 14 | barentu.
# Processing the file 31 of Group 14 | pangkalanbuun.
# Processing the file 32 of Group 14 | kiruna.
# Processing the file 33 of Group 14 | portobelo.
# Processing the file 34 of Group 14 | bhan.
# Processing the file 35 of Group 14 | uyemskiy.
# Processing the file 36 of Group 14 | mabaruma.
# Processing the file 37 of Group 14 | kabalo.
# Processing the file 38 of Group 14 | mana.
# Processing the file 39 of Group 14 | kawalu.
# Processing the file 40 of Group 14 | namatanai.
# Processing the file 41 of Group 14 | la asuncion.
# Processing the file 42 of Group 14 | dorado.
# Processing the file 43 of Group 14 | paptalaya.
# Processing the file 44 of Group 14 | toora-khem.
# Processing the file 45 of Group 14 | tak bai.
# Processing the file 46 of Group 14 | erzurum.
# Processing the file 47 of Group 14 | gwadar.
# Processing the file 48 of Group 14 | papara.
# Processing the file 49 of Group 14 | lisala.
# Processing the file 0 of Group 15 | llata.
# Processing the file 1 of Group 15 | buritis.
# Processing the file 2 of Group 15 | prabumulih.
# Processing the file 3 of Group 15 | dzhusaly.
# Processing the file 4 of Group 15 | sorland.
# Processing the file 5 of Group 15 | mumford.
# Processing the file 6 of Group 15 | opunake.
# Processing the file 7 of Group 15 | maceio.
# Processing the file 8 of Group 15 | port lincoln.
# Processing the file 9 of Group 15 | yaan.
# Processing the file 10 of Group 15 | sulangan.
# Processing the file 11 of Group 15 | togul.
# Processing the file 12 of Group 15 | tianpeng.
# Processing the file 13 of Group 15 | anchorage.
# Processing the file 14 of Group 15 | soe.
# Processing the file 15 of Group 15 | alice town.
# Processing the file 16 of Group 15 | sept-iles.
# Processing the file 17 of Group 15 | yining.
# Processing the file 18 of Group 15 | ossora.
# Processing the file 19 of Group 15 | batemans bay.
# Processing the file 20 of Group 15 | mazagao.
# Processing the file 21 of Group 15 | the pas.
# Processing the file 22 of Group 15 | mount darwin.
# Processing the file 23 of Group 15 | fenoarivo.
# Processing the file 24 of Group 15 | clovis.
# Processing the file 25 of Group 15 | nelson bay.
# Processing the file 26 of Group 15 | camacha.
# Processing the file 27 of Group 15 | el wasta.
# Processing the file 28 of Group 15 | george town.
# Processing the file 29 of Group 15 | houston.
# Processing the file 30 of Group 15 | chimoio.
# Processing the file 31 of Group 15 | veinticinco de mayo.
# Processing the file 32 of Group 15 | victoria point.
# Processing the file 33 of Group 15 | marsaxlokk.
# Processing the file 34 of Group 15 | hay river.
# Processing the file 35 of Group 15 | pitimbu.
# Processing the file 36 of Group 15 | ippy.
# Processing the file 37 of Group 15 | broome.
# Processing the file 38 of Group 15 | samarai.
# Processing the file 39 of Group 15 | nuuk.
# Processing the file 40 of Group 15 | piterka.
# Processing the file 41 of Group 15 | carauari.
# Processing the file 42 of Group 15 | yeniseysk.
# Processing the file 43 of Group 15 | saint-paul.
# Processing the file 44 of Group 15 | daxian.
# -------------------------------
# API Retrieval is complete
# http://api.openweathermap.org/data/2.5/weather?appid=f4243e09885630e9dced03c5ef1f7560&units=metric&q=
# city name: []
# The latitude information received is: []
# The temperature information received is: []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(len(weather_by_city_df))

# %%
weather_by_city_dict = {"City": place, "Country": country, "Latitude": lat, "Longtitude": lng, "Max Temp": temp, "Humidity": hum, "Cloudiness": cld, "Wind Speed": wind, "Date":dt}

weather_by_city_df = pd.DataFrame.from_dict(weather_by_city_dict, orient = "index")

weather_by_city_df = weather_by_city_df.transpose()
weather_by_city_df
# Out:
#        City Country Latitude Longtitude Max Temp Humidity Cloudiness  \
# 0  coquimbo    None     None       None     None     None       None
#
#   Wind Speed  Date
# 0       None  None

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float),  alpha=.5, facecolor="red", edgecolors="black", marker ="o")
plt.title(f"Latitude vs Max Temperature in F")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)") 
print(f"The max temperatures are highest near the equator.")
plt.show()

# %%
# Save figure to Images folder dont run this right now ##########
plt.savefig("Images/Latitude vs Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(pd.to_numeric(city_weather["Latitude"]).astype(float), pd.to_numeric(city_weather["Humidity (%)"]).astype(float), facecolors="skyblue", edgecolors="purple", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Latitude vs Humidity as at 14/09/2021")
plt.show()

# %%
plt.savefig("Images/Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.savefig("Images/latitude_cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.savefig("Images/latitude vs wind speed.png")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
