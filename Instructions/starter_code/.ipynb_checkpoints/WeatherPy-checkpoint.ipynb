# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
from scipy import stats
from scipy.stats import linregress

from citipy import citipy
from datetime import date
import scipy.stats as st


# Import API key
from api_keys import weather_api_key
from citipy import citipy

# %%
#create a list of lattitute and longitiutde and cities
lat_range = (-90,90)
lon_range = (-180,180)

cities = []
lat_lon = []
unique_cities = []

#import cities datafile 
cities_pd = pd.read_csv("../output_data/cities.csv")
cities_pd.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ## Generate Cities List

# %%
#lat and long combination 
lat = np.random.uniform(lat_range[0], lat_range[1],size = 2000)
lon = np.random.uniform(lon_range[0], lon_range[1],size = 2000)

#map the lat and lon
lat_lon = zip(lat,lon)

#find the nearest city for a given coordinate

for coordinates in lat_lon:
    location_data = citipy.nearest_city(coordinates[0], coordinates[1])
    city = location_data.city_name
    country_name = location_data.country_code
    
    #if the location is unique add the new city into the cities list 
    if city not in unique_cities:
        unique_cities.append(city)
        cities.append(city)

print(len(cities))
# Out:
# 755

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#URL
units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"
API_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url = url + "appid=" + weather_api_key + "&q="

# %%
#create lists to store the variable data 
lat = []
lng = []
temp = []
hum = []
cld = []
wind = []
dt =[]
city_list = []
country = []
no_data = []

# %%
cities
# Out:
# ['orange',
#  'ribeira grande',
#  'mareeba',
#  'port elizabeth',
#  'arraial do cabo',
#  'ushuaia',
#  'saskylakh',
#  'minot',
#  'caceres',
#  'norman wells',
#  'hithadhoo',
#  'barentsburg',
#  'roma',
#  'bredasdorp',
#  'kuche',
#  'carnarvon',
#  'albany',
#  'mar del plata',
#  'matara',
#  'pisco',
#  'rikitea',
#  'mataura',
#  'san patricio',
#  'portland',
#  'sambava',
#  'oskarshamn',
#  'vaini',
#  'nanortalik',
#  'vila velha',
#  'georgetown',
#  'marco',
#  'saint-leu',
#  'lokosovo',
#  'hirara',
#  'guerrero negro',
#  'airai',
#  'olafsvik',
#  'longyearbyen',
#  'carberry',
#  'atuona',
#  'avarua',
#  'bambous virieux',
#  'bluff',
#  'bam',
#  'assiniboia',
#  'fallon',
#  'kapaa',
#  'thompson',
#  'saint george',
#  'lompoc',
#  'utamysh',
#  'holetown',
#  'ambanja',
#  'ouahigouya',
#  'qaanaaq',
#  'esperance',
#  'punta arenas',
#  'hobart',
#  'broome',
#  'murindo',
#  'vila franca do campo',
#  'utiroa',
#  'tasiilaq',
#  'sakakah',
#  'gat',
#  'attawapiskat',
#  'egvekinot',
#  'puerto ayora',
#  'jalu',
#  'barrow',
#  'hermanus',
#  'chojnow',
#  'busselton',
#  'bilma',
#  'hamilton',
#  'huarmey',
#  'aksarka',
#  'louisbourg',
#  'chuy',
#  'hilo',
#  'taolanaro',
#  'severo-kurilsk',
#  'butaritari',
#  'namibe',
#  'karkaralinsk',
#  'amderma',
#  'poum',
#  'shimoda',
#  'ngunguru',
#  'chokurdakh',
#  'east london',
#  'ratangarh',
#  'krasnyy chikoy',
#  'launceston',
#  'belomorsk',
#  'illoqqortoormiut',
#  'manaure',
#  'mys shmidta',
#  'cape town',
#  'saint-philippe',
#  'tilichiki',
#  'nisia floresta',
#  'garmsar',
#  'half moon bay',
#  'moshupa',
#  'sechura',
#  'ushtobe',
#  'kaitangata',
#  'clarksburg',
#  'atambua',
#  'sidi bu zayd',
#  'castro',
#  'unai',
#  'torit',
#  'tsihombe',
#  'manzhouli',
#  'bengkulu',
#  'phan thiet',
#  'pevek',
#  'khatanga',
#  'novyy urengoy',
#  'karari',
#  'ust-tsilma',
#  'port alfred',
#  'jamestown',
#  'pandan',
#  'norheimsund',
#  'cururupu',
#  'kamenka',
#  'kodiak',
#  'srednekolymsk',
#  'upernavik',
#  'pitimbu',
#  'salalah',
#  'itoman',
#  'haverfordwest',
#  'avera',
#  'buala',
#  'contai',
#  'sao filipe',
#  'alotau',
#  'belushya guba',
#  'cayenne',
#  'broken hill',
#  'san pedro de lloc',
#  'tabiauea',
#  'tiksi',
#  'tuktoyaktuk',
#  'mount gambier',
#  'iqaluit',
#  'benguela',
#  'ocampo',
#  'moerai',
#  'tazmalt',
#  'sibu',
#  'whitianga',
#  'lebu',
#  'kalikino',
#  'victoria',
#  'hasaki',
#  'klaksvik',
#  'cockburn town',
#  'petropavlovsk-kamchatskiy',
#  'clyde river',
#  'road town',
#  'yar-sale',
#  'berwyn',
#  'teguise',
#  'sarkand',
#  'pauini',
#  'elliot lake',
#  'zhangye',
#  'quang ngai',
#  'narsaq',
#  'new norfolk',
#  'bintulu',
#  'youkounkoun',
#  'wanaka',
#  'kirra',
#  'ilulissat',
#  'fortuna',
#  'north branch',
#  'nikolskoye',
#  'chodavaram',
#  'koslan',
#  'orange cove',
#  'morro bay',
#  'mayskiy',
#  'beloha',
#  'pirajui',
#  'katsuura',
#  'zhezkazgan',
#  'sancraieni',
#  'kiama',
#  'forbes',
#  'rocha',
#  'safaga',
#  'evensk',
#  'tumannyy',
#  'kainantu',
#  'port hardy',
#  'tucuman',
#  'concarneau',
#  'medea',
#  'bursa',
#  'tobermory',
#  'byron bay',
#  'jiwani',
#  'omboue',
#  'rungata',
#  'luderitz',
#  'vao',
#  'rio cuarto',
#  'kutum',
#  'faanui',
#  'padang',
#  'yellowknife',
#  'uvira',
#  'agboville',
#  'mayo',
#  'pontes e lacerda',
#  'roald',
#  'la cruz',
#  'pacific grove',
#  'catamarca',
#  'malinovoye ozero',
#  'sinjai',
#  'lagoa',
#  'nizhneyansk',
#  'sovetskiy',
#  'pemangkat',
#  'sept-iles',
#  'rawlins',
#  'codrington',
#  'khujner',
#  'comodoro rivadavia',
#  'necochea',
#  'bafra',
#  'omsukchan',
#  'te anau',
#  'deputatskiy',
#  'sobral',
#  'muros',
#  'xingyi',
#  'palaikastron',
#  'ormara',
#  'corralillo',
#  'saleaula',
#  'vaitupu',
#  'mnogovershinnyy',
#  'bundaberg',
#  'mirabad',
#  'lakes entrance',
#  'dhaulpur',
#  'yulara',
#  'florianopolis',
#  'samusu',
#  'mosquera',
#  'lata',
#  'gamba',
#  'marfino',
#  'salisbury',
#  'djibo',
#  'ambikapur',
#  'eureka',
#  'shakiso',
#  'taguatinga',
#  'mabaruma',
#  'khairpur nathan shah',
#  'kurilsk',
#  'kavieng',
#  'saint-francois',
#  'linhai',
#  'dawlatabad',
#  'myitkyina',
#  'acari',
#  'ostrovnoy',
#  'kruisfontein',
#  'bonthe',
#  'naco',
#  'ponta do sol',
#  'port lincoln',
#  'atar',
#  'oranjemund',
#  'shadrinsk',
#  'carutapera',
#  'friedeburg',
#  'mao',
#  'toora-khem',
#  'parabel',
#  'bolungarvik',
#  'vestmanna',
#  'marawi',
#  'banda aceh',
#  'port macquarie',
#  'wanlaweyn',
#  'nome',
#  'umm lajj',
#  'constitucion',
#  'chongwe',
#  'souillac',
#  'brae',
#  'katherine',
#  'saint-pierre',
#  'pilar',
#  'lasa',
#  'high rock',
#  'manokwari',
#  'dinklage',
#  'shetpe',
#  'geraldton',
#  'bela vista',
#  'chiniot',
#  'svetlograd',
#  'dikson',
#  'tigre',
#  'tautira',
#  'cherskiy',
#  'norsup',
#  'rembang',
#  'olginskaya',
#  'dhidhdhoo',
#  'mahebourg',
#  'hofn',
#  'hue',
#  'provideniya',
#  'dalhousie',
#  'kahului',
#  'shemonaikha',
#  'los llanos de aridane',
#  'ban nahin',
#  'ozu',
#  'sitka',
#  'fiche',
#  'ampanihy',
#  'kasama',
#  'naze',
#  'tayibe',
#  'bara',
#  'taoudenni',
#  'nemuro',
#  'saint anthony',
#  'grand river south east',
#  'cidreira',
#  'mazyr',
#  'krasnomayskiy',
#  'pasir gudang',
#  'tete',
#  'verkhnevilyuysk',
#  'porosozero',
#  'tambun',
#  'walla walla',
#  'caravelas',
#  'sioux lookout',
#  'mata',
#  'tromso',
#  'coihaique',
#  'bani walid',
#  'isabela',
#  'lagunas',
#  'zabid',
#  'arlit',
#  'kibala',
#  'kunya',
#  'cap malheureux',
#  'del rio',
#  'basco',
#  'seoul',
#  'lima',
#  'severobaykalsk',
#  'karauzyak',
#  'bemidji',
#  'mandla',
#  'bathsheba',
#  'suez',
#  'sosnovo',
#  'mooi river',
#  'tabarqah',
#  'les cayes',
#  'klyuchi',
#  'temaraia',
#  'barawe',
#  'regina',
#  'beringovskiy',
#  'touros',
#  'jonesboro',
#  'aklavik',
#  'ugoofaaru',
#  'srivilliputtur',
#  'altay',
#  'coquimbo',
#  'santa maria',
#  'waddan',
#  'searcy',
#  'alexandria',
#  'marsh harbour',
#  'sisimiut',
#  'yekepa',
#  'barreirinhas',
#  'oussouye',
#  'khash',
#  'changji',
#  'panorama',
#  'quthing',
#  'cristobal obregon',
#  'zhigansk',
#  'kawalu',
#  'najran',
#  'coari',
#  'tucupita',
#  'ambon',
#  'turayf',
#  'luan',
#  'tual',
#  'potiskum',
#  'owando',
#  'dianopolis',
#  'melfort',
#  'xining',
#  'morden',
#  'leningradskiy',
#  'lorengau',
#  'dakoro',
#  'brookings',
#  'hami',
#  'nasice',
#  'peniche',
#  'ust-kuyga',
#  'ewo',
#  'trelew',
#  'innisfail',
#  'lazarev',
#  'henties bay',
#  'yeppoon',
#  'gaya',
#  'champasak',
#  'hanting',
#  'marcona',
#  'pierre',
#  'labuhan',
#  'winneba',
#  'ballymena',
#  'bambanglipuro',
#  'sahrak',
#  'charters towers',
#  'feni',
#  'kokstad',
#  'kupino',
#  'leshukonskoye',
#  'camalu',
#  'berbera',
#  'dingle',
#  'emba',
#  'tura',
#  'majene',
#  'malanje',
#  'vestmannaeyjar',
#  'bayaguana',
#  'skagastrond',
#  'umzimvubu',
#  'katangli',
#  'talnakh',
#  'aswan',
#  'inhambane',
#  'shangzhi',
#  'palabuhanratu',
#  'bongouanou',
#  'jinchang',
#  'charlestown',
#  'sorong',
#  'chinsali',
#  'sonqor',
#  'havoysund',
#  'beitbridge',
#  'emerald',
#  'golden',
#  'jovellar',
#  'quatre cocos',
#  'skalistyy',
#  'vardo',
#  'the valley',
#  'cherdakly',
#  'heidenheim',
#  'bangolo',
#  'wulanhaote',
#  'arawa',
#  'hualmay',
#  'miranda',
#  'maumere',
#  'edson',
#  'concordia',
#  'yumen',
#  'kamina',
#  'baker city',
#  'pachino',
#  'barstow',
#  'college',
#  'sumbe',
#  'kisumu',
#  'alappuzha',
#  'ixtapa',
#  'durango',
#  'sao jose da coroa grande',
#  'fort frances',
#  'faya',
#  'niksar',
#  'ahipara',
#  'jiblah',
#  'martapura',
#  'lavrentiya',
#  'kieta',
#  'haibowan',
#  'maralal',
#  'hamada',
#  'port blair',
#  'kottagudem',
#  'waingapu',
#  'moura',
#  'torbay',
#  'saldanha',
#  'plainview',
#  'tabialan',
#  'sentyabrskiy',
#  'tarudant',
#  'cordoba',
#  'kargil',
#  'ancud',
#  'yeovil',
#  'jining',
#  'dunedin',
#  'cumbum',
#  'port hawkesbury',
#  'port keats',
#  'la union',
#  'zyryanka',
#  'sulangan',
#  'hanzhong',
#  'muisne',
#  'ola',
#  'margate',
#  'treinta y tres',
#  'chunskiy',
#  'sarangani',
#  'chumikan',
#  'okha',
#  'saveh',
#  'kandi',
#  'kipini',
#  'kiri buru',
#  'lingao',
#  'grindavik',
#  'waipawa',
#  'puerto leguizamo',
#  'lodja',
#  'mercedes',
#  'regeneracao',
#  'brigantine',
#  'andenes',
#  'humberto de campos',
#  'areosa',
#  'namie',
#  'kamenskoye',
#  'adrar',
#  'rio bueno',
#  'khandagayty',
#  'berlevag',
#  'nuuk',
#  'erzin',
#  'gravdal',
#  'ballina',
#  'perth',
#  'yaan',
#  'wahpeton',
#  'eberbach',
#  'kerema',
#  'riyadh',
#  'yanam',
#  'cabo san lucas',
#  'lolua',
#  'dubrovka',
#  'kegayli',
#  'kaihua',
#  'yangambi',
#  'fort nelson',
#  'ratnagiri',
#  'gubkinskiy',
#  'vizinga',
#  'haines junction',
#  'massakory',
#  'gewane',
#  'orsha',
#  'san cristobal',
#  'barbar',
#  'komsomolskiy',
#  'mogotes',
#  'russell',
#  'marzuq',
#  'asau',
#  'nova olinda do norte',
#  'piacabucu',
#  'bubaque',
#  'daura',
#  'izhma',
#  'monrovia',
#  'banamba',
#  'togur',
#  'baykit',
#  'osa',
#  'athabasca',
#  'aripuana',
#  'lefka',
#  'teonthar',
#  'arman',
#  'sorgun',
#  'kavaratti',
#  'calama',
#  'konice',
#  'semporna',
#  'guadalupe y calvo',
#  'grimstad',
#  'mahibadhoo',
#  'carballo',
#  'suntar',
#  'le port',
#  'mishelevka',
#  'price',
#  'bako',
#  'port hedland',
#  'acarau',
#  'chara',
#  'ondjiva',
#  'arcelia',
#  'dasoguz',
#  'tateyama',
#  'muriae',
#  'juchitan',
#  'vilyuysk',
#  'raudeberg',
#  'high prairie',
#  'yarada',
#  'nabire',
#  'kirkcudbright',
#  'lyaskelya',
#  'corinto',
#  'darfield',
#  'vilhena',
#  'harindanga',
#  'chute-aux-outardes',
#  'north platte',
#  'mayumba',
#  'dimbokro',
#  'hay river',
#  'aitape',
#  'itarema',
#  'meulaboh',
#  'jaicos',
#  'baghdad',
#  'timra',
#  'fairbanks',
#  'yamada',
#  'kolo',
#  'kargopol',
#  'oktyabrskiy',
#  'bulgan',
#  'mullaitivu',
#  'tuatapere',
#  'palmer',
#  'vyborg',
#  'makokou',
#  'boissevain',
#  'cabra',
#  'shitanjing',
#  'farafangana',
#  'latung',
#  'la ronge',
#  'nakhon sawan',
#  'tarakan',
#  'samarai',
#  'ciudad bolivar',
#  'bani',
#  'ducheng',
#  'valdivia',
#  'os',
#  'kloulklubed',
#  'husavik',
#  'merauke',
#  'boende',
#  'la asuncion',
#  'dolbeau',
#  'manta',
#  'saint-ambroise',
#  'anadyr',
#  'boa vista',
#  'olga',
#  'abu samrah',
#  'almaty',
#  'creston',
#  'killybegs',
#  'jaypur',
#  'mishkino',
#  'lieksa',
#  'geresk',
#  'jaitaran',
#  'atasu',
#  'povenets',
#  'mukhen',
#  'inirida',
#  'ulvik',
#  'grand gaube',
#  'ridgecrest',
#  'lac du bonnet',
#  'iskateley',
#  'linchuan',
#  'rasht',
#  'williams lake',
#  'champerico',
#  'samalaeulu',
#  'coalcoman',
#  'korla',
#  'walvis bay',
#  'kenai',
#  'port-gentil',
#  'dongning',
#  'san jose de guanipa',
#  'malyn',
#  'elko',
#  'nereju',
#  'manakara',
#  'taraz',
#  'young',
#  'andros',
#  'aleksandrov gay',
#  'bognor regis',
#  'toliary',
#  'kanye',
#  'yendi',
#  'bandarbeyla',
#  'puerto escondido',
#  'mrirt',
#  'dagda',
#  'cheuskiny',
#  'hunza',
#  'iraan',
#  'udaipur',
#  'derzhavinsk',
#  'prieska',
#  'alofi',
#  'zeya',
#  'laguna',
#  'bamako',
#  'svetlogorsk',
#  'yinchuan',
#  'soroti',
#  'mildura',
#  'olpad']

# %%
requests.get(query_url+'chuy').json()["coord"]["lat"]
# Out:
# -33.6971

# %%
#use API to scan through the dataset and insert it into the df and print a summary
number = 0
group = 1

#limit the API search so it doesn't max out


#start API run
print ("Initiate API Data Retrieval")
print ("-------------------------------")

for place in cities:
    try:
        print (f"Processing the file {number} of Group {group} | {place}.")
            
        #place the response into variables first
        response = requests.get(query_url+place).json()
        
        city_list.append(place)
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        hum.append(response["main"]["humidity"])
        cld.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        dt.append(response["dt"])
        country.append(response["sys"]["country"])

        
    except:
        (f"Weather for the city is unavaliable, checking next city: {place}.")
        
        city_list.remove(place)    
            
    number = number + 1
    if number == 50:
        number= 0
        group = group + 1   
        
print ("-------------------------------")
print ("API Retrieval is complete")
print(API_url)
print(f"city name: {city_list}")
print (f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# Initiate API Data Retrieval
# -------------------------------
# Processing the file 0 of Group 1 | orange.
# Processing the file 1 of Group 1 | ribeira grande.
# Processing the file 2 of Group 1 | mareeba.
# Processing the file 3 of Group 1 | port elizabeth.
# Processing the file 4 of Group 1 | arraial do cabo.
# Processing the file 5 of Group 1 | ushuaia.
# Processing the file 6 of Group 1 | saskylakh.
# Processing the file 7 of Group 1 | minot.
# Processing the file 8 of Group 1 | caceres.
# Processing the file 9 of Group 1 | norman wells.
# Processing the file 10 of Group 1 | hithadhoo.
# Processing the file 11 of Group 1 | barentsburg.
# Processing the file 12 of Group 1 | roma.
# Processing the file 13 of Group 1 | bredasdorp.
# Processing the file 14 of Group 1 | kuche.
# Processing the file 15 of Group 1 | carnarvon.
# Processing the file 16 of Group 1 | albany.
# Processing the file 17 of Group 1 | mar del plata.
# Processing the file 18 of Group 1 | matara.
# Processing the file 19 of Group 1 | pisco.
# Processing the file 20 of Group 1 | rikitea.
# Processing the file 21 of Group 1 | mataura.
# Processing the file 22 of Group 1 | san patricio.
# Processing the file 23 of Group 1 | portland.
# Processing the file 24 of Group 1 | sambava.
# Processing the file 25 of Group 1 | oskarshamn.
# Processing the file 26 of Group 1 | vaini.
# Processing the file 27 of Group 1 | nanortalik.
# Processing the file 28 of Group 1 | vila velha.
# Processing the file 29 of Group 1 | georgetown.
# Processing the file 30 of Group 1 | marco.
# Processing the file 31 of Group 1 | saint-leu.
# Processing the file 32 of Group 1 | lokosovo.
# Processing the file 33 of Group 1 | hirara.
# Processing the file 34 of Group 1 | guerrero negro.
# Processing the file 35 of Group 1 | airai.
# Processing the file 36 of Group 1 | olafsvik.
# Processing the file 37 of Group 1 | longyearbyen.
# Processing the file 38 of Group 1 | carberry.
# Processing the file 39 of Group 1 | atuona.
# Processing the file 40 of Group 1 | avarua.
# Processing the file 41 of Group 1 | bambous virieux.
# Processing the file 42 of Group 1 | bluff.
# Processing the file 43 of Group 1 | bam.
# Processing the file 44 of Group 1 | assiniboia.
# Processing the file 45 of Group 1 | fallon.
# Processing the file 46 of Group 1 | kapaa.
# Processing the file 47 of Group 1 | thompson.
# Processing the file 48 of Group 1 | saint george.
# Processing the file 49 of Group 1 | lompoc.
# Processing the file 0 of Group 2 | utamysh.
# Processing the file 1 of Group 2 | holetown.
# Processing the file 2 of Group 2 | ambanja.
# Processing the file 3 of Group 2 | ouahigouya.
# Processing the file 4 of Group 2 | qaanaaq.
# Processing the file 5 of Group 2 | esperance.
# Processing the file 6 of Group 2 | punta arenas.
# Processing the file 7 of Group 2 | hobart.
# Processing the file 8 of Group 2 | broome.
# Processing the file 9 of Group 2 | murindo.
# Processing the file 10 of Group 2 | vila franca do campo.
# Processing the file 11 of Group 2 | utiroa.
# Processing the file 12 of Group 2 | tasiilaq.
# Processing the file 13 of Group 2 | sakakah.
# Processing the file 14 of Group 2 | gat.
# Processing the file 15 of Group 2 | attawapiskat.
# Processing the file 16 of Group 2 | egvekinot.
# Processing the file 17 of Group 2 | puerto ayora.
# Processing the file 18 of Group 2 | jalu.
# Processing the file 19 of Group 2 | barrow.
# Processing the file 20 of Group 2 | hermanus.
# Processing the file 21 of Group 2 | chojnow.
# Processing the file 22 of Group 2 | busselton.
# Processing the file 23 of Group 2 | bilma.
# Processing the file 24 of Group 2 | hamilton.
# Processing the file 25 of Group 2 | huarmey.
# Processing the file 26 of Group 2 | aksarka.
# Processing the file 27 of Group 2 | louisbourg.
# Processing the file 28 of Group 2 | chuy.
# Processing the file 29 of Group 2 | hilo.
# Processing the file 30 of Group 2 | taolanaro.
# Processing the file 31 of Group 2 | severo-kurilsk.
# Processing the file 32 of Group 2 | butaritari.
# Processing the file 33 of Group 2 | namibe.
# Processing the file 34 of Group 2 | karkaralinsk.
# Processing the file 35 of Group 2 | amderma.
# Processing the file 36 of Group 2 | poum.
# Processing the file 37 of Group 2 | shimoda.
# Processing the file 38 of Group 2 | ngunguru.
# Processing the file 39 of Group 2 | chokurdakh.
# Processing the file 40 of Group 2 | east london.
# Processing the file 41 of Group 2 | ratangarh.
# Processing the file 42 of Group 2 | krasnyy chikoy.
# Processing the file 43 of Group 2 | launceston.
# Processing the file 44 of Group 2 | belomorsk.
# Processing the file 45 of Group 2 | illoqqortoormiut.
# Processing the file 46 of Group 2 | manaure.
# Processing the file 47 of Group 2 | mys shmidta.
# Processing the file 48 of Group 2 | cape town.
# Processing the file 49 of Group 2 | saint-philippe.
# Processing the file 0 of Group 3 | tilichiki.
# Processing the file 1 of Group 3 | nisia floresta.
# Processing the file 2 of Group 3 | garmsar.
# Processing the file 3 of Group 3 | half moon bay.
# Processing the file 4 of Group 3 | moshupa.
# Processing the file 5 of Group 3 | sechura.
# Processing the file 6 of Group 3 | ushtobe.
# Processing the file 7 of Group 3 | kaitangata.
# Processing the file 8 of Group 3 | clarksburg.
# Processing the file 9 of Group 3 | atambua.
# Processing the file 10 of Group 3 | sidi bu zayd.
# Processing the file 11 of Group 3 | castro.
# Processing the file 12 of Group 3 | unai.
# Processing the file 13 of Group 3 | torit.
# Processing the file 14 of Group 3 | tsihombe.
# Processing the file 15 of Group 3 | manzhouli.
# Processing the file 16 of Group 3 | bengkulu.
# Processing the file 17 of Group 3 | phan thiet.
# Processing the file 18 of Group 3 | pevek.
# Processing the file 19 of Group 3 | khatanga.
# Processing the file 20 of Group 3 | novyy urengoy.
# Processing the file 21 of Group 3 | karari.
# Processing the file 22 of Group 3 | ust-tsilma.
# Processing the file 23 of Group 3 | port alfred.
# Processing the file 24 of Group 3 | jamestown.
# Processing the file 25 of Group 3 | pandan.
# Processing the file 26 of Group 3 | norheimsund.
# Processing the file 27 of Group 3 | cururupu.
# Processing the file 28 of Group 3 | kamenka.
# Processing the file 29 of Group 3 | kodiak.
# Processing the file 30 of Group 3 | srednekolymsk.
# Processing the file 31 of Group 3 | upernavik.
# Processing the file 32 of Group 3 | pitimbu.
# Processing the file 33 of Group 3 | salalah.
# Processing the file 34 of Group 3 | itoman.
# Processing the file 35 of Group 3 | haverfordwest.
# Processing the file 36 of Group 3 | avera.
# Processing the file 37 of Group 3 | buala.
# Processing the file 38 of Group 3 | contai.
# Processing the file 39 of Group 3 | sao filipe.
# Processing the file 40 of Group 3 | alotau.
# Processing the file 41 of Group 3 | belushya guba.
# Processing the file 42 of Group 3 | cayenne.
# Processing the file 43 of Group 3 | broken hill.
# Processing the file 44 of Group 3 | san pedro de lloc.
# Processing the file 45 of Group 3 | tabiauea.
# Processing the file 46 of Group 3 | tiksi.
# Processing the file 47 of Group 3 | tuktoyaktuk.
# Processing the file 48 of Group 3 | mount gambier.
# Processing the file 49 of Group 3 | iqaluit.
# Processing the file 0 of Group 4 | benguela.
# Processing the file 1 of Group 4 | ocampo.
# Processing the file 2 of Group 4 | moerai.
# Processing the file 3 of Group 4 | tazmalt.
# Processing the file 4 of Group 4 | sibu.
# Processing the file 5 of Group 4 | whitianga.
# Processing the file 6 of Group 4 | lebu.
# Processing the file 7 of Group 4 | kalikino.
# Processing the file 8 of Group 4 | victoria.
# Processing the file 9 of Group 4 | hasaki.
# Processing the file 10 of Group 4 | klaksvik.
# Processing the file 11 of Group 4 | cockburn town.
# Processing the file 12 of Group 4 | petropavlovsk-kamchatskiy.
# Processing the file 13 of Group 4 | clyde river.
# Processing the file 14 of Group 4 | road town.
# Processing the file 15 of Group 4 | yar-sale.
# Processing the file 16 of Group 4 | berwyn.
# Processing the file 17 of Group 4 | teguise.
# Processing the file 18 of Group 4 | sarkand.
# Processing the file 19 of Group 4 | pauini.
# Processing the file 20 of Group 4 | elliot lake.
# Processing the file 21 of Group 4 | zhangye.
# Processing the file 22 of Group 4 | quang ngai.
# Processing the file 23 of Group 4 | narsaq.
# Processing the file 24 of Group 4 | new norfolk.
# Processing the file 25 of Group 4 | bintulu.
# Processing the file 26 of Group 4 | youkounkoun.
# Processing the file 27 of Group 4 | wanaka.
# Processing the file 28 of Group 4 | kirra.
# Processing the file 29 of Group 4 | ilulissat.
# Processing the file 30 of Group 4 | fortuna.
# Processing the file 31 of Group 4 | north branch.
# Processing the file 32 of Group 4 | nikolskoye.
# Processing the file 33 of Group 4 | chodavaram.
# Processing the file 34 of Group 4 | koslan.
# Processing the file 35 of Group 4 | orange cove.
# Processing the file 36 of Group 4 | morro bay.
# Processing the file 37 of Group 4 | mayskiy.
# Processing the file 38 of Group 4 | beloha.
# Processing the file 39 of Group 4 | pirajui.
# Processing the file 40 of Group 4 | katsuura.
# Processing the file 41 of Group 4 | zhezkazgan.
# Processing the file 42 of Group 4 | sancraieni.
# Processing the file 43 of Group 4 | kiama.
# Processing the file 44 of Group 4 | forbes.
# Processing the file 45 of Group 4 | rocha.
# Processing the file 46 of Group 4 | safaga.
# Processing the file 47 of Group 4 | evensk.
# Processing the file 48 of Group 4 | tumannyy.
# Processing the file 49 of Group 4 | kainantu.
# Processing the file 0 of Group 5 | port hardy.
# Processing the file 1 of Group 5 | tucuman.
# Processing the file 2 of Group 5 | concarneau.
# Processing the file 3 of Group 5 | medea.
# Processing the file 4 of Group 5 | bursa.
# Processing the file 5 of Group 5 | tobermory.
# Processing the file 6 of Group 5 | byron bay.
# Processing the file 7 of Group 5 | jiwani.
# Processing the file 8 of Group 5 | omboue.
# Processing the file 9 of Group 5 | rungata.
# Processing the file 10 of Group 5 | luderitz.
# Processing the file 11 of Group 5 | vao.
# Processing the file 12 of Group 5 | rio cuarto.
# Processing the file 13 of Group 5 | kutum.
# Processing the file 14 of Group 5 | faanui.
# Processing the file 15 of Group 5 | padang.
# Processing the file 16 of Group 5 | yellowknife.
# Processing the file 17 of Group 5 | uvira.
# Processing the file 18 of Group 5 | agboville.
# Processing the file 19 of Group 5 | mayo.
# Processing the file 20 of Group 5 | pontes e lacerda.
# Processing the file 21 of Group 5 | roald.
# Processing the file 22 of Group 5 | la cruz.
# Processing the file 23 of Group 5 | pacific grove.
# Processing the file 24 of Group 5 | catamarca.
# Processing the file 25 of Group 5 | malinovoye ozero.
# Processing the file 26 of Group 5 | sinjai.
# Processing the file 27 of Group 5 | lagoa.
# Processing the file 28 of Group 5 | nizhneyansk.
# Processing the file 29 of Group 5 | sovetskiy.
# Processing the file 30 of Group 5 | pemangkat.
# Processing the file 31 of Group 5 | sept-iles.
# Processing the file 32 of Group 5 | rawlins.
# Processing the file 33 of Group 5 | codrington.
# Processing the file 34 of Group 5 | khujner.
# Processing the file 35 of Group 5 | comodoro rivadavia.
# Processing the file 36 of Group 5 | necochea.
# Processing the file 37 of Group 5 | bafra.
# Processing the file 38 of Group 5 | omsukchan.
# Processing the file 39 of Group 5 | te anau.
# Processing the file 40 of Group 5 | deputatskiy.
# Processing the file 41 of Group 5 | sobral.
# Processing the file 42 of Group 5 | muros.
# Processing the file 43 of Group 5 | xingyi.
# Processing the file 44 of Group 5 | palaikastron.
# Processing the file 45 of Group 5 | ormara.
# Processing the file 46 of Group 5 | corralillo.
# Processing the file 47 of Group 5 | saleaula.
# Processing the file 48 of Group 5 | vaitupu.
# Processing the file 49 of Group 5 | mnogovershinnyy.
# Processing the file 0 of Group 6 | bundaberg.
# Processing the file 1 of Group 6 | mirabad.
# Processing the file 2 of Group 6 | lakes entrance.
# Processing the file 3 of Group 6 | dhaulpur.
# Processing the file 4 of Group 6 | yulara.
# Processing the file 5 of Group 6 | florianopolis.
# Processing the file 6 of Group 6 | samusu.
# Processing the file 7 of Group 6 | mosquera.
# Processing the file 8 of Group 6 | lata.
# Processing the file 9 of Group 6 | gamba.
# Processing the file 10 of Group 6 | marfino.
# Processing the file 11 of Group 6 | salisbury.
# Processing the file 12 of Group 6 | djibo.
# Processing the file 13 of Group 6 | ambikapur.
# Processing the file 14 of Group 6 | eureka.
# Processing the file 15 of Group 6 | shakiso.
# Processing the file 16 of Group 6 | taguatinga.
# Processing the file 17 of Group 6 | mabaruma.
# Processing the file 18 of Group 6 | khairpur nathan shah.
# Processing the file 19 of Group 6 | kurilsk.
# Processing the file 20 of Group 6 | kavieng.
# Processing the file 21 of Group 6 | saint-francois.
# Processing the file 22 of Group 6 | linhai.
# Processing the file 23 of Group 6 | dawlatabad.
# Processing the file 24 of Group 6 | myitkyina.
# Processing the file 25 of Group 6 | acari.
# Processing the file 26 of Group 6 | ostrovnoy.
# Processing the file 27 of Group 6 | kruisfontein.
# Processing the file 28 of Group 6 | bonthe.
# Processing the file 29 of Group 6 | naco.
# Processing the file 30 of Group 6 | ponta do sol.
# Processing the file 31 of Group 6 | port lincoln.
# Processing the file 32 of Group 6 | atar.
# Processing the file 33 of Group 6 | oranjemund.
# Processing the file 34 of Group 6 | shadrinsk.
# Processing the file 35 of Group 6 | carutapera.
# Processing the file 36 of Group 6 | friedeburg.
# Processing the file 37 of Group 6 | mao.
# Processing the file 38 of Group 6 | toora-khem.
# Processing the file 39 of Group 6 | parabel.
# Processing the file 40 of Group 6 | bolungarvik.
# Processing the file 41 of Group 6 | vestmanna.
# Processing the file 42 of Group 6 | marawi.
# Processing the file 43 of Group 6 | banda aceh.
# Processing the file 44 of Group 6 | port macquarie.
# Processing the file 45 of Group 6 | wanlaweyn.
# Processing the file 46 of Group 6 | nome.
# Processing the file 47 of Group 6 | umm lajj.
# Processing the file 48 of Group 6 | constitucion.
# Processing the file 49 of Group 6 | chongwe.
# Processing the file 0 of Group 7 | souillac.
# Processing the file 1 of Group 7 | brae.
# Processing the file 2 of Group 7 | katherine.
# Processing the file 3 of Group 7 | saint-pierre.
# Processing the file 4 of Group 7 | pilar.
# Processing the file 5 of Group 7 | lasa.
# Processing the file 6 of Group 7 | high rock.
# Processing the file 7 of Group 7 | manokwari.
# Processing the file 8 of Group 7 | dinklage.
# Processing the file 9 of Group 7 | shetpe.
# Processing the file 10 of Group 7 | geraldton.
# Processing the file 11 of Group 7 | bela vista.
# Processing the file 12 of Group 7 | chiniot.
# Processing the file 13 of Group 7 | svetlograd.
# Processing the file 14 of Group 7 | dikson.
# Processing the file 15 of Group 7 | tigre.
# Processing the file 16 of Group 7 | tautira.
# Processing the file 17 of Group 7 | cherskiy.
# Processing the file 18 of Group 7 | norsup.
# Processing the file 19 of Group 7 | rembang.
# Processing the file 20 of Group 7 | olginskaya.
# Processing the file 21 of Group 7 | dhidhdhoo.
# Processing the file 22 of Group 7 | mahebourg.
# Processing the file 23 of Group 7 | hofn.
# Processing the file 24 of Group 7 | hue.
# Processing the file 25 of Group 7 | provideniya.
# Processing the file 26 of Group 7 | dalhousie.
# Processing the file 27 of Group 7 | kahului.
# Processing the file 28 of Group 7 | shemonaikha.
# Processing the file 29 of Group 7 | los llanos de aridane.
# Processing the file 30 of Group 7 | ban nahin.
# Processing the file 31 of Group 7 | ozu.
# Processing the file 32 of Group 7 | sitka.
# Processing the file 33 of Group 7 | fiche.
# Processing the file 34 of Group 7 | ampanihy.
# Processing the file 35 of Group 7 | kasama.
# Processing the file 36 of Group 7 | naze.
# Processing the file 37 of Group 7 | tayibe.
# Processing the file 38 of Group 7 | bara.
# Processing the file 39 of Group 7 | taoudenni.
# Processing the file 40 of Group 7 | nemuro.
# Processing the file 41 of Group 7 | saint anthony.
# Processing the file 42 of Group 7 | grand river south east.
# Processing the file 43 of Group 7 | cidreira.
# Processing the file 44 of Group 7 | mazyr.
# Processing the file 45 of Group 7 | krasnomayskiy.
# Processing the file 46 of Group 7 | pasir gudang.
# Processing the file 47 of Group 7 | tete.
# Processing the file 48 of Group 7 | verkhnevilyuysk.
# Processing the file 49 of Group 7 | porosozero.
# Processing the file 0 of Group 8 | tambun.
# Processing the file 1 of Group 8 | walla walla.
# Processing the file 2 of Group 8 | caravelas.
# Processing the file 3 of Group 8 | sioux lookout.
# Processing the file 4 of Group 8 | mata.
# Processing the file 5 of Group 8 | tromso.
# Processing the file 6 of Group 8 | coihaique.
# Processing the file 7 of Group 8 | bani walid.
# Processing the file 8 of Group 8 | isabela.
# Processing the file 9 of Group 8 | lagunas.
# Processing the file 10 of Group 8 | zabid.
# Processing the file 11 of Group 8 | arlit.
# Processing the file 12 of Group 8 | kibala.
# Processing the file 13 of Group 8 | kunya.
# Processing the file 14 of Group 8 | cap malheureux.
# Processing the file 15 of Group 8 | del rio.
# Processing the file 16 of Group 8 | basco.
# Processing the file 17 of Group 8 | seoul.
# Processing the file 18 of Group 8 | lima.
# Processing the file 19 of Group 8 | severobaykalsk.
# Processing the file 20 of Group 8 | karauzyak.
# Processing the file 21 of Group 8 | bemidji.
# Processing the file 22 of Group 8 | mandla.
# Processing the file 23 of Group 8 | bathsheba.
# Processing the file 24 of Group 8 | suez.
# Processing the file 25 of Group 8 | sosnovo.
# Processing the file 26 of Group 8 | mooi river.
# Processing the file 27 of Group 8 | tabarqah.
# Processing the file 28 of Group 8 | les cayes.
# Processing the file 29 of Group 8 | klyuchi.
# Processing the file 30 of Group 8 | temaraia.
# Processing the file 31 of Group 8 | barawe.
# Processing the file 32 of Group 8 | regina.
# Processing the file 33 of Group 8 | beringovskiy.
# Processing the file 34 of Group 8 | touros.
# Processing the file 35 of Group 8 | jonesboro.
# Processing the file 36 of Group 8 | aklavik.
# Processing the file 37 of Group 8 | ugoofaaru.
# Processing the file 38 of Group 8 | srivilliputtur.
# Processing the file 39 of Group 8 | altay.
# Processing the file 40 of Group 8 | coquimbo.
# Processing the file 41 of Group 8 | santa maria.
# Processing the file 42 of Group 8 | waddan.
# Processing the file 43 of Group 8 | searcy.
# Processing the file 44 of Group 8 | alexandria.
# Processing the file 45 of Group 8 | marsh harbour.
# Processing the file 46 of Group 8 | sisimiut.
# Processing the file 47 of Group 8 | yekepa.
# Processing the file 48 of Group 8 | barreirinhas.
# Processing the file 49 of Group 8 | oussouye.
# Processing the file 0 of Group 9 | khash.
# Processing the file 1 of Group 9 | changji.
# Processing the file 2 of Group 9 | panorama.
# Processing the file 3 of Group 9 | quthing.
# Processing the file 4 of Group 9 | cristobal obregon.
# Processing the file 5 of Group 9 | zhigansk.
# Processing the file 6 of Group 9 | kawalu.
# Processing the file 7 of Group 9 | najran.
# Processing the file 8 of Group 9 | coari.
# Processing the file 9 of Group 9 | tucupita.
# Processing the file 10 of Group 9 | ambon.
# Processing the file 11 of Group 9 | turayf.
# Processing the file 12 of Group 9 | luan.
# Processing the file 13 of Group 9 | tual.
# Processing the file 14 of Group 9 | potiskum.
# Processing the file 15 of Group 9 | owando.
# Processing the file 16 of Group 9 | dianopolis.
# Processing the file 17 of Group 9 | melfort.
# Processing the file 18 of Group 9 | xining.
# Processing the file 19 of Group 9 | morden.
# Processing the file 20 of Group 9 | leningradskiy.
# Processing the file 21 of Group 9 | lorengau.
# Processing the file 22 of Group 9 | dakoro.
# Processing the file 23 of Group 9 | brookings.
# Processing the file 24 of Group 9 | hami.
# Processing the file 25 of Group 9 | nasice.
# Processing the file 26 of Group 9 | peniche.
# Processing the file 27 of Group 9 | ust-kuyga.
# Processing the file 28 of Group 9 | ewo.
# Processing the file 29 of Group 9 | trelew.
# Processing the file 30 of Group 9 | innisfail.
# Processing the file 31 of Group 9 | lazarev.
# Processing the file 32 of Group 9 | henties bay.
# Processing the file 33 of Group 9 | yeppoon.
# Processing the file 34 of Group 9 | gaya.
# Processing the file 35 of Group 9 | champasak.
# Processing the file 36 of Group 9 | hanting.
# Processing the file 37 of Group 9 | marcona.
# Processing the file 38 of Group 9 | pierre.
# Processing the file 39 of Group 9 | labuhan.
# Processing the file 40 of Group 9 | winneba.
# Processing the file 41 of Group 9 | ballymena.
# Processing the file 42 of Group 9 | bambanglipuro.
# Processing the file 43 of Group 9 | sahrak.
# Processing the file 44 of Group 9 | charters towers.
# Processing the file 45 of Group 9 | feni.
# Processing the file 46 of Group 9 | kokstad.
# Processing the file 47 of Group 9 | kupino.
# Processing the file 48 of Group 9 | leshukonskoye.
# Processing the file 49 of Group 9 | camalu.
# Processing the file 0 of Group 10 | berbera.
# Processing the file 1 of Group 10 | dingle.
# Processing the file 2 of Group 10 | emba.
# Processing the file 3 of Group 10 | tura.
# Processing the file 4 of Group 10 | majene.
# Processing the file 5 of Group 10 | malanje.
# Processing the file 6 of Group 10 | vestmannaeyjar.
# Processing the file 7 of Group 10 | bayaguana.
# Processing the file 8 of Group 10 | skagastrond.
# Processing the file 9 of Group 10 | umzimvubu.
# Processing the file 10 of Group 10 | katangli.
# Processing the file 11 of Group 10 | talnakh.
# Processing the file 12 of Group 10 | aswan.
# Processing the file 13 of Group 10 | inhambane.
# Processing the file 14 of Group 10 | shangzhi.
# Processing the file 15 of Group 10 | palabuhanratu.
# Processing the file 16 of Group 10 | bongouanou.
# Processing the file 17 of Group 10 | jinchang.
# Processing the file 18 of Group 10 | charlestown.
# Processing the file 19 of Group 10 | sorong.
# Processing the file 20 of Group 10 | chinsali.
# Processing the file 21 of Group 10 | sonqor.
# Processing the file 22 of Group 10 | havoysund.
# Processing the file 23 of Group 10 | beitbridge.
# Processing the file 24 of Group 10 | emerald.
# Processing the file 25 of Group 10 | golden.
# Processing the file 26 of Group 10 | jovellar.
# Processing the file 27 of Group 10 | quatre cocos.
# Processing the file 28 of Group 10 | skalistyy.
# Processing the file 29 of Group 10 | vardo.
# Processing the file 30 of Group 10 | the valley.
# Processing the file 31 of Group 10 | cherdakly.
# Processing the file 32 of Group 10 | heidenheim.
# Processing the file 33 of Group 10 | bangolo.
# Processing the file 34 of Group 10 | wulanhaote.
# Processing the file 35 of Group 10 | arawa.
# Processing the file 36 of Group 10 | hualmay.
# Processing the file 37 of Group 10 | miranda.
# Processing the file 38 of Group 10 | maumere.
# Processing the file 39 of Group 10 | edson.
# Processing the file 40 of Group 10 | concordia.
# Processing the file 41 of Group 10 | yumen.
# Processing the file 42 of Group 10 | kamina.
# Processing the file 43 of Group 10 | baker city.
# Processing the file 44 of Group 10 | pachino.
# Processing the file 45 of Group 10 | barstow.
# Processing the file 46 of Group 10 | college.
# Processing the file 47 of Group 10 | sumbe.
# Processing the file 48 of Group 10 | kisumu.
# Processing the file 49 of Group 10 | alappuzha.
# Processing the file 0 of Group 11 | ixtapa.
# Processing the file 1 of Group 11 | durango.
# Processing the file 2 of Group 11 | sao jose da coroa grande.
# Processing the file 3 of Group 11 | fort frances.
# Processing the file 4 of Group 11 | faya.
# Processing the file 5 of Group 11 | niksar.
# Processing the file 6 of Group 11 | ahipara.
# Processing the file 7 of Group 11 | jiblah.
# Processing the file 8 of Group 11 | martapura.
# Processing the file 9 of Group 11 | lavrentiya.
# Processing the file 10 of Group 11 | kieta.
# Processing the file 11 of Group 11 | haibowan.
# Processing the file 12 of Group 11 | maralal.
# Processing the file 13 of Group 11 | hamada.
# Processing the file 14 of Group 11 | port blair.
# Processing the file 15 of Group 11 | kottagudem.
# Processing the file 16 of Group 11 | waingapu.
# Processing the file 17 of Group 11 | moura.
# Processing the file 18 of Group 11 | torbay.
# Processing the file 19 of Group 11 | saldanha.
# Processing the file 20 of Group 11 | plainview.
# Processing the file 21 of Group 11 | tabialan.
# Processing the file 22 of Group 11 | sentyabrskiy.
# Processing the file 23 of Group 11 | tarudant.
# Processing the file 24 of Group 11 | cordoba.
# Processing the file 25 of Group 11 | kargil.
# Processing the file 26 of Group 11 | ancud.
# Processing the file 27 of Group 11 | yeovil.
# Processing the file 28 of Group 11 | jining.
# Processing the file 29 of Group 11 | dunedin.
# Processing the file 30 of Group 11 | cumbum.
# Processing the file 31 of Group 11 | port hawkesbury.
# Processing the file 32 of Group 11 | port keats.
# Processing the file 33 of Group 11 | la union.
# Processing the file 34 of Group 11 | zyryanka.
# Processing the file 35 of Group 11 | sulangan.
# Processing the file 36 of Group 11 | hanzhong.
# Processing the file 37 of Group 11 | muisne.
# Processing the file 38 of Group 11 | ola.
# Processing the file 39 of Group 11 | margate.
# Processing the file 40 of Group 11 | treinta y tres.
# Processing the file 41 of Group 11 | chunskiy.
# Processing the file 42 of Group 11 | sarangani.
# Processing the file 43 of Group 11 | chumikan.
# Processing the file 44 of Group 11 | okha.
# Processing the file 45 of Group 11 | saveh.
# Processing the file 46 of Group 11 | kandi.
# Processing the file 47 of Group 11 | kipini.
# Processing the file 48 of Group 11 | kiri buru.
# Processing the file 49 of Group 11 | lingao.
# Processing the file 0 of Group 12 | grindavik.
# Processing the file 1 of Group 12 | waipawa.
# Processing the file 2 of Group 12 | puerto leguizamo.
# Processing the file 3 of Group 12 | lodja.
# Processing the file 4 of Group 12 | mercedes.
# Processing the file 5 of Group 12 | regeneracao.
# Processing the file 6 of Group 12 | brigantine.
# Processing the file 7 of Group 12 | andenes.
# Processing the file 8 of Group 12 | humberto de campos.
# Processing the file 9 of Group 12 | areosa.
# Processing the file 10 of Group 12 | namie.
# Processing the file 11 of Group 12 | kamenskoye.
# Processing the file 12 of Group 12 | adrar.
# Processing the file 13 of Group 12 | rio bueno.
# Processing the file 14 of Group 12 | khandagayty.
# Processing the file 15 of Group 12 | berlevag.
# Processing the file 16 of Group 12 | nuuk.
# Processing the file 17 of Group 12 | erzin.
# Processing the file 18 of Group 12 | gravdal.
# Processing the file 19 of Group 12 | ballina.
# Processing the file 20 of Group 12 | perth.
# Processing the file 21 of Group 12 | yaan.
# Processing the file 22 of Group 12 | wahpeton.
# Processing the file 23 of Group 12 | eberbach.
# Processing the file 24 of Group 12 | kerema.
# Processing the file 25 of Group 12 | riyadh.
# Processing the file 26 of Group 12 | yanam.
# Processing the file 27 of Group 12 | cabo san lucas.
# Processing the file 28 of Group 12 | lolua.
# Processing the file 29 of Group 12 | dubrovka.
# Processing the file 30 of Group 12 | kegayli.
# Processing the file 31 of Group 12 | kaihua.
# Processing the file 32 of Group 12 | yangambi.
# Processing the file 33 of Group 12 | fort nelson.
# Processing the file 34 of Group 12 | ratnagiri.
# Processing the file 35 of Group 12 | gubkinskiy.
# Processing the file 36 of Group 12 | vizinga.
# Processing the file 37 of Group 12 | haines junction.
# Processing the file 38 of Group 12 | massakory.
# Processing the file 39 of Group 12 | gewane.
# Processing the file 40 of Group 12 | orsha.
# Processing the file 41 of Group 12 | san cristobal.
# Processing the file 42 of Group 12 | barbar.
# Processing the file 43 of Group 12 | komsomolskiy.
# Processing the file 44 of Group 12 | mogotes.
# Processing the file 45 of Group 12 | russell.
# Processing the file 46 of Group 12 | marzuq.
# Processing the file 47 of Group 12 | asau.
# Processing the file 48 of Group 12 | nova olinda do norte.
# Processing the file 49 of Group 12 | piacabucu.
# Processing the file 0 of Group 13 | bubaque.
# Processing the file 1 of Group 13 | daura.
# Processing the file 2 of Group 13 | izhma.
# Processing the file 3 of Group 13 | monrovia.
# Processing the file 4 of Group 13 | banamba.
# Processing the file 5 of Group 13 | togur.
# Processing the file 6 of Group 13 | baykit.
# Processing the file 7 of Group 13 | osa.
# Processing the file 8 of Group 13 | athabasca.
# Processing the file 9 of Group 13 | aripuana.
# Processing the file 10 of Group 13 | lefka.
# Processing the file 11 of Group 13 | teonthar.
# Processing the file 12 of Group 13 | arman.
# Processing the file 13 of Group 13 | sorgun.
# Processing the file 14 of Group 13 | kavaratti.
# Processing the file 15 of Group 13 | calama.
# Processing the file 16 of Group 13 | konice.
# Processing the file 17 of Group 13 | semporna.
# Processing the file 18 of Group 13 | guadalupe y calvo.
# Processing the file 19 of Group 13 | grimstad.
# Processing the file 20 of Group 13 | mahibadhoo.
# Processing the file 21 of Group 13 | carballo.
# Processing the file 22 of Group 13 | suntar.
# Processing the file 23 of Group 13 | le port.
# Processing the file 24 of Group 13 | mishelevka.
# Processing the file 25 of Group 13 | price.
# Processing the file 26 of Group 13 | bako.
# Processing the file 27 of Group 13 | port hedland.
# Processing the file 28 of Group 13 | acarau.
# Processing the file 29 of Group 13 | chara.
# Processing the file 30 of Group 13 | ondjiva.
# Processing the file 31 of Group 13 | arcelia.
# Processing the file 32 of Group 13 | dasoguz.
# Processing the file 33 of Group 13 | tateyama.
# Processing the file 34 of Group 13 | muriae.
# Processing the file 35 of Group 13 | juchitan.
# Processing the file 36 of Group 13 | vilyuysk.
# Processing the file 37 of Group 13 | raudeberg.
# Processing the file 38 of Group 13 | high prairie.
# Processing the file 39 of Group 13 | yarada.
# Processing the file 40 of Group 13 | nabire.
# Processing the file 41 of Group 13 | kirkcudbright.
# Processing the file 42 of Group 13 | lyaskelya.
# Processing the file 43 of Group 13 | corinto.
# Processing the file 44 of Group 13 | darfield.
# Processing the file 45 of Group 13 | vilhena.
# Processing the file 46 of Group 13 | harindanga.
# Processing the file 47 of Group 13 | chute-aux-outardes.
# Processing the file 48 of Group 13 | north platte.
# Processing the file 49 of Group 13 | mayumba.
# Processing the file 0 of Group 14 | dimbokro.
# Processing the file 1 of Group 14 | hay river.
# Processing the file 2 of Group 14 | aitape.
# Processing the file 3 of Group 14 | itarema.
# Processing the file 4 of Group 14 | meulaboh.
# Processing the file 5 of Group 14 | jaicos.
# Processing the file 6 of Group 14 | baghdad.
# Processing the file 7 of Group 14 | timra.
# Processing the file 8 of Group 14 | fairbanks.
# Processing the file 9 of Group 14 | yamada.
# Processing the file 10 of Group 14 | kolo.
# Processing the file 11 of Group 14 | kargopol.
# Processing the file 12 of Group 14 | oktyabrskiy.
# Processing the file 13 of Group 14 | bulgan.
# Processing the file 14 of Group 14 | mullaitivu.
# Processing the file 15 of Group 14 | tuatapere.
# Processing the file 16 of Group 14 | palmer.
# Processing the file 17 of Group 14 | vyborg.
# Processing the file 18 of Group 14 | makokou.
# Processing the file 19 of Group 14 | boissevain.
# Processing the file 20 of Group 14 | cabra.
# Processing the file 21 of Group 14 | shitanjing.
# Processing the file 22 of Group 14 | farafangana.
# Processing the file 23 of Group 14 | latung.
# Processing the file 24 of Group 14 | la ronge.
# Processing the file 25 of Group 14 | nakhon sawan.
# Processing the file 26 of Group 14 | tarakan.
# Processing the file 27 of Group 14 | samarai.
# Processing the file 28 of Group 14 | ciudad bolivar.
# Processing the file 29 of Group 14 | bani.
# Processing the file 30 of Group 14 | ducheng.
# Processing the file 31 of Group 14 | valdivia.
# Processing the file 32 of Group 14 | os.
# Processing the file 33 of Group 14 | kloulklubed.
# Processing the file 34 of Group 14 | husavik.
# Processing the file 35 of Group 14 | merauke.
# Processing the file 36 of Group 14 | boende.
# Processing the file 37 of Group 14 | la asuncion.
# Processing the file 38 of Group 14 | dolbeau.
# Processing the file 39 of Group 14 | manta.
# Processing the file 40 of Group 14 | saint-ambroise.
# Processing the file 41 of Group 14 | anadyr.
# Processing the file 42 of Group 14 | boa vista.
# Processing the file 43 of Group 14 | olga.
# Processing the file 44 of Group 14 | abu samrah.
# Processing the file 45 of Group 14 | almaty.
# Processing the file 46 of Group 14 | creston.
# Processing the file 47 of Group 14 | killybegs.
# Processing the file 48 of Group 14 | jaypur.
# Processing the file 49 of Group 14 | mishkino.
# Processing the file 0 of Group 15 | lieksa.
# Processing the file 1 of Group 15 | geresk.
# Processing the file 2 of Group 15 | jaitaran.
# Processing the file 3 of Group 15 | atasu.
# Processing the file 4 of Group 15 | povenets.
# Processing the file 5 of Group 15 | mukhen.
# Processing the file 6 of Group 15 | inirida.
# Processing the file 7 of Group 15 | ulvik.
# Processing the file 8 of Group 15 | grand gaube.
# Processing the file 9 of Group 15 | ridgecrest.
# Processing the file 10 of Group 15 | lac du bonnet.
# Processing the file 11 of Group 15 | iskateley.
# Processing the file 12 of Group 15 | linchuan.
# Processing the file 13 of Group 15 | rasht.
# Processing the file 14 of Group 15 | williams lake.
# Processing the file 15 of Group 15 | champerico.
# Processing the file 16 of Group 15 | samalaeulu.
# Processing the file 17 of Group 15 | coalcoman.
# Processing the file 18 of Group 15 | korla.
# Processing the file 19 of Group 15 | walvis bay.
# Processing the file 20 of Group 15 | kenai.
# Processing the file 21 of Group 15 | port-gentil.
# Processing the file 22 of Group 15 | dongning.
# Processing the file 23 of Group 15 | san jose de guanipa.
# Processing the file 24 of Group 15 | malyn.
# Processing the file 25 of Group 15 | elko.
# Processing the file 26 of Group 15 | nereju.
# Processing the file 27 of Group 15 | manakara.
# Processing the file 28 of Group 15 | taraz.
# Processing the file 29 of Group 15 | young.
# Processing the file 30 of Group 15 | andros.
# Processing the file 31 of Group 15 | aleksandrov gay.
# Processing the file 32 of Group 15 | bognor regis.
# Processing the file 33 of Group 15 | toliary.
# Processing the file 34 of Group 15 | kanye.
# Processing the file 35 of Group 15 | yendi.
# Processing the file 36 of Group 15 | bandarbeyla.
# Processing the file 37 of Group 15 | puerto escondido.
# Processing the file 38 of Group 15 | mrirt.
# Processing the file 39 of Group 15 | dagda.
# Processing the file 40 of Group 15 | cheuskiny.
# Processing the file 41 of Group 15 | hunza.
# Processing the file 42 of Group 15 | iraan.
# Processing the file 43 of Group 15 | udaipur.
# Processing the file 44 of Group 15 | derzhavinsk.
# Processing the file 45 of Group 15 | prieska.
# Processing the file 46 of Group 15 | alofi.
# Processing the file 47 of Group 15 | zeya.
# Processing the file 48 of Group 15 | laguna.
# Processing the file 49 of Group 15 | bamako.
# Processing the file 0 of Group 16 | svetlogorsk.
# Processing the file 1 of Group 16 | yinchuan.
# Processing the file 2 of Group 16 | soroti.
# Processing the file 3 of Group 16 | mildura.
# Processing the file 4 of Group 16 | olpad.
# -------------------------------
# API Retrieval is complete
# http://api.openweathermap.org/data/2.5/weather?appid=f4243e09885630e9dced03c5ef1f7560&units=metric&q=
# city name: ['orange', 'ribeira grande', 'mareeba', 'port elizabeth', 'arraial do cabo', 'ushuaia', 'saskylakh', 'minot', 'caceres', 'norman wells', 'hithadhoo', 'orange', 'ribeira grande', 'mareeba', 'port elizabeth', 'arraial do cabo', 'ushuaia', 'saskylakh', 'minot', 'caceres', 'norman wells', 'hithadhoo', 'barentsburg', 'orange', 'ribeira grande', 'mareeba', 'port elizabeth', 'arraial do cabo', 'ushuaia', 'saskylakh', 'minot', 'caceres', 'norman wells', 'hithadhoo', 'barentsburg', 'roma', 'bredasdorp', 'carnarvon', 'albany', 'mar del plata', 'matara', 'pisco', 'rikitea', 'mataura', 'san patricio', 'portland', 'sambava', 'oskarshamn', 'vaini', 'nanortalik', 'vila velha', 'georgetown', 'marco', 'saint-leu', 'lokosovo', 'hirara', 'guerrero negro', 'airai', 'olafsvik', 'longyearbyen', 'carberry', 'atuona', 'avarua', 'bambous virieux', 'bluff', 'bam', 'assiniboia', 'fallon', 'kapaa', 'thompson', 'saint george', 'lompoc', 'utamysh', 'holetown', 'ambanja', 'ouahigouya', 'qaanaaq', 'esperance', 'punta arenas', 'hobart', 'broome', 'murindo', 'vila franca do campo', 'tasiilaq', 'sakakah', 'gat', 'egvekinot', 'puerto ayora', 'jalu', 'barrow', 'hermanus', 'chojnow', 'busselton', 'bilma', 'hamilton', 'huarmey', 'aksarka', 'chuy', 'hilo', 'severo-kurilsk', 'butaritari', 'namibe', 'poum', 'shimoda', 'ngunguru', 'chokurdakh', 'east london', 'ratangarh', 'krasnyy chikoy', 'launceston', 'belomorsk', 'manaure', 'cape town', 'saint-philippe', 'tilichiki', 'nisia floresta', 'garmsar', 'half moon bay', 'moshupa', 'sechura', 'ushtobe', 'kaitangata', 'clarksburg', 'atambua', 'castro', 'unai', 'torit', 'manzhouli', 'bengkulu', 'phan thiet', 'pevek', 'khatanga', 'novyy urengoy', 'karari', 'ust-tsilma', 'port alfred', 'jamestown', 'pandan', 'norheimsund', 'cururupu', 'kamenka', 'kodiak', 'srednekolymsk', 'upernavik', 'pitimbu', 'salalah', 'itoman', 'haverfordwest', 'avera', 'buala', 'contai', 'sao filipe', 'cayenne', 'broken hill', 'san pedro de lloc', 'tiksi', 'tuktoyaktuk', 'mount gambier', 'iqaluit', 'benguela', 'ocampo', 'moerai', 'tazmalt', 'sibu', 'whitianga', 'lebu', 'kalikino', 'victoria', 'hasaki', 'klaksvik', 'cockburn town', 'petropavlovsk-kamchatskiy', 'clyde river', 'road town', 'yar-sale', 'berwyn', 'teguise', 'sarkand', 'pauini', 'elliot lake', 'zhangye', 'quang ngai', 'narsaq', 'new norfolk', 'bintulu', 'youkounkoun', 'wanaka', 'kirra', 'ilulissat', 'fortuna', 'north branch', 'nikolskoye', 'chodavaram', 'koslan', 'orange cove', 'morro bay', 'mayskiy', 'beloha', 'pirajui', 'katsuura', 'zhezkazgan', 'sancraieni', 'kiama', 'forbes', 'rocha', 'safaga', 'evensk', 'kainantu', 'port hardy', 'tucuman', 'concarneau', 'medea', 'bursa', 'tobermory', 'byron bay', 'jiwani', 'omboue', 'luderitz', 'vao', 'rio cuarto', 'kutum', 'faanui', 'padang', 'yellowknife', 'uvira', 'agboville', 'mayo', 'pontes e lacerda', 'roald', 'la cruz', 'pacific grove', 'catamarca', 'malinovoye ozero', 'sinjai', 'lagoa', 'sovetskiy', 'pemangkat', 'sept-iles', 'rawlins', 'codrington', 'khujner', 'comodoro rivadavia', 'necochea', 'bafra', 'omsukchan', 'te anau', 'deputatskiy', 'sobral', 'muros', 'xingyi', 'palaikastron', 'ormara', 'corralillo', 'mnogovershinnyy', 'bundaberg', 'mirabad', 'lakes entrance', 'dhaulpur', 'yulara', 'florianopolis', 'mosquera', 'lata', 'gamba', 'marfino', 'salisbury', 'djibo', 'ambikapur', 'eureka', 'shakiso', 'taguatinga', 'mabaruma', 'khairpur nathan shah', 'kurilsk', 'kavieng', 'saint-francois', 'linhai', 'dawlatabad', 'myitkyina', 'acari', 'ostrovnoy', 'kruisfontein', 'bonthe', 'naco', 'ponta do sol', 'port lincoln', 'atar', 'oranjemund', 'shadrinsk', 'carutapera', 'friedeburg', 'mao', 'toora-khem', 'parabel', 'vestmanna', 'marawi', 'banda aceh', 'port macquarie', 'wanlaweyn', 'nome', 'umm lajj', 'constitucion', 'chongwe', 'souillac', 'brae', 'katherine', 'saint-pierre', 'pilar', 'lasa', 'high rock', 'manokwari', 'dinklage', 'shetpe', 'geraldton', 'bela vista', 'chiniot', 'svetlograd', 'dikson', 'tigre', 'tautira', 'cherskiy', 'norsup', 'remban ...
# The latitude information received is: [33.7, 38.5167, -17, -33.918, -22.9661, -54.8, 71.9167, 48.2325, 39.522, 65.282, -0.6, 33.7, 38.5167, -17, -33.918, -22.9661, -54.8, 71.9167, 48.2325, 39.522, 65.282, -0.6, 33.7, 38.5167, -17, -33.918, -22.9661, -54.8, 71.9167, 48.2325, 39.522, 65.282, -0.6, 43.2128, -34.5322, -24.8667, 42.6001, -38.0023, 5.9485, -13.7, -23.1203, -46.1927, 28.017, 45.5234, -14.2667, 57.2645, -21.2, 60.1432, -20.3297, 5.4112, 25.9726, -21.15, 61.1333, 24.8, 27.9769, -8.9266, 64.8945, 78.2186, 49.8689, -9.8, -21.2078, -20.3428, -46.6, 29.106, 49.6334, 39.4735, 22.0752, 55.7435, 37.1041, 34.6391, 42.4072, 13.1867, -13.6833, 13.5828, 77.484, -33.8667, -53.15, -42.8794, 42.2506, 6.9848, 37.7167, 65.6145, 29.9697, 31.61, 66.3167, -0.7393, 29.0331, 71.2906, -34.4187, 51.2737, -33.65, 18.6853, 39.1834, -10.0681, 66.5606, -33.6971, 19.7297, 50.6789, 3.0707, -15.1961, -20.2333, 34.6667, -35.6167, 70.6333, -33.0153, 28.0833, 50.3643, -41.45, 64.5232, 11.7751, -33.9258, -21.3585, 60.4667, -6.0911, 35.2182, 37.4636, -24.7782, -5.5569, 45.2514, -46.2817, 39.2807, -9.1061, -24.7911, -16.3575, 4.4133, 49.6, -3.8004, 10.9333, 69.7008, 71.9667, 66.0833, 25.45, 65.441, -33.5906, 42.097, 14.0453, 60.3709, -1.8283, 51.3223, 57.79, 67.45, 72.7868, -7.4706, 17.0151, 26.1247, 51.8017, 33.194, -8.145, 21.7786, 14.8961, 4.9333, -31.95, -7.4328, 71.6872, 69.4541, -37.8333, 63.7506, -12.5763, 21.65, -22.4333, 36.3868, 2.3, -36.8333, -37.6167, 52.9493, 22.2855, 35.7333, 62.2266, 21.4612, 53.0452, 70.4692, 18.4167, 66.8333, 41.8506, 29.0605, 45.41, -7.7136, 46.3834, 38.9342, 15.1167, 60.9167, -42.7826, 3.1667, 12.5333, -44.7, 38.4333, 69.2167, 40.5982, 45.5113, 59.7035, 17.8333, 63.4564, 36.6244, 35.3658, 47.6931, -25.1667, -21.9986, 35.1333, 47.8043, 46.3144, -34.6833, -33.3833, -34.4833, 26.7292, 61.95, -6.2887, 50.6996, -26.8241, 47.875, 36.2642, 40.1667, 45.2501, -28.65, 25.05, -1.5746, -26.6481, -22.6667, -33.1307, 14.2, -16.4833, -0.9492, 62.456, -3.4067, 5.928, 38.8876, -15.2261, 62.5833, 23.9167, 36.6177, -28.4696, 51.6753, -5.1241, 39.05, 61.3614, 1.1667, 50.2001, 41.7911, -38.2667, 23.7833, -45.8667, -38.5473, 41.5678, 62.5333, -45.4167, 69.3, -3.6861, 42.7762, 24.1877, 35.2, 25.2088, 22.9819, 53.9353, -24.85, 30.4362, -37.8811, 26.7, -25.2406, -27.6146, 4.7059, 40.1629, -2.65, 55.7028, 51.0693, 14.1022, 23.1167, 40.8021, 5.75, -12.3857, 8.2, 27.0936, 45.2333, -2.5744, 46.4154, 28.85, 36.4141, 25.3833, -15.4311, 68.0531, -34.0033, 7.5264, 31.3347, 32.6667, -34.7333, 20.5169, -28.55, 56.0852, -1.195, 53.45, 39.8885, 52.4675, 58.6978, 62.1564, 7.9986, 5.5577, -31.4333, 2.6185, 64.5011, 25.0213, -35.3333, -15.3292, -20.5167, 60.3964, -14.4667, -21.3393, -9.5972, 46.6166, 26.6208, -0.8667, 52.65, 44.1667, -28.7667, -22.1089, 31.72, 45.3353, 73.5069, -34.426, -17.7333, 68.75, -16.0667, -6.707, 47.1879, 6.8833, -20.4081, 64.2539, 16.4667, 64.3833, 32.5333, 20.8947, 50.6328, 28.6585, 18.2418, 33.5, 57.0531, 9.8, -24.7, -10.2129, 28.3667, 10.3744, 22.6783, 43.3236, 45.0205, -30.1811, 52.0495, 57.6194, 1.4584, -16.1564, 63.4453, 62.7191, -6.2641, 46.0646, -17.7125, 50.1001, 40.683, 69.6496, -45.5752, 31.7566, 6.7085, -5.2269, 14.1951, 18.7369, 9.1104, 12.2233, -19.9842, 29.3627, 20.4487, 37.5683, -12.0432, 55.65, 47.4736, 22.6, 13.2167, 29.9737, 60.5514, 18.2, 52.2667, 50.4501, 63.05, -5.1989, 35.8423, 68.2191, 5.6667, 9.5081, 47.8667, -29.9533, -29.6842, 29.1614, 35.2506, 31.2156, 26.5412, 66.9395, 7.5753, -2.7469, 12.485, 28.2211, 44.0167, 40.5878, -30.4, 16.35, 66.7697, -7.3817, 17.4924, -4.085, 9.0622, -3.6954, 31.6725, 46.3592, -5.6667, 11.7091, -0.4819, 52.8667, 36.6167, 49.1919, 69.3833, -2.0226, 14.5106, 44.3114, 42.8, 45.4886, 39.3558, 70.0167, -0.8725, -43.249, -17.5333, 52.225, -22.116, -23.1333, 24.7833, 14.75, 36.7708, 44.3683, -6.8844, 5.3511, 54.8636, -7.95, -20.1, 23.0186, -30.5472, 54.3663, 64.8989, 30.85, 10.4396, 10.9995, 48.8264, 25.5198, -3.5403, -9.5402, 63.4427, 18.7564, 51.7102, 69.4865, 24.0934, -23.865, 45.21 ...
# The temperature information received is: [292.92, 296.37, 293.55, 290.31, 296.13, 272.96, 279.96, 285.7, 292.48, 279.17, 300.67, 292.92, 296.37, 293.55, 290.31, 296.13, 272.96, 279.96, 285.7, 292.48, 279.17, 300.67, 292.92, 296.37, 293.55, 290.31, 296.13, 272.96, 279.96, 285.7, 292.48, 279.17, 300.67, 296.85, 290.77, 293.19, 296.93, 276.16, 301.33, 288.18, 296.23, 280.08, 299.07, 291.9, 297.69, 291.37, 296.24, 277.18, 297.12, 304.11, 297.18, 298.61, 284.49, 300.3, 293.8, 289.9, 281.09, 275.06, 276.28, 298.21, 295.18, 298.29, 280.26, 308.72, 287.1, 292.55, 299.33, 277.24, 296.78, 287.82, 298, 301.46, 304.11, 305.6, 262.47, 294.06, 273.21, 280.52, 295.02, 295.33, 295.38, 278.24, 308.91, 305.04, 271.6, 292.34, 304.33, 276.16, 289.76, 297.59, 288.2, 312.02, 294.81, 289.08, 281.78, 281, 296.08, 282.3, 301.03, 292.5, 295.29, 295.71, 289.35, 271.38, 293.67, 307.32, 284.2, 282.95, 281.33, 300.62, 290.99, 298.9, 276.3, 297.6, 310.12, 289.05, 305.38, 289.96, 302.45, 278.8, 293.4, 297.87, 291.14, 300.96, 306.2, 284.3, 300.13, 298.89, 273.06, 280.42, 281.83, 298.4, 282.23, 291.29, 292.63, 300.79, 290.34, 300.35, 290.37, 277.88, 280.3, 271.29, 298.48, 303.2, 302.58, 292.34, 293.88, 299.84, 301.44, 300.4, 298.76, 286.99, 289.2, 276.91, 278.26, 283.1, 274, 298.08, 285.99, 295.97, 308.14, 298.32, 286.49, 279.69, 288.91, 305.18, 294.37, 284.66, 301.43, 278.48, 270.91, 301.04, 281.82, 290.14, 296.27, 300.17, 296.59, 286.2, 295.69, 299.9, 272.27, 280.87, 297.38, 301.91, 277.65, 306.37, 273.16, 283.33, 285.59, 281.09, 305.06, 279.04, 295.96, 288.26, 298.82, 306.53, 294.88, 296.21, 296.38, 297.96, 285.58, 280.88, 281.59, 308.12, 279.94, 288.1, 283.15, 287.15, 293.59, 299.4, 294.17, 288.72, 290.09, 303.37, 300.07, 291.47, 293.49, 278.06, 305.14, 299.23, 302.18, 282.44, 304.27, 300.56, 296.55, 297.17, 288.77, 298.79, 287.97, 287.47, 297.06, 298.37, 293.51, 278.48, 298.06, 283.39, 286.27, 283.87, 300.57, 284.07, 279.28, 292.03, 278.81, 276.3, 279.22, 302.63, 295.5, 292.24, 298.3, 301.97, 297.58, 283.46, 289.38, 310.64, 283.47, 301.67, 299.06, 290.61, 278.2, 294.77, 299.3, 285.29, 294.24, 306.39, 298.43, 283.47, 300.25, 302.9, 297.31, 316.76, 283.92, 300.17, 293.84, 296.51, 309.48, 302.78, 289.88, 279.71, 288.64, 298.44, 295.82, 300.38, 286.75, 310.54, 288.89, 293.62, 299.89, 293.12, 300.46, 284.69, 279.99, 283.66, 295.73, 301.22, 286.13, 306.61, 279.19, 306.43, 281.01, 307.66, 298.36, 287.1, 305.33, 298.95, 298.11, 292.64, 296.16, 299.2, 292.23, 302.7, 289.38, 294.69, 312.21, 301.14, 277.14, 284.42, 296.16, 274.12, 298.59, 300.9, 301.64, 301.31, 298.31, 283.16, 304.21, 277.94, 292.9, 297.16, 295.07, 298.01, 299.45, 297.94, 283.09, 289.73, 308.81, 305.55, 299.66, 304.03, 315.39, 285.79, 286.01, 286.61, 291.4, 282.62, 303.26, 309.2, 278.68, 280.21, 303.17, 294, 299.2, 281.36, 292, 283.51, 280.12, 303.02, 300.18, 295, 309.29, 311.04, 305.12, 302.24, 298.42, 299.21, 302.3, 297.88, 288.09, 279.81, 283.1, 298.37, 301.49, 307.09, 281.26, 298.02, 296.44, 288.16, 278.31, 297.65, 294.28, 279.61, 301.63, 311.06, 293.79, 282, 279.76, 302.3, 295.51, 302.45, 300.36, 274.26, 295.31, 301.28, 303.2, 306.21, 302.59, 303.39, 295.31, 293.74, 280.68, 296.68, 308.51, 296.04, 297.22, 300.23, 303.29, 291.43, 300.35, 304.22, 307.18, 286.22, 284.32, 285.39, 270.45, 300.04, 304.77, 284.38, 302.98, 303.68, 297.2, 281.01, 305.74, 282.45, 292.55, 288.68, 286.96, 290.03, 299.1, 304.64, 295.16, 289.74, 301.35, 300.41, 289.27, 298.08, 291.75, 301.56, 290.28, 295.15, 281.74, 292.95, 307.6, 299.25, 301.19, 299.78, 299.64, 298.36, 283.7, 299.23, 283, 278.37, 312.76, 302.14, 286.88, 302.91, 293.77, 287.03, 299.52, 306.43, 307.6, 280.64, 309.23, 294.23, 290.79, 299.23, 298.21, 280.26, 300.43, 287.12, 294.52, 295, 296.79, 288.5, 290.22, 300.11, 279.23, 278.19, 296.87, 304.59, 287.7, 305.17, 296.75, 279.76, 298.15, 300.04, 301.12, 297.72, 289.74, 299.18, 280.96, 302.44, 298.27, 288.57, 297.64, 299.2, 276.93, 297.44, 297.39, 296.55, 299.9, 303.74, 300.65, 293.21, 282.31, 290.18, 296.21, 281 ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print (len(city_list))
# Out:
# 722

# %%
weather_by_city_dict = {"City": city_list, "Country": country, "Latitude": lat, "Longtitude": lng, "Max Temp": temp, "Humidity": hum, "Cloudiness": cld, "Wind Speed": wind, "Date":dt}

weather_by_city_df = pd.DataFrame.from_dict(weather_by_city_dict, orient="index")
weather_by_city_df = weather_by_city_df.transpose()

weather_by_city_df
# Out:
#                 City Country Latitude Longtitude Max Temp Humidity Cloudiness  \
# 0             orange      US     33.7  -117.7675   292.92       84         90
# 1     ribeira grande      PT  38.5167      -28.7   296.37       68         20
# 2            mareeba      AU      -17   145.4333   293.55       90         25
# 3     port elizabeth      ZA  -33.918    25.5701   290.31       67         40
# 4    arraial do cabo      BR -22.9661   -42.0278   296.13      100         20
# ..               ...     ...      ...        ...      ...      ...        ...
# 717      svetlogorsk      UG   1.7146    33.6111   303.61       36         54
# 718         yinchuan      AU    -34.2     142.15   287.13       41          2
# 719           soroti      IN  21.3333      72.75   300.14       85         92
# 720          mildura    None     None       None     None     None       None
# 721            olpad    None     None       None     None     None       None
#
#     Wind Speed        Date
# 0         0.45  1631702774
# 1         2.06  1631702551
# 2         1.62  1631702777
# 3        10.29  1631702628
# 4         0.51  1631702599
# ..         ...         ...
# 717       1.63  1631703514
# 718       2.06  1631703515
# 719       6.86  1631703516
# 720       None        None
# 721       None        None
#
# [722 rows x 9 columns]

# %%
weather_by_city_df = weather_by_city_df.dropna()
weather_by_city_df
# Out:
#                 City Country Latitude Longtitude Max Temp Humidity Cloudiness  \
# 0             orange      US     33.7  -117.7675   292.92       84         90
# 1     ribeira grande      PT  38.5167      -28.7   296.37       68         20
# 2            mareeba      AU      -17   145.4333   293.55       90         25
# 3     port elizabeth      ZA  -33.918    25.5701   290.31       67         40
# 4    arraial do cabo      BR -22.9661   -42.0278   296.13      100         20
# ..               ...     ...      ...        ...      ...      ...        ...
# 715           laguna      BY  52.6333    29.7333   290.91       40         30
# 716           bamako      CN  38.4681   106.2731   290.74       66        100
# 717      svetlogorsk      UG   1.7146    33.6111   303.61       36         54
# 718         yinchuan      AU    -34.2     142.15   287.13       41          2
# 719           soroti      IN  21.3333      72.75   300.14       85         92
#
#     Wind Speed        Date
# 0         0.45  1631702774
# 1         2.06  1631702551
# 2         1.62  1631702777
# 3        10.29  1631702628
# 4         0.51  1631702599
# ..         ...         ...
# 715       3.43  1631703512
# 716       0.94  1631703513
# 717       1.63  1631703514
# 718       2.06  1631703515
# 719       6.86  1631703516
#
# [720 rows x 9 columns]

# %%
weather_by_city_df.to_csv("../output_data/weather_data.csv")

# %%
#statistics
weather_by_city_df["Wind Speed"] = weather_by_city_df["Wind Speed"].astype(float)
weather_by_city_df["Humidity"] = weather_by_city_df["Humidity"].astype(float)
weather_by_city_df["Cloudiness"] = weather_by_city_df["Cloudiness"].astype(float)


weather_by_city_df.describe()
# Out:
#          Humidity  Cloudiness  Wind Speed
# count  720.000000  720.000000  720.000000
# mean    68.375000   54.369444    3.339903
# std     23.651525   38.423121    2.301469
# min      3.000000    0.000000    0.000000
# 25%     55.000000   13.000000    1.620000
# 50%     75.000000   62.000000    2.835000
# 75%     86.000000   92.000000    4.652500
# max    100.000000  100.000000   14.110000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No cities in the dataframe have humidty over 100% - skipping this step.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Max Temp"]).astype(float),  alpha=.45, marker ="o", facecolor="gold", edgecolors="black", )

#format the scatter plot
plt.title(f"Latitude vs Max Temperature (F) as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)") 
print(f"The maximum temperatures can be found in cities nearer to the equator.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Temperature Plot.png")

plt.show()
# Out:
# The maximum temperatures can be found in cities nearer to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Humidity"]).astype(float),  alpha=.45, marker ="o", facecolor="limegreen", edgecolors="black", )

#format the scatter plot
plt.title(f"Latitude vs Humidity as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Humidity") 
print(f"Cities found nearer to the equator experience higher humidity.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Humidity Plot.png")

plt.show()
# Out:
# Cities found nearer to the equator experience higher humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Cloudiness"]).astype(float),  alpha=.45, marker ="o", facecolor="pink", edgecolors="purple", )

#format the scatter plot
plt.title(f"Latitude vs Cloudiness as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness") 
print(f"Cities found further away from the equator experienced higher cloudiness.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Cloudiness Plot.png")

plt.show()
# Out:
# Cities found further away from the equator experienced higher cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Wind Speed"]).astype(float),  alpha=.45, marker ="o", facecolor="indigo", edgecolors="yellow", )

#format the scatter plot
plt.title(f"Latitude vs Wind Speed (mph) as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)") 
print(f"Cities found further north from the equator experienced higher Wind Speeds.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Wind Speed Plot.png")

plt.show()
# Out:
# Cities found further north from the equator experienced higher Wind Speeds.

# %%
plt.savefig("Images/latitude vs wind speed.png")

# %% [markdown]
# ## Linear Regression

# %%
#creating dataframes to store Northern hemisphere cities and southern hemisphere cities

north_hem = weather_by_city_df.loc[pd.to_numeric(weather_by_city_df["Latitude"]).astype(float) > 0, :]
south_hem = weather_by_city_df.loc[pd.to_numeric(weather_by_city_df["Latitude"]).astype(float) < 0, :]

# %%
#defining the equation for regression analysis
def linear_regression(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Max Temp']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Max Temp vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value details a strong-negative correlation suggesting further north cities lie from the equater the colder it gets")

#regression plot
plt.scatter(x_axis,y_axis, color = "salmon")
plt.plot(x_axis,regress_values,"r-", color="navy")

#regression format
plt.annotate(regression,(10,270),fontsize=15,color="navy")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression y = -0.38x + 307.47
# R-squared: -0.7662448147190866, the regression details a strong correlation
# The regression and the R-value details a strong-negative correlation suggesting further north cities lie from the equater the colder it gets

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Max Temp']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Max Temp vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value details a strong-postive correlation suggesting further south cities lie from the equater the colder it gets")

#regression plot
plt.scatter(x_axis,y_axis, color = "dodgerblue")
plt.plot(x_axis,regress_values,"r-", color="dimgrey")

#regression format
plt.annotate(regression,(-30,275),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression y = 0.47x + 303.1
# R-squared: 0.7863377647638303, the regression details a strong correlation
# The regression and the R-value details a strong-postive correlation suggesting further south cities lie from the equater the colder it gets

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Humidity']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value details a weak correlation suggesting distance away from the equator doesn't have impact on humidity")

#regression plot
plt.scatter(x_axis,y_axis, color = "indigo")
plt.plot(x_axis,regress_values,"r-", color="gold")

#regression format
plt.annotate(regression,(55,10),fontsize=15,color="indigo")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression y = 0.06x + 65.33
# R-squared: 0.050333880564333716, the regression details a strong correlation
# The regression and the R-value details a weak correlation suggesting distance away from the equator doesn't have impact on humidity

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Humidity']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value shows no correlation between distance away from the equator and humidity in the Southern Hemisphere")

#regression plot
plt.scatter(x_axis,y_axis, color = "teal")
plt.plot(x_axis,regress_values,"r-", color="tomato")

#regression format
plt.annotate(regression,(-50,10),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression y = 0.0x + 69.99
# R-squared: 0.001375242563295776, the regression details a strong correlation
# The regression and the R-value shows no correlation between distance away from the equator and humidity in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Cloudiness']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression{regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value no correlation between distance north from the equator and cloudiness")

#regression plot
plt.scatter(x_axis,y_axis, color = "tan")
plt.plot(x_axis,regress_values,"r-", color="maroon")

#regression format
plt.annotate(regression,(20,20),fontsize=15,color="navy")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regressionn as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")

plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regressiony = 0.06x + 55.18
# R-squared: 0.03308589095446284, the regression details a strong correlation
# The regression and the R-value no correlation between distance north from the equator and cloudiness

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Cloudiness']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value shows no correlation between distance away from the equator and cloudiness in the Southern Hemisphere")

#regression plot
plt.scatter(x_axis,y_axis, color = "crimson")
plt.plot(x_axis,regress_values,"r-", color="olive")

#regression format
plt.annotate(regression,(-50,10),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression y = 0.22x + 51.25
# R-squared: 0.08623092095100991, the regression details a strong correlation
# The regression and the R-value shows no correlation between distance away from the equator and cloudiness in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Wind Speed']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression{regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value very little correlation between distance north from the equator and wind speed (mph)")

#regression plot
plt.scatter(x_axis,y_axis, color = "indianred")
plt.plot(x_axis,regress_values,"r-", color="darkviolet")

#regression format
plt.annotate(regression,(40,12),fontsize=15,color="navy")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("../Images/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regressiony = -0.0x + 3.15
# R-squared: -0.005744495253824902, the regression details a strong correlation
# The regression and the R-value very little correlation between distance north from the equator and wind speed (mph)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Wind Speed']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value shows weak correlation between distance away from the equator and Wind Speed in the Southern Hemisphere")

#regression plot
plt.scatter(x_axis,y_axis, color = "deeppink")
plt.plot(x_axis,regress_values,"r-", color="darkcyan")

#regression format
plt.annotate(regression,(-50,10),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.savefig("../Images/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression y = -0.03x + 3.31
# R-squared: -0.13897455032126038, the regression details a strong correlation
# The regression and the R-value shows weak correlation between distance away from the equator and Wind Speed in the Southern Hemisphere
