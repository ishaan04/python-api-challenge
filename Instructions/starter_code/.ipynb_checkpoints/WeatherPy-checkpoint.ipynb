# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
from scipy import stats
from scipy.stats import linregress

from citipy import citipy
from datetime import date
import scipy.stats as st


# Import API key
from api_keys import weather_api_key
from citipy import citipy

# %%
#create a list of lattitute and longitiutde and cities
lat_range = (-90,90)
lon_range = (-180,180)

cities = []
lat_lon = []
unique_cities = []

#import cities datafile 
cities_pd = pd.read_csv("../output_data/cities.csv")
cities_pd.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ## Generate Cities List

# %%
#lat and long combination 
lat = np.random.uniform(lat_range[0], lat_range[1],size = 2000)
lon = np.random.uniform(lon_range[0], lon_range[1],size = 2000)

#map the lat and lon
lat_lon = zip(lat,lon)

#find the nearest city for a given coordinate

for coordinates in lat_lon:
    location_data = citipy.nearest_city(coordinates[0], coordinates[1])
    city = location_data.city_name
    country_name = location_data.country_code
    
    #if the location is unique add the new city into the cities list 
    if city not in unique_cities:
        unique_cities.append(city)
        cities.append(city)

print(len(cities))
# Out:
# 737

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#URL
units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"
API_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url = url + "appid=" + weather_api_key + "&q="

# %%
#create lists to store the variable data 
lat = []
lng = []
temp = []
hum = []
cld = []
wind = []
dt =[]
city_list = []
country = []
no_data = []

# %%
requests.get(query_url+'chuy').json()["coord"]["lat"]
# Out:
# -33.6971

# %%
#use API to scan through the dataset and insert it into the df and print a summary
number = 0
group = 1

#limit the API search so it doesn't max out


#start API run
print ("Initiate API Data Retrieval")
print ("-------------------------------")

for place in cities:
    try:
        print (f"Processing the file {number} of Group {group} | {place}.")
            
        #place the response into variables first
        response = requests.get(query_url+place).json()
        
        city_list.append(place)
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        hum.append(response["main"]["humidity"])
        cld.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        dt.append(response["dt"])
        country.append(response["sys"]["country"])

        
    except:
        (f"Weather for the city is unavaliable, checking next city: {place}.")
        
        city_list.remove(place)    
            
    number = number + 1
    if number == 50:
        number= 0
        group = group + 1   
        
print ("-------------------------------")
print ("API Retrieval is complete")
# Out:
# Initiate API Data Retrieval
# -------------------------------
# Processing the file 0 of Group 1 | saleaula.
# Processing the file 1 of Group 1 | atuona.
# Processing the file 2 of Group 1 | charters towers.
# Processing the file 3 of Group 1 | lodwar.
# Processing the file 4 of Group 1 | severo-kurilsk.
# Processing the file 5 of Group 1 | arraial do cabo.
# Processing the file 6 of Group 1 | saint-pierre.
# Processing the file 7 of Group 1 | taolanaro.
# Processing the file 8 of Group 1 | meyungs.
# Processing the file 9 of Group 1 | yellowknife.
# Processing the file 10 of Group 1 | castro.
# Processing the file 11 of Group 1 | nikolskoye.
# Processing the file 12 of Group 1 | ribeira grande.
# Processing the file 13 of Group 1 | mitsamiouli.
# Processing the file 14 of Group 1 | sorong.
# Processing the file 15 of Group 1 | east london.
# Processing the file 16 of Group 1 | carnarvon.
# Processing the file 17 of Group 1 | tiksi.
# Processing the file 18 of Group 1 | charlestown.
# Processing the file 19 of Group 1 | torbay.
# Processing the file 20 of Group 1 | rikitea.
# Processing the file 21 of Group 1 | vaini.
# Processing the file 22 of Group 1 | puerto ayora.
# Processing the file 23 of Group 1 | tautira.
# Processing the file 24 of Group 1 | mataura.
# Processing the file 25 of Group 1 | illoqqortoormiut.
# Processing the file 26 of Group 1 | kutna hora.
# Processing the file 27 of Group 1 | grand gaube.
# Processing the file 28 of Group 1 | grand river south east.
# Processing the file 29 of Group 1 | pierre.
# Processing the file 30 of Group 1 | kuching.
# Processing the file 31 of Group 1 | busselton.
# Processing the file 32 of Group 1 | upernavik.
# Processing the file 33 of Group 1 | miri.
# Processing the file 34 of Group 1 | anqiu.
# Processing the file 35 of Group 1 | gorno-chuyskiy.
# Processing the file 36 of Group 1 | hilo.
# Processing the file 37 of Group 1 | agirish.
# Processing the file 38 of Group 1 | qaqortoq.
# Processing the file 39 of Group 1 | port elizabeth.
# Processing the file 40 of Group 1 | tevaitoa.
# Processing the file 41 of Group 1 | vardo.
# Processing the file 42 of Group 1 | tuktoyaktuk.
# Processing the file 43 of Group 1 | san jose de guanipa.
# Processing the file 44 of Group 1 | vila velha.
# Processing the file 45 of Group 1 | hami.
# Processing the file 46 of Group 1 | lebu.
# Processing the file 47 of Group 1 | punta arenas.
# Processing the file 48 of Group 1 | jamestown.
# Processing the file 49 of Group 1 | saldanha.
# Processing the file 0 of Group 2 | lujiang.
# Processing the file 1 of Group 2 | barrow.
# Processing the file 2 of Group 2 | doha.
# Processing the file 3 of Group 2 | colinas.
# Processing the file 4 of Group 2 | faanui.
# Processing the file 5 of Group 2 | ushuaia.
# Processing the file 6 of Group 2 | belushya guba.
# Processing the file 7 of Group 2 | mentok.
# Processing the file 8 of Group 2 | attawapiskat.
# Processing the file 9 of Group 2 | payo.
# Processing the file 10 of Group 2 | constitucion.
# Processing the file 11 of Group 2 | walvis bay.
# Processing the file 12 of Group 2 | barentsburg.
# Processing the file 13 of Group 2 | saskylakh.
# Processing the file 14 of Group 2 | carutapera.
# Processing the file 15 of Group 2 | provideniya.
# Processing the file 16 of Group 2 | bluff.
# Processing the file 17 of Group 2 | whitehorse.
# Processing the file 18 of Group 2 | hamilton.
# Processing the file 19 of Group 2 | quepos.
# Processing the file 20 of Group 2 | georgetown.
# Processing the file 21 of Group 2 | kapaa.
# Processing the file 22 of Group 2 | matucana.
# Processing the file 23 of Group 2 | albany.
# Processing the file 24 of Group 2 | hattiesburg.
# Processing the file 25 of Group 2 | saint-joseph.
# Processing the file 26 of Group 2 | cidreira.
# Processing the file 27 of Group 2 | townsville.
# Processing the file 28 of Group 2 | kupang.
# Processing the file 29 of Group 2 | bredasdorp.
# Processing the file 30 of Group 2 | tuatapere.
# Processing the file 31 of Group 2 | paamiut.
# Processing the file 32 of Group 2 | marsh harbour.
# Processing the file 33 of Group 2 | chuy.
# Processing the file 34 of Group 2 | booue.
# Processing the file 35 of Group 2 | cape town.
# Processing the file 36 of Group 2 | tombouctou.
# Processing the file 37 of Group 2 | gazanjyk.
# Processing the file 38 of Group 2 | cartagena del chaira.
# Processing the file 39 of Group 2 | butaritari.
# Processing the file 40 of Group 2 | port harcourt.
# Processing the file 41 of Group 2 | kavieng.
# Processing the file 42 of Group 2 | marsa matruh.
# Processing the file 43 of Group 2 | ahipara.
# Processing the file 44 of Group 2 | botou.
# Processing the file 45 of Group 2 | oga.
# Processing the file 46 of Group 2 | hermanus.
# Processing the file 47 of Group 2 | clyde river.
# Processing the file 48 of Group 2 | monywa.
# Processing the file 49 of Group 2 | cherskiy.
# Processing the file 0 of Group 3 | burns lake.
# Processing the file 1 of Group 3 | jacobina.
# Processing the file 2 of Group 3 | vanimo.
# Processing the file 3 of Group 3 | iracoubo.
# Processing the file 4 of Group 3 | amderma.
# Processing the file 5 of Group 3 | tiarei.
# Processing the file 6 of Group 3 | sulangan.
# Processing the file 7 of Group 3 | hobart.
# Processing the file 8 of Group 3 | avarua.
# Processing the file 9 of Group 3 | yulara.
# Processing the file 10 of Group 3 | srednekolymsk.
# Processing the file 11 of Group 3 | qaanaaq.
# Processing the file 12 of Group 3 | lagoa.
# Processing the file 13 of Group 3 | kaitangata.
# Processing the file 14 of Group 3 | togitsu.
# Processing the file 15 of Group 3 | salalah.
# Processing the file 16 of Group 3 | deputatskiy.
# Processing the file 17 of Group 3 | takoradi.
# Processing the file 18 of Group 3 | satitoa.
# Processing the file 19 of Group 3 | haines junction.
# Processing the file 20 of Group 3 | oranjestad.
# Processing the file 21 of Group 3 | caucaia.
# Processing the file 22 of Group 3 | port alfred.
# Processing the file 23 of Group 3 | richards bay.
# Processing the file 24 of Group 3 | tessalit.
# Processing the file 25 of Group 3 | alofi.
# Processing the file 26 of Group 3 | ternate.
# Processing the file 27 of Group 3 | adrar.
# Processing the file 28 of Group 3 | katsuura.
# Processing the file 29 of Group 3 | mango.
# Processing the file 30 of Group 3 | hithadhoo.
# Processing the file 31 of Group 3 | makakilo city.
# Processing the file 32 of Group 3 | thompson.
# Processing the file 33 of Group 3 | colac.
# Processing the file 34 of Group 3 | port lincoln.
# Processing the file 35 of Group 3 | mar del plata.
# Processing the file 36 of Group 3 | gold coast.
# Processing the file 37 of Group 3 | koshurnikovo.
# Processing the file 38 of Group 3 | cap malheureux.
# Processing the file 39 of Group 3 | vrangel.
# Processing the file 40 of Group 3 | nanortalik.
# Processing the file 41 of Group 3 | cayenne.
# Processing the file 42 of Group 3 | bam.
# Processing the file 43 of Group 3 | meulaboh.
# Processing the file 44 of Group 3 | athabasca.
# Processing the file 45 of Group 3 | camacha.
# Processing the file 46 of Group 3 | pevek.
# Processing the file 47 of Group 3 | sao filipe.
# Processing the file 48 of Group 3 | dingle.
# Processing the file 49 of Group 3 | zhuhai.
# Processing the file 0 of Group 4 | balkhash.
# Processing the file 1 of Group 4 | poya.
# Processing the file 2 of Group 4 | saint george.
# Processing the file 3 of Group 4 | yanam.
# Processing the file 4 of Group 4 | thunder bay.
# Processing the file 5 of Group 4 | omsukchan.
# Processing the file 6 of Group 4 | linxia.
# Processing the file 7 of Group 4 | victoria.
# Processing the file 8 of Group 4 | blacksburg.
# Processing the file 9 of Group 4 | sao joao da barra.
# Processing the file 10 of Group 4 | emet.
# Processing the file 11 of Group 4 | san patricio.
# Processing the file 12 of Group 4 | chokurdakh.
# Processing the file 13 of Group 4 | dikson.
# Processing the file 14 of Group 4 | ramos arizpe.
# Processing the file 15 of Group 4 | airai.
# Processing the file 16 of Group 4 | vaitupu.
# Processing the file 17 of Group 4 | ingraj bazar.
# Processing the file 18 of Group 4 | marsaxlokk.
# Processing the file 19 of Group 4 | jacqueville.
# Processing the file 20 of Group 4 | schramberg.
# Processing the file 21 of Group 4 | mataram.
# Processing the file 22 of Group 4 | tsihombe.
# Processing the file 23 of Group 4 | isangel.
# Processing the file 24 of Group 4 | pisco.
# Processing the file 25 of Group 4 | mys shmidta.
# Processing the file 26 of Group 4 | soloneshnoye.
# Processing the file 27 of Group 4 | new norfolk.
# Processing the file 28 of Group 4 | port hardy.
# Processing the file 29 of Group 4 | turbat.
# Processing the file 30 of Group 4 | correntina.
# Processing the file 31 of Group 4 | itarema.
# Processing the file 32 of Group 4 | canico.
# Processing the file 33 of Group 4 | samalaeulu.
# Processing the file 34 of Group 4 | zhangzhou.
# Processing the file 35 of Group 4 | rungata.
# Processing the file 36 of Group 4 | ust-kut.
# Processing the file 37 of Group 4 | hobyo.
# Processing the file 38 of Group 4 | novyy urengoy.
# Processing the file 39 of Group 4 | marcona.
# Processing the file 40 of Group 4 | havre-saint-pierre.
# Processing the file 41 of Group 4 | hailey.
# Processing the file 42 of Group 4 | tezu.
# Processing the file 43 of Group 4 | plouzane.
# Processing the file 44 of Group 4 | coquimbo.
# Processing the file 45 of Group 4 | vasto.
# Processing the file 46 of Group 4 | inzer.
# Processing the file 47 of Group 4 | bambous virieux.
# Processing the file 48 of Group 4 | yatou.
# Processing the file 49 of Group 4 | sur.
# Processing the file 0 of Group 5 | saint combs.
# Processing the file 1 of Group 5 | bilibino.
# Processing the file 2 of Group 5 | okahandja.
# Processing the file 3 of Group 5 | portland.
# Processing the file 4 of Group 5 | broken hill.
# Processing the file 5 of Group 5 | porto torres.
# Processing the file 6 of Group 5 | rundu.
# Processing the file 7 of Group 5 | lata.
# Processing the file 8 of Group 5 | alghero.
# Processing the file 9 of Group 5 | tinjah.
# Processing the file 10 of Group 5 | nueva guinea.
# Processing the file 11 of Group 5 | khatanga.
# Processing the file 12 of Group 5 | yar-sale.
# Processing the file 13 of Group 5 | klaksvik.
# Processing the file 14 of Group 5 | tsabong.
# Processing the file 15 of Group 5 | galiwinku.
# Processing the file 16 of Group 5 | bathsheba.
# Processing the file 17 of Group 5 | aleksandrov gay.
# Processing the file 18 of Group 5 | saint-philippe.
# Processing the file 19 of Group 5 | axim.
# Processing the file 20 of Group 5 | bethel.
# Processing the file 21 of Group 5 | naze.
# Processing the file 22 of Group 5 | ahuimanu.
# Processing the file 23 of Group 5 | redmond.
# Processing the file 24 of Group 5 | kuryk.
# Processing the file 25 of Group 5 | mergui.
# Processing the file 26 of Group 5 | pyay.
# Processing the file 27 of Group 5 | hasaki.
# Processing the file 28 of Group 5 | sentyabrskiy.
# Processing the file 29 of Group 5 | kamwenge.
# Processing the file 30 of Group 5 | moose factory.
# Processing the file 31 of Group 5 | valparaiso.
# Processing the file 32 of Group 5 | esperance.
# Processing the file 33 of Group 5 | ixtapa.
# Processing the file 34 of Group 5 | tahe.
# Processing the file 35 of Group 5 | george.
# Processing the file 36 of Group 5 | san quintin.
# Processing the file 37 of Group 5 | luderitz.
# Processing the file 38 of Group 5 | ponta do sol.
# Processing the file 39 of Group 5 | brae.
# Processing the file 40 of Group 5 | oranjemund.
# Processing the file 41 of Group 5 | karaul.
# Processing the file 42 of Group 5 | sataua.
# Processing the file 43 of Group 5 | kushmurun.
# Processing the file 44 of Group 5 | nishihara.
# Processing the file 45 of Group 5 | suarez.
# Processing the file 46 of Group 5 | kyzyl.
# Processing the file 47 of Group 5 | tumannyy.
# Processing the file 48 of Group 5 | hay river.
# Processing the file 49 of Group 5 | benha.
# Processing the file 0 of Group 6 | lompoc.
# Processing the file 1 of Group 6 | bengkulu.
# Processing the file 2 of Group 6 | quang ngai.
# Processing the file 3 of Group 6 | korla.
# Processing the file 4 of Group 6 | bahia blanca.
# Processing the file 5 of Group 6 | fare.
# Processing the file 6 of Group 6 | nizhneyansk.
# Processing the file 7 of Group 6 | fairbanks.
# Processing the file 8 of Group 6 | addis zemen.
# Processing the file 9 of Group 6 | fort nelson.
# Processing the file 10 of Group 6 | palabuhanratu.
# Processing the file 11 of Group 6 | santa rosa.
# Processing the file 12 of Group 6 | mahajanga.
# Processing the file 13 of Group 6 | honningsvag.
# Processing the file 14 of Group 6 | ancud.
# Processing the file 15 of Group 6 | camopi.
# Processing the file 16 of Group 6 | kargil.
# Processing the file 17 of Group 6 | tyup.
# Processing the file 18 of Group 6 | mahebourg.
# Processing the file 19 of Group 6 | sao luis.
# Processing the file 20 of Group 6 | ninotsminda.
# Processing the file 21 of Group 6 | kalabo.
# Processing the file 22 of Group 6 | narsaq.
# Processing the file 23 of Group 6 | cabo san lucas.
# Processing the file 24 of Group 6 | maumere.
# Processing the file 25 of Group 6 | rakai.
# Processing the file 26 of Group 6 | pacocha.
# Processing the file 27 of Group 6 | denpasar.
# Processing the file 28 of Group 6 | noumea.
# Processing the file 29 of Group 6 | kamsack.
# Processing the file 30 of Group 6 | boundiali.
# Processing the file 31 of Group 6 | heihe.
# Processing the file 32 of Group 6 | kubuta.
# Processing the file 33 of Group 6 | beloha.
# Processing the file 34 of Group 6 | alappuzha.
# Processing the file 35 of Group 6 | menongue.
# Processing the file 36 of Group 6 | awbari.
# Processing the file 37 of Group 6 | svetlogorsk.
# Processing the file 38 of Group 6 | san matias.
# Processing the file 39 of Group 6 | eldorado.
# Processing the file 40 of Group 6 | kununurra.
# Processing the file 41 of Group 6 | eseka.
# Processing the file 42 of Group 6 | balabac.
# Processing the file 43 of Group 6 | alamos.
# Processing the file 44 of Group 6 | sabancuy.
# Processing the file 45 of Group 6 | byron bay.
# Processing the file 46 of Group 6 | barra patuca.
# Processing the file 47 of Group 6 | omboue.
# Processing the file 48 of Group 6 | puerto quijarro.
# Processing the file 49 of Group 6 | bandarbeyla.
# Processing the file 0 of Group 7 | chegdomyn.
# Processing the file 1 of Group 7 | hovd.
# Processing the file 2 of Group 7 | vao.
# Processing the file 3 of Group 7 | zaozerne.
# Processing the file 4 of Group 7 | lorengau.
# Processing the file 5 of Group 7 | kurduvadi.
# Processing the file 6 of Group 7 | eureka.
# Processing the file 7 of Group 7 | tchollire.
# Processing the file 8 of Group 7 | angoche.
# Processing the file 9 of Group 7 | wanaka.
# Processing the file 10 of Group 7 | shimoda.
# Processing the file 11 of Group 7 | nata.
# Processing the file 12 of Group 7 | tasiilaq.
# Processing the file 13 of Group 7 | longyearbyen.
# Processing the file 14 of Group 7 | innisfail.
# Processing the file 15 of Group 7 | sitka.
# Processing the file 16 of Group 7 | kruisfontein.
# Processing the file 17 of Group 7 | tilichiki.
# Processing the file 18 of Group 7 | hernani.
# Processing the file 19 of Group 7 | vicuna.
# Processing the file 20 of Group 7 | saint-raphael.
# Processing the file 21 of Group 7 | bajo baudo.
# Processing the file 22 of Group 7 | kazalinsk.
# Processing the file 23 of Group 7 | awjilah.
# Processing the file 24 of Group 7 | coahuayana.
# Processing the file 25 of Group 7 | karatau.
# Processing the file 26 of Group 7 | burgos.
# Processing the file 27 of Group 7 | port macquarie.
# Processing the file 28 of Group 7 | sug-aksy.
# Processing the file 29 of Group 7 | kirakira.
# Processing the file 30 of Group 7 | sokoni.
# Processing the file 31 of Group 7 | antalaha.
# Processing the file 32 of Group 7 | jalu.
# Processing the file 33 of Group 7 | santa cruz de la palma.
# Processing the file 34 of Group 7 | mizdah.
# Processing the file 35 of Group 7 | kenai.
# Processing the file 36 of Group 7 | lulea.
# Processing the file 37 of Group 7 | brand-erbisdorf.
# Processing the file 38 of Group 7 | waingapu.
# Processing the file 39 of Group 7 | neiafu.
# Processing the file 40 of Group 7 | razgrad.
# Processing the file 41 of Group 7 | fortuna.
# Processing the file 42 of Group 7 | iqaluit.
# Processing the file 43 of Group 7 | benjamin constant.
# Processing the file 44 of Group 7 | acajutla.
# Processing the file 45 of Group 7 | pronsk.
# Processing the file 46 of Group 7 | bacuit.
# Processing the file 47 of Group 7 | dustlik.
# Processing the file 48 of Group 7 | zhaozhou.
# Processing the file 49 of Group 7 | conde.
# Processing the file 0 of Group 8 | jerantut.
# Processing the file 1 of Group 8 | namibe.
# Processing the file 2 of Group 8 | mocuba.
# Processing the file 3 of Group 8 | churapcha.
# Processing the file 4 of Group 8 | kodiak.
# Processing the file 5 of Group 8 | herat.
# Processing the file 6 of Group 8 | vila franca do campo.
# Processing the file 7 of Group 8 | itoman.
# Processing the file 8 of Group 8 | batemans bay.
# Processing the file 9 of Group 8 | valdivia.
# Processing the file 10 of Group 8 | mae ramat.
# Processing the file 11 of Group 8 | half moon bay.
# Processing the file 12 of Group 8 | bargal.
# Processing the file 13 of Group 8 | roma.
# Processing the file 14 of Group 8 | guerrero negro.
# Processing the file 15 of Group 8 | nguiu.
# Processing the file 16 of Group 8 | nemuro.
# Processing the file 17 of Group 8 | dubbo.
# Processing the file 18 of Group 8 | serenje.
# Processing the file 19 of Group 8 | malwan.
# Processing the file 20 of Group 8 | toliary.
# Processing the file 21 of Group 8 | abnub.
# Processing the file 22 of Group 8 | donghai.
# Processing the file 23 of Group 8 | goma.
# Processing the file 24 of Group 8 | muros.
# Processing the file 25 of Group 8 | lanzhou.
# Processing the file 26 of Group 8 | avera.
# Processing the file 27 of Group 8 | san julian.
# Processing the file 28 of Group 8 | muswellbrook.
# Processing the file 29 of Group 8 | fairview.
# Processing the file 30 of Group 8 | geraldton.
# Processing the file 31 of Group 8 | margate.
# Processing the file 32 of Group 8 | abha.
# Processing the file 33 of Group 8 | tarko-sale.
# Processing the file 34 of Group 8 | zhigansk.
# Processing the file 35 of Group 8 | ngukurr.
# Processing the file 36 of Group 8 | puerto maldonado.
# Processing the file 37 of Group 8 | manzhouli.
# Processing the file 38 of Group 8 | cabedelo.
# Processing the file 39 of Group 8 | njeru.
# Processing the file 40 of Group 8 | umzimvubu.
# Processing the file 41 of Group 8 | namatanai.
# Processing the file 42 of Group 8 | pacific grove.
# Processing the file 43 of Group 8 | pimentel.
# Processing the file 44 of Group 8 | majene.
# Processing the file 45 of Group 8 | nome.
# Processing the file 46 of Group 8 | olinda.
# Processing the file 47 of Group 8 | grindavik.
# Processing the file 48 of Group 8 | darhan.
# Processing the file 49 of Group 8 | abalak.
# Processing the file 0 of Group 9 | tarudant.
# Processing the file 1 of Group 9 | samarai.
# Processing the file 2 of Group 9 | phrai bung.
# Processing the file 3 of Group 9 | hambantota.
# Processing the file 4 of Group 9 | yabrud.
# Processing the file 5 of Group 9 | norman wells.
# Processing the file 6 of Group 9 | alice springs.
# Processing the file 7 of Group 9 | sola.
# Processing the file 8 of Group 9 | changzhou.
# Processing the file 9 of Group 9 | higuey.
# Processing the file 10 of Group 9 | sao gabriel da cachoeira.
# Processing the file 11 of Group 9 | medicine hat.
# Processing the file 12 of Group 9 | jaguarao.
# Processing the file 13 of Group 9 | kouroussa.
# Processing the file 14 of Group 9 | misratah.
# Processing the file 15 of Group 9 | sosua.
# Processing the file 16 of Group 9 | hammerfest.
# Processing the file 17 of Group 9 | kahului.
# Processing the file 18 of Group 9 | maragogi.
# Processing the file 19 of Group 9 | semnan.
# Processing the file 20 of Group 9 | san angelo.
# Processing the file 21 of Group 9 | porto novo.
# Processing the file 22 of Group 9 | komsomolskiy.
# Processing the file 23 of Group 9 | samana.
# Processing the file 24 of Group 9 | goderich.
# Processing the file 25 of Group 9 | rio grande.
# Processing the file 26 of Group 9 | hofn.
# Processing the file 27 of Group 9 | palu.
# Processing the file 28 of Group 9 | christchurch.
# Processing the file 29 of Group 9 | trelew.
# Processing the file 30 of Group 9 | kalyazin.
# Processing the file 31 of Group 9 | cancun.
# Processing the file 32 of Group 9 | samoded.
# Processing the file 33 of Group 9 | skalistyy.
# Processing the file 34 of Group 9 | touros.
# Processing the file 35 of Group 9 | sidi ali.
# Processing the file 36 of Group 9 | hihifo.
# Processing the file 37 of Group 9 | saryg-sep.
# Processing the file 38 of Group 9 | altamira.
# Processing the file 39 of Group 9 | pontianak.
# Processing the file 40 of Group 9 | murgab.
# Processing the file 41 of Group 9 | plesetsk.
# Processing the file 42 of Group 9 | pendleton.
# Processing the file 43 of Group 9 | toila.
# Processing the file 44 of Group 9 | ijaki.
# Processing the file 45 of Group 9 | yeppoon.
# Processing the file 46 of Group 9 | prince rupert.
# Processing the file 47 of Group 9 | khasan.
# Processing the file 48 of Group 9 | souillac.
# Processing the file 49 of Group 9 | ushtobe.
# Processing the file 0 of Group 10 | yumen.
# Processing the file 1 of Group 10 | lasa.
# Processing the file 2 of Group 10 | necochea.
# Processing the file 3 of Group 10 | soe.
# Processing the file 4 of Group 10 | nakasongola.
# Processing the file 5 of Group 10 | dolbeau.
# Processing the file 6 of Group 10 | whitianga.
# Processing the file 7 of Group 10 | burica.
# Processing the file 8 of Group 10 | frankfort.
# Processing the file 9 of Group 10 | ketchikan.
# Processing the file 10 of Group 10 | cockburn town.
# Processing the file 11 of Group 10 | codrington.
# Processing the file 12 of Group 10 | yokadouma.
# Processing the file 13 of Group 10 | xapuri.
# Processing the file 14 of Group 10 | tambovka.
# Processing the file 15 of Group 10 | hyeres.
# Processing the file 16 of Group 10 | ailigandi.
# Processing the file 17 of Group 10 | xuddur.
# Processing the file 18 of Group 10 | bose.
# Processing the file 19 of Group 10 | porbandar.
# Processing the file 20 of Group 10 | santiago del estero.
# Processing the file 21 of Group 10 | pavelets.
# Processing the file 22 of Group 10 | bhag.
# Processing the file 23 of Group 10 | pinega.
# Processing the file 24 of Group 10 | kosonsoy.
# Processing the file 25 of Group 10 | vieques.
# Processing the file 26 of Group 10 | verkhnyaya salda.
# Processing the file 27 of Group 10 | lavrentiya.
# Processing the file 28 of Group 10 | rawson.
# Processing the file 29 of Group 10 | zhangjiakou.
# Processing the file 30 of Group 10 | marquette.
# Processing the file 31 of Group 10 | sovetskoye.
# Processing the file 32 of Group 10 | turtas.
# Processing the file 33 of Group 10 | tromso.
# Processing the file 34 of Group 10 | kavaratti.
# Processing the file 35 of Group 10 | rio gallegos.
# Processing the file 36 of Group 10 | dharmadam.
# Processing the file 37 of Group 10 | bilma.
# Processing the file 38 of Group 10 | sorland.
# Processing the file 39 of Group 10 | at-bashi.
# Processing the file 40 of Group 10 | kidal.
# Processing the file 41 of Group 10 | north vernon.
# Processing the file 42 of Group 10 | bastia.
# Processing the file 43 of Group 10 | gua musang.
# Processing the file 44 of Group 10 | ljig.
# Processing the file 45 of Group 10 | thinadhoo.
# Processing the file 46 of Group 10 | gat.
# Processing the file 47 of Group 10 | bayanday.
# Processing the file 48 of Group 10 | nizhniy ingash.
# Processing the file 49 of Group 10 | huicungo.
# Processing the file 0 of Group 11 | tura.
# Processing the file 1 of Group 11 | baykit.
# Processing the file 2 of Group 11 | ust-maya.
# Processing the file 3 of Group 11 | ostrovnoy.
# Processing the file 4 of Group 11 | kommunarka.
# Processing the file 5 of Group 11 | yaan.
# Processing the file 6 of Group 11 | san carlos de bariloche.
# Processing the file 7 of Group 11 | dalvik.
# Processing the file 8 of Group 11 | magistralnyy.
# Processing the file 9 of Group 11 | kanigoro.
# Processing the file 10 of Group 11 | novopokrovka.
# Processing the file 11 of Group 11 | te anau.
# Processing the file 12 of Group 11 | hereford.
# Processing the file 13 of Group 11 | xining.
# Processing the file 14 of Group 11 | warrnambool.
# Processing the file 15 of Group 11 | mbandaka.
# Processing the file 16 of Group 11 | paradwip.
# Processing the file 17 of Group 11 | ewo.
# Processing the file 18 of Group 11 | celestun.
# Processing the file 19 of Group 11 | berlevag.
# Processing the file 20 of Group 11 | vestmannaeyjar.
# Processing the file 21 of Group 11 | pangkalanbuun.
# Processing the file 22 of Group 11 | cefalu.
# Processing the file 23 of Group 11 | kostomuksha.
# Processing the file 24 of Group 11 | numi.
# Processing the file 25 of Group 11 | nizhnyaya tavda.
# Processing the file 26 of Group 11 | nianzishan.
# Processing the file 27 of Group 11 | warqla.
# Processing the file 28 of Group 11 | guozhen.
# Processing the file 29 of Group 11 | nongstoin.
# Processing the file 30 of Group 11 | kalat.
# Processing the file 31 of Group 11 | bonthe.
# Processing the file 32 of Group 11 | lipnita.
# Processing the file 33 of Group 11 | port augusta.
# Processing the file 34 of Group 11 | baisha.
# Processing the file 35 of Group 11 | halifax.
# Processing the file 36 of Group 11 | sehithwa.
# Processing the file 37 of Group 11 | cruz do espirito santo.
# Processing the file 38 of Group 11 | andevoranto.
# Processing the file 39 of Group 11 | lagos.
# Processing the file 40 of Group 11 | komsomolets.
# Processing the file 41 of Group 11 | bauchi.
# Processing the file 42 of Group 11 | ibra.
# Processing the file 43 of Group 11 | tual.
# Processing the file 44 of Group 11 | tabory.
# Processing the file 45 of Group 11 | salinopolis.
# Processing the file 46 of Group 11 | banyuwangi.
# Processing the file 47 of Group 11 | nanga eboko.
# Processing the file 48 of Group 11 | bubaque.
# Processing the file 49 of Group 11 | saryshagan.
# Processing the file 0 of Group 12 | igarka.
# Processing the file 1 of Group 12 | honiara.
# Processing the file 2 of Group 12 | ucluelet.
# Processing the file 3 of Group 12 | porto velho.
# Processing the file 4 of Group 12 | langsa.
# Processing the file 5 of Group 12 | husavik.
# Processing the file 6 of Group 12 | road town.
# Processing the file 7 of Group 12 | saint anthony.
# Processing the file 8 of Group 12 | petropavlovka.
# Processing the file 9 of Group 12 | cochabamba.
# Processing the file 10 of Group 12 | mount gambier.
# Processing the file 11 of Group 12 | filadelfia.
# Processing the file 12 of Group 12 | muzhi.
# Processing the file 13 of Group 12 | storforshei.
# Processing the file 14 of Group 12 | caravelas.
# Processing the file 15 of Group 12 | kushiro.
# Processing the file 16 of Group 12 | caete.
# Processing the file 17 of Group 12 | san policarpo.
# Processing the file 18 of Group 12 | middelburg.
# Processing the file 19 of Group 12 | tidore.
# Processing the file 20 of Group 12 | paragominas.
# Processing the file 21 of Group 12 | khomeynishahr.
# Processing the file 22 of Group 12 | hyvinkaa.
# Processing the file 23 of Group 12 | tarazona.
# Processing the file 24 of Group 12 | talnakh.
# Processing the file 25 of Group 12 | poronaysk.
# Processing the file 26 of Group 12 | nelson bay.
# Processing the file 27 of Group 12 | tunghsiao.
# Processing the file 28 of Group 12 | aklavik.
# Processing the file 29 of Group 12 | kashi.
# Processing the file 30 of Group 12 | saint-augustin.
# Processing the file 31 of Group 12 | trairi.
# Processing the file 32 of Group 12 | henties bay.
# Processing the file 33 of Group 12 | kampong thum.
# Processing the file 34 of Group 12 | leningradskiy.
# Processing the file 35 of Group 12 | olustvere.
# Processing the file 36 of Group 12 | ransang.
# Processing the file 37 of Group 12 | mednogorsk.
# Processing the file 38 of Group 12 | bykivka.
# Processing the file 39 of Group 12 | ambon.
# Processing the file 40 of Group 12 | zhumadian.
# Processing the file 41 of Group 12 | nichinan.
# Processing the file 42 of Group 12 | ban phai.
# Processing the file 43 of Group 12 | senanga.
# Processing the file 44 of Group 12 | linjiang.
# Processing the file 45 of Group 12 | progreso.
# Processing the file 46 of Group 12 | thai binh.
# Processing the file 47 of Group 12 | powell river.
# Processing the file 48 of Group 12 | ust-kamchatsk.
# Processing the file 49 of Group 12 | karratha.
# Processing the file 0 of Group 13 | boralday.
# Processing the file 1 of Group 13 | tongliao.
# Processing the file 2 of Group 13 | kachikau.
# Processing the file 3 of Group 13 | ambanja.
# Processing the file 4 of Group 13 | carbonear.
# Processing the file 5 of Group 13 | bairiki.
# Processing the file 6 of Group 13 | ormara.
# Processing the file 7 of Group 13 | calama.
# Processing the file 8 of Group 13 | anshun.
# Processing the file 9 of Group 13 | bundaberg.
# Processing the file 10 of Group 13 | rincon.
# Processing the file 11 of Group 13 | banff.
# Processing the file 12 of Group 13 | gotsu.
# Processing the file 13 of Group 13 | aranda de duero.
# Processing the file 14 of Group 13 | huarmey.
# Processing the file 15 of Group 13 | kita.
# Processing the file 16 of Group 13 | vermillion.
# Processing the file 17 of Group 13 | opuwo.
# Processing the file 18 of Group 13 | gladstone.
# Processing the file 19 of Group 13 | alekseyevsk.
# Processing the file 20 of Group 13 | mnogovershinnyy.
# Processing the file 21 of Group 13 | mainit.
# Processing the file 22 of Group 13 | lagdo.
# Processing the file 23 of Group 13 | metro.
# Processing the file 24 of Group 13 | mrirt.
# Processing the file 25 of Group 13 | sonoita.
# Processing the file 26 of Group 13 | sechura.
# Processing the file 27 of Group 13 | bo.
# Processing the file 28 of Group 13 | mehamn.
# Processing the file 29 of Group 13 | barawe.
# Processing the file 30 of Group 13 | changji.
# Processing the file 31 of Group 13 | mugur-aksy.
# Processing the file 32 of Group 13 | kovur.
# Processing the file 33 of Group 13 | perth.
# Processing the file 34 of Group 13 | disna.
# Processing the file 35 of Group 13 | coos bay.
# Processing the file 36 of Group 13 | conil.
# Processing the file 37 of Group 13 | erzurum.
# Processing the file 38 of Group 13 | lufilufi.
# Processing the file 39 of Group 13 | marawi.
# Processing the file 40 of Group 13 | lumphat.
# Processing the file 41 of Group 13 | rexburg.
# Processing the file 42 of Group 13 | ternitz.
# Processing the file 43 of Group 13 | chernyshevskiy.
# Processing the file 44 of Group 13 | la ronge.
# Processing the file 45 of Group 13 | san cristobal.
# Processing the file 46 of Group 13 | gandajika.
# Processing the file 47 of Group 13 | scottsbluff.
# Processing the file 48 of Group 13 | saint-louis.
# Processing the file 49 of Group 13 | hualmay.
# Processing the file 0 of Group 14 | talcahuano.
# Processing the file 1 of Group 14 | kencong.
# Processing the file 2 of Group 14 | asau.
# Processing the file 3 of Group 14 | belaya gora.
# Processing the file 4 of Group 14 | maimon.
# Processing the file 5 of Group 14 | novobiryusinskiy.
# Processing the file 6 of Group 14 | ngunguru.
# Processing the file 7 of Group 14 | murray bridge.
# Processing the file 8 of Group 14 | rotifunk.
# Processing the file 9 of Group 14 | matara.
# Processing the file 10 of Group 14 | ruatoria.
# Processing the file 11 of Group 14 | kamenskoye.
# Processing the file 12 of Group 14 | karaton.
# Processing the file 13 of Group 14 | puerto cabezas.
# Processing the file 14 of Group 14 | letka.
# Processing the file 15 of Group 14 | vilyuysk.
# Processing the file 16 of Group 14 | mosetse.
# Processing the file 17 of Group 14 | acqui terme.
# Processing the file 18 of Group 14 | sambava.
# Processing the file 19 of Group 14 | pa sang.
# Processing the file 20 of Group 14 | tecpan.
# Processing the file 21 of Group 14 | gondanglegi.
# Processing the file 22 of Group 14 | orcopampa.
# Processing the file 23 of Group 14 | marabba.
# Processing the file 24 of Group 14 | vanavara.
# Processing the file 25 of Group 14 | marfino.
# Processing the file 26 of Group 14 | maningrida.
# Processing the file 27 of Group 14 | ilulissat.
# Processing the file 28 of Group 14 | kytlym.
# Processing the file 29 of Group 14 | dalhousie.
# Processing the file 30 of Group 14 | luba.
# Processing the file 31 of Group 14 | kalmunai.
# Processing the file 32 of Group 14 | bolungarvik.
# Processing the file 33 of Group 14 | soverato.
# Processing the file 34 of Group 14 | chifeng.
# Processing the file 35 of Group 14 | tucumcari.
# Processing the file 36 of Group 14 | watertown.
# Processing the file 37 of Group 14 | rabo de peixe.
# Processing the file 38 of Group 14 | freetown.
# Processing the file 39 of Group 14 | houma.
# Processing the file 40 of Group 14 | tabou.
# Processing the file 41 of Group 14 | verkhnevilyuysk.
# Processing the file 42 of Group 14 | the pas.
# Processing the file 43 of Group 14 | issaquah.
# Processing the file 44 of Group 14 | santa cruz.
# Processing the file 45 of Group 14 | mount darwin.
# Processing the file 46 of Group 14 | eisenberg.
# Processing the file 47 of Group 14 | ballina.
# Processing the file 48 of Group 14 | forestville.
# Processing the file 49 of Group 14 | oda.
# Processing the file 0 of Group 15 | na wa.
# Processing the file 1 of Group 15 | gritsovskiy.
# Processing the file 2 of Group 15 | saint-francois.
# Processing the file 3 of Group 15 | wulanhaote.
# Processing the file 4 of Group 15 | prado.
# Processing the file 5 of Group 15 | maltahohe.
# Processing the file 6 of Group 15 | tottori.
# Processing the file 7 of Group 15 | chabahar.
# Processing the file 8 of Group 15 | meiganga.
# Processing the file 9 of Group 15 | la trinidad.
# Processing the file 10 of Group 15 | umm kaddadah.
# Processing the file 11 of Group 15 | kargasok.
# Processing the file 12 of Group 15 | wanning.
# Processing the file 13 of Group 15 | lagunas.
# Processing the file 14 of Group 15 | roanoke rapids.
# Processing the file 15 of Group 15 | ashland.
# Processing the file 16 of Group 15 | yerbogachen.
# Processing the file 17 of Group 15 | dakar.
# Processing the file 18 of Group 15 | stockelsdorf.
# Processing the file 19 of Group 15 | baoning.
# Processing the file 20 of Group 15 | pangnirtung.
# Processing the file 21 of Group 15 | bartica.
# Processing the file 22 of Group 15 | caetite.
# Processing the file 23 of Group 15 | octeville.
# Processing the file 24 of Group 15 | silca.
# Processing the file 25 of Group 15 | chiredzi.
# Processing the file 26 of Group 15 | broome.
# Processing the file 27 of Group 15 | moranbah.
# Processing the file 28 of Group 15 | faya.
# Processing the file 29 of Group 15 | labuan.
# Processing the file 30 of Group 15 | labutta.
# Processing the file 31 of Group 15 | praya.
# Processing the file 32 of Group 15 | nyimba.
# Processing the file 33 of Group 15 | viedma.
# Processing the file 34 of Group 15 | olafsvik.
# Processing the file 35 of Group 15 | muroto.
# Processing the file 36 of Group 15 | marzuq.
# -------------------------------
# API Retrieval is complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print (len(city_list))
# Out:
# 669

# %%
weather_by_city_dict = {"City": city_list, "Country": country, "Latitude": lat, "Longtitude": lng, "Max Temp": temp, "Humidity": hum, "Cloudiness": cld, "Wind Speed": wind, "Date":dt}

weather_by_city_df = pd.DataFrame.from_dict(weather_by_city_dict, orient="index")
weather_by_city_df = weather_by_city_df.transpose()

weather_by_city_df
# Out:
#                 City Country Latitude Longtitude Max Temp Humidity Cloudiness  \
# 0             atuona      PF     -9.8  -139.0333   298.49       75         60
# 1    charters towers      AU    -20.1   146.2667   288.68       70          4
# 2             lodwar      KE   3.1191    35.5973   307.89       27         99
# 3     severo-kurilsk      RU  50.6789    156.125   282.28       89         13
# 4    arraial do cabo      BR -22.9661   -42.0278   300.13       73          0
# ..               ...     ...      ...        ...      ...      ...        ...
# 664           nyimba      ZM -14.5566    30.8149   308.42       12         95
# 665           viedma      AR -40.8135   -62.9967   291.61       24          5
# 666         olafsvik      IS  64.8945   -23.7142   281.99       65         45
# 667           muroto      JP  33.2833     134.15    297.5       75         78
# 668           marzuq      YE     14.4    46.4667   301.94       46        100
#
#     Wind Speed        Date
# 0        11.45  1631716278
# 1         3.55  1631716279
# 2         4.17  1631716151
# 3         3.64  1631716280
# 4          3.6  1631716282
# ..         ...         ...
# 664       3.17  1631717001
# 665       6.12  1631717003
# 666       2.52  1631717004
# 667       7.44  1631717006
# 668       7.88  1631717006
#
# [669 rows x 9 columns]

# %%
weather_by_city_df = weather_by_city_df.dropna()
weather_by_city_df
# Out:
#                 City Country Latitude Longtitude Max Temp Humidity Cloudiness  \
# 0             atuona      PF     -9.8  -139.0333   298.49       75         60
# 1    charters towers      AU    -20.1   146.2667   288.68       70          4
# 2             lodwar      KE   3.1191    35.5973   307.89       27         99
# 3     severo-kurilsk      RU  50.6789    156.125   282.28       89         13
# 4    arraial do cabo      BR -22.9661   -42.0278   300.13       73          0
# ..               ...     ...      ...        ...      ...      ...        ...
# 664           nyimba      ZM -14.5566    30.8149   308.42       12         95
# 665           viedma      AR -40.8135   -62.9967   291.61       24          5
# 666         olafsvik      IS  64.8945   -23.7142   281.99       65         45
# 667           muroto      JP  33.2833     134.15    297.5       75         78
# 668           marzuq      YE     14.4    46.4667   301.94       46        100
#
#     Wind Speed        Date
# 0        11.45  1631716278
# 1         3.55  1631716279
# 2         4.17  1631716151
# 3         3.64  1631716280
# 4          3.6  1631716282
# ..         ...         ...
# 664       3.17  1631717001
# 665       6.12  1631717003
# 666       2.52  1631717004
# 667       7.44  1631717006
# 668       7.88  1631717006
#
# [669 rows x 9 columns]

# %%
weather_by_city_df.to_csv("../output_data/weather_data.csv")

# %%
#statistics
weather_by_city_df["Wind Speed"] = weather_by_city_df["Wind Speed"].astype(float)
weather_by_city_df["Humidity"] = weather_by_city_df["Humidity"].astype(float)
weather_by_city_df["Cloudiness"] = weather_by_city_df["Cloudiness"].astype(float)


weather_by_city_df.describe()
# Out:
#          Humidity  Cloudiness  Wind Speed
# count  669.000000  669.000000  669.000000
# mean    69.321375   55.230194    3.480822
# std     23.211405   39.815302    2.547295
# min      5.000000    0.000000    0.000000
# 25%     59.000000   10.000000    1.700000
# 50%     76.000000   71.000000    2.910000
# 75%     86.000000   96.000000    4.630000
# max    100.000000  100.000000   16.460000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No cities in the dataframe have humidty over 100% - skipping this step.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Max Temp"]).astype(float),  alpha=.45, marker ="o", facecolor="gold", edgecolors="black", )

#format the scatter plot
plt.title(f"Latitude vs Max Temperature (F) as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)") 
print(f"The maximum temperatures can be found in cities nearer to the equator.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Temperature Plot.png")

plt.show()
# Out:
# The maximum temperatures can be found in cities nearer to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Humidity"]).astype(float),  alpha=.45, marker ="o", facecolor="limegreen", edgecolors="black", )

#format the scatter plot
plt.title(f"Latitude vs Humidity as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Humidity") 
print(f"Cities found nearer to the equator experience higher humidity.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Humidity Plot.png")

plt.show()
# Out:
# Cities found nearer to the equator experience higher humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Cloudiness"]).astype(float),  alpha=.45, marker ="o", facecolor="pink", edgecolors="purple", )

#format the scatter plot
plt.title(f"Latitude vs Cloudiness as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness") 
print(f"Cities found further away from the equator experienced higher cloudiness.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Cloudiness Plot.png")

plt.show()
# Out:
# Cities found further away from the equator experienced higher cloudiness.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#scatter plot
plt.scatter(pd.to_numeric(weather_by_city_df["Latitude"]).astype(float), pd.to_numeric(weather_by_city_df["Wind Speed"]).astype(float),  alpha=.45, marker ="o", facecolor="indigo", edgecolors="yellow", )

#format the scatter plot
plt.title(f"Latitude vs Wind Speed (mph) as at 15-Sep-2021")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)") 
print(f"Cities found further north from the equator experienced higher Wind Speeds.")

#save the scatter plot
plt.savefig("../Images/Latitude vs Wind Speed Plot.png")

plt.show()
# Out:
# Cities found further north from the equator experienced higher Wind Speeds.

# %% [markdown]
# ## Linear Regression

# %%
#creating dataframes to store Northern hemisphere cities and southern hemisphere cities

north_hem = weather_by_city_df.loc[pd.to_numeric(weather_by_city_df["Latitude"]).astype(float) > 0, :]
south_hem = weather_by_city_df.loc[pd.to_numeric(weather_by_city_df["Latitude"]).astype(float) < 0, :]

# %%
#defining the equation for regression analysis
def linear_regression(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regress_values = x_axis * slope + intercept
    regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Max Temp']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Max Temp vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value details a strong-negative correlation suggesting further north cities lie from the equater the colder it gets")

#regression plot
plt.scatter(x_axis,y_axis, color = "salmon")
plt.plot(x_axis,regress_values,"r-", color="navy")

#regression format
plt.annotate(regression,(10,270),fontsize=15,color="navy")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression y = -0.4x + 307.52
# R-squared: -0.8071694333309316, the regression details a strong correlation
# The regression and the R-value details a strong-negative correlation suggesting further north cities lie from the equater the colder it gets

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Max Temp']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Max Temp vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value details a strong-postive correlation suggesting further south cities lie from the equater the colder it gets")

#regression plot
plt.scatter(x_axis,y_axis, color = "dodgerblue")
plt.plot(x_axis,regress_values,"r-", color="dimgrey")

#regression format
plt.annotate(regression,(-30,275),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression y = 0.48x + 304.31
# R-squared: 0.7511665318671307, the regression details a strong correlation
# The regression and the R-value details a strong-postive correlation suggesting further south cities lie from the equater the colder it gets

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Humidity']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value details a weak correlation suggesting distance away from the equator doesn't have impact on humidity")

#regression plot
plt.scatter(x_axis,y_axis, color = "indigo")
plt.plot(x_axis,regress_values,"r-", color="gold")

#regression format
plt.annotate(regression,(55,10),fontsize=15,color="indigo")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression y = 0.1x + 67.32
# R-squared: 0.09349688804903626, the regression details a strong correlation
# The regression and the R-value details a weak correlation suggesting distance away from the equator doesn't have impact on humidity

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Humidity']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value shows no correlation between distance away from the equator and humidity in the Southern Hemisphere")

#regression plot
plt.scatter(x_axis,y_axis, color = "teal")
plt.plot(x_axis,regress_values,"r-", color="tomato")

#regression format
plt.annotate(regression,(-50,10),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression y = 0.0x + 65.52
# R-squared: 0.0014472771414059747, the regression details a strong correlation
# The regression and the R-value shows no correlation between distance away from the equator and humidity in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Cloudiness']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression{regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value no correlation between distance north from the equator and cloudiness")

#regression plot
plt.scatter(x_axis,y_axis, color = "tan")
plt.plot(x_axis,regress_values,"r-", color="maroon")

#regression format
plt.annotate(regression,(20,20),fontsize=15,color="navy")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regressionn as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")

plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regressiony = 0.02x + 59.57
# R-squared: 0.010715002787602231, the regression details a strong correlation
# The regression and the R-value no correlation between distance north from the equator and cloudiness

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Cloudiness']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value shows no correlation between distance away from the equator and cloudiness in the Southern Hemisphere")

#regression plot
plt.scatter(x_axis,y_axis, color = "crimson")
plt.plot(x_axis,regress_values,"r-", color="olive")

#regression format
plt.annotate(regression,(-50,10),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression y = 0.39x + 52.54
# R-squared: 0.1277493018451415, the regression details a strong correlation
# The regression and the R-value shows no correlation between distance away from the equator and cloudiness in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(north_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(north_hem['Wind Speed']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression{regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value very little correlation between distance north from the equator and wind speed (mph)")

#regression plot
plt.scatter(x_axis,y_axis, color = "indianred")
plt.plot(x_axis,regress_values,"r-", color="darkviolet")

#regression format
plt.annotate(regression,(40,12),fontsize=15,color="navy")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("../Images/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regressiony = -0.0x + 3.13
# R-squared: -0.016860737378179176, the regression details a strong correlation
# The regression and the R-value very little correlation between distance north from the equator and wind speed (mph)

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = pd.to_numeric(south_hem['Latitude']).astype(float)
y_axis = pd.to_numeric(south_hem['Wind Speed']).astype(float)


#the equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#summary
print(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression {regression}")
print(f"R-squared: {rvalue}, the regression details a strong correlation")
print("The regression and the R-value shows weak correlation between distance away from the equator and Wind Speed in the Southern Hemisphere")

#regression plot
plt.scatter(x_axis,y_axis, color = "deeppink")
plt.plot(x_axis,regress_values,"r-", color="darkcyan")

#regression format
plt.annotate(regression,(-50,10),fontsize=15,color="dimgrey")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression as at 15/09/2021")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.savefig("../Images/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression y = -0.06x + 3.11
# R-squared: -0.2585164709249585, the regression details a strong correlation
# The regression and the R-value shows weak correlation between distance away from the equator and Wind Speed in the Southern Hemisphere
