# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
from scipy import stats
from scipy.stats import linregress

from citipy import citipy
from datetime import date
import scipy.stats as st


# Import API key
from api_keys import weather_api_key
from citipy import citipy

# %%
#create a list of lattitute and longitiutde and cities
lat_range = (-90,90)
lon_range = (-180,180)

cities = []
lat_lon = []
unique_cities = []

#import cities datafile 
cities_pd = pd.read_csv("../output_data/cities.csv")
cities_pd.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ## Generate Cities List

# %%
#lat and long combination 
lat = np.random.uniform(lat_range[0], lat_range[1],size = 2000)
lon = np.random.uniform(lon_range[0], lon_range[1],size = 2000)

#map the lat and lon
lat_lon = zip(lat,lon)

#find the nearest city for a given coordinate

for coordinates in lat_lon:
    location_data = citipy.nearest_city(coordinates[0], coordinates[1])
    city = location_data.city_name
    country_name = location_data.country_code
    
    #if the location is unique add the new city into the cities list 
    if city not in unique_cities:
        unique_cities.append(city)
        cities.append({city})

print(len(cities))
# Out:
# 736

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#URL
units = "metric"
url = "http://api.openweathermap.org/data/2.5/weather?"
API_url = f"{url}appid={weather_api_key}&units={units}&q="
query_url = url + "appid=" + weather_api_key + "&q="

# %%
#create lists to store the variable data 
lat = []
lng = []
temp = []
hum = []
cld = []
wind = []
dt =[]
city_list = []
country = []

# %%
#use API to scan through the dataset and insert it into the df and print a summary
number = 0
group = 1

#limit the API search so it doesn't max out


#start API run
print ("Initiate API Data Retrieval")
print ("-------------------------------")

for place in cities:
    try:
        print (f"Processing the file {number} of Group {group} | {place}.")
            
        #place the response into variables first
        response = requests.get(query_url+place).json()
        
        city_list.append(place)
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        hum.append(response["main"]["humidity"])
        cld.append(response["clouds"]["all"])
        wind.append(response["wind"]["speed"])
        dt.append(response["dt"])
        country.append(response["sys"]["country"])

        
    except:
        (f"Weather for the city is unavaliable, checking next city: {place}.")
            
            
    number = number + 1
    if number == 50:
        number= 0
        group = group + 1   
        
print ("-------------------------------")
print ("API Retrieval is complete")
print(API_url)
print(f"city name: {city_list}")
print (f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")
# Out:
# Initiate API Data Retrieval
# -------------------------------
# Processing the file 0 of Group 1 | {'iqaluit'}.
# Processing the file 1 of Group 1 | {'busselton'}.
# Processing the file 2 of Group 1 | {'sorland'}.
# Processing the file 3 of Group 1 | {'jacareacanga'}.
# Processing the file 4 of Group 1 | {'vila velha'}.
# Processing the file 5 of Group 1 | {'qaanaaq'}.
# Processing the file 6 of Group 1 | {'bethel'}.
# Processing the file 7 of Group 1 | {'mehamn'}.
# Processing the file 8 of Group 1 | {'vimperk'}.
# Processing the file 9 of Group 1 | {'new norfolk'}.
# Processing the file 10 of Group 1 | {'worland'}.
# Processing the file 11 of Group 1 | {'rikitea'}.
# Processing the file 12 of Group 1 | {'damietta'}.
# Processing the file 13 of Group 1 | {'vaitupu'}.
# Processing the file 14 of Group 1 | {'victoria'}.
# Processing the file 15 of Group 1 | {'coahuayana'}.
# Processing the file 16 of Group 1 | {'colomiers'}.
# Processing the file 17 of Group 1 | {'albany'}.
# Processing the file 18 of Group 1 | {'cape town'}.
# Processing the file 19 of Group 1 | {'saldanha'}.
# Processing the file 20 of Group 1 | {'ushuaia'}.
# Processing the file 21 of Group 1 | {'nikolskoye'}.
# Processing the file 22 of Group 1 | {'hermanus'}.
# Processing the file 23 of Group 1 | {'pastavy'}.
# Processing the file 24 of Group 1 | {'luderitz'}.
# Processing the file 25 of Group 1 | {'lebu'}.
# Processing the file 26 of Group 1 | {'nanortalik'}.
# Processing the file 27 of Group 1 | {'mantua'}.
# Processing the file 28 of Group 1 | {'weiser'}.
# Processing the file 29 of Group 1 | {'praia'}.
# Processing the file 30 of Group 1 | {'broome'}.
# Processing the file 31 of Group 1 | {'pedernales'}.
# Processing the file 32 of Group 1 | {'illoqqortoormiut'}.
# Processing the file 33 of Group 1 | {'punta arenas'}.
# Processing the file 34 of Group 1 | {'barentsburg'}.
# Processing the file 35 of Group 1 | {'ormara'}.
# Processing the file 36 of Group 1 | {'bredasdorp'}.
# Processing the file 37 of Group 1 | {'taolanaro'}.
# Processing the file 38 of Group 1 | {'marathon'}.
# Processing the file 39 of Group 1 | {'saint-pierre'}.
# Processing the file 40 of Group 1 | {'manokwari'}.
# Processing the file 41 of Group 1 | {'mackay'}.
# Processing the file 42 of Group 1 | {'upernavik'}.
# Processing the file 43 of Group 1 | {'nome'}.
# Processing the file 44 of Group 1 | {'kodiak'}.
# Processing the file 45 of Group 1 | {'aklavik'}.
# Processing the file 46 of Group 1 | {'bengkulu'}.
# Processing the file 47 of Group 1 | {'clyde river'}.
# Processing the file 48 of Group 1 | {'tuktoyaktuk'}.
# Processing the file 49 of Group 1 | {'alice springs'}.
# Processing the file 0 of Group 2 | {'kapaa'}.
# Processing the file 1 of Group 2 | {'thompson'}.
# Processing the file 2 of Group 2 | {'taburi'}.
# Processing the file 3 of Group 2 | {'hithadhoo'}.
# Processing the file 4 of Group 2 | {'houma'}.
# Processing the file 5 of Group 2 | {'tuatapere'}.
# Processing the file 6 of Group 2 | {'khatanga'}.
# Processing the file 7 of Group 2 | {'hobart'}.
# Processing the file 8 of Group 2 | {'kargasok'}.
# Processing the file 9 of Group 2 | {'namatanai'}.
# Processing the file 10 of Group 2 | {'meulaboh'}.
# Processing the file 11 of Group 2 | {'vao'}.
# Processing the file 12 of Group 2 | {'avarua'}.
# Processing the file 13 of Group 2 | {'codrington'}.
# Processing the file 14 of Group 2 | {'bud'}.
# Processing the file 15 of Group 2 | {'jamestown'}.
# Processing the file 16 of Group 2 | {'kyzyl-suu'}.
# Processing the file 17 of Group 2 | {'batemans bay'}.
# Processing the file 18 of Group 2 | {'vaini'}.
# Processing the file 19 of Group 2 | {'dunedin'}.
# Processing the file 20 of Group 2 | {'provideniya'}.
# Processing the file 21 of Group 2 | {'dikson'}.
# Processing the file 22 of Group 2 | {'kavaratti'}.
# Processing the file 23 of Group 2 | {'amderma'}.
# Processing the file 24 of Group 2 | {'kaitangata'}.
# Processing the file 25 of Group 2 | {'trincomalee'}.
# Processing the file 26 of Group 2 | {'georgetown'}.
# Processing the file 27 of Group 2 | {'nemuro'}.
# Processing the file 28 of Group 2 | {'kalmunai'}.
# Processing the file 29 of Group 2 | {'mahebourg'}.
# Processing the file 30 of Group 2 | {'santa maria'}.
# Processing the file 31 of Group 2 | {'marzuq'}.
# Processing the file 32 of Group 2 | {'katsuura'}.
# Processing the file 33 of Group 2 | {'hukuntsi'}.
# Processing the file 34 of Group 2 | {'naze'}.
# Processing the file 35 of Group 2 | {'bridgetown'}.
# Processing the file 36 of Group 2 | {'chuy'}.
# Processing the file 37 of Group 2 | {'hakkari'}.
# Processing the file 38 of Group 2 | {'cabo san lucas'}.
# Processing the file 39 of Group 2 | {'anar darreh'}.
# Processing the file 40 of Group 2 | {'castro'}.
# Processing the file 41 of Group 2 | {'mwinilunga'}.
# Processing the file 42 of Group 2 | {'koutsouras'}.
# Processing the file 43 of Group 2 | {'isangel'}.
# Processing the file 44 of Group 2 | {'paita'}.
# Processing the file 45 of Group 2 | {'nizhneyansk'}.
# Processing the file 46 of Group 2 | {'ilulissat'}.
# Processing the file 47 of Group 2 | {'alofi'}.
# Processing the file 48 of Group 2 | {'tasiilaq'}.
# Processing the file 49 of Group 2 | {'sevierville'}.
# Processing the file 0 of Group 3 | {'tazovskiy'}.
# Processing the file 1 of Group 3 | {'villa vazquez'}.
# Processing the file 2 of Group 3 | {'narsaq'}.
# Processing the file 3 of Group 3 | {'kidal'}.
# Processing the file 4 of Group 3 | {'morant bay'}.
# Processing the file 5 of Group 3 | {'opuwo'}.
# Processing the file 6 of Group 3 | {'poggibonsi'}.
# Processing the file 7 of Group 3 | {'aksarka'}.
# Processing the file 8 of Group 3 | {'kudahuvadhoo'}.
# Processing the file 9 of Group 3 | {'pimentel'}.
# Processing the file 10 of Group 3 | {'marcona'}.
# Processing the file 11 of Group 3 | {'hofn'}.
# Processing the file 12 of Group 3 | {'port hedland'}.
# Processing the file 13 of Group 3 | {'kruisfontein'}.
# Processing the file 14 of Group 3 | {'camana'}.
# Processing the file 15 of Group 3 | {'mataura'}.
# Processing the file 16 of Group 3 | {'oskemen'}.
# Processing the file 17 of Group 3 | {'bluff'}.
# Processing the file 18 of Group 3 | {'ribeira grande'}.
# Processing the file 19 of Group 3 | {'kodinsk'}.
# Processing the file 20 of Group 3 | {'hilo'}.
# Processing the file 21 of Group 3 | {'bam'}.
# Processing the file 22 of Group 3 | {'lujiang'}.
# Processing the file 23 of Group 3 | {'kamenskoye'}.
# Processing the file 24 of Group 3 | {'faya'}.
# Processing the file 25 of Group 3 | {'hirara'}.
# Processing the file 26 of Group 3 | {'norman wells'}.
# Processing the file 27 of Group 3 | {'bella union'}.
# Processing the file 28 of Group 3 | {'ancud'}.
# Processing the file 29 of Group 3 | {'arraial do cabo'}.
# Processing the file 30 of Group 3 | {'carnarvon'}.
# Processing the file 31 of Group 3 | {'guerrero negro'}.
# Processing the file 32 of Group 3 | {'pecos'}.
# Processing the file 33 of Group 3 | {'port alfred'}.
# Processing the file 34 of Group 3 | {'havoysund'}.
# Processing the file 35 of Group 3 | {'muros'}.
# Processing the file 36 of Group 3 | {'yellowknife'}.
# Processing the file 37 of Group 3 | {'aitape'}.
# Processing the file 38 of Group 3 | {'tessalit'}.
# Processing the file 39 of Group 3 | {'misratah'}.
# Processing the file 40 of Group 3 | {'noumea'}.
# Processing the file 41 of Group 3 | {'markova'}.
# Processing the file 42 of Group 3 | {'kavieng'}.
# Processing the file 43 of Group 3 | {'alyangula'}.
# Processing the file 44 of Group 3 | {'lata'}.
# Processing the file 45 of Group 3 | {'okhotsk'}.
# Processing the file 46 of Group 3 | {'vila franca do campo'}.
# Processing the file 47 of Group 3 | {'port elizabeth'}.
# Processing the file 48 of Group 3 | {'chokurdakh'}.
# Processing the file 49 of Group 3 | {'fortuna'}.
# Processing the file 0 of Group 4 | {'airai'}.
# Processing the file 1 of Group 4 | {'cananeia'}.
# Processing the file 2 of Group 4 | {'tateyama'}.
# Processing the file 3 of Group 4 | {'viedma'}.
# Processing the file 4 of Group 4 | {'tulsipur'}.
# Processing the file 5 of Group 4 | {'puerto del rosario'}.
# Processing the file 6 of Group 4 | {'cedartown'}.
# Processing the file 7 of Group 4 | {'mys shmidta'}.
# Processing the file 8 of Group 4 | {'cidreira'}.
# Processing the file 9 of Group 4 | {'cap malheureux'}.
# Processing the file 10 of Group 4 | {'pisco'}.
# Processing the file 11 of Group 4 | {'fairbanks'}.
# Processing the file 12 of Group 4 | {'cayenne'}.
# Processing the file 13 of Group 4 | {'dongsheng'}.
# Processing the file 14 of Group 4 | {'atuona'}.
# Processing the file 15 of Group 4 | {'the valley'}.
# Processing the file 16 of Group 4 | {'porto novo'}.
# Processing the file 17 of Group 4 | {'yagodnoye'}.
# Processing the file 18 of Group 4 | {'miyazu'}.
# Processing the file 19 of Group 4 | {'ahipara'}.
# Processing the file 20 of Group 4 | {'xai-xai'}.
# Processing the file 21 of Group 4 | {'stykkisholmur'}.
# Processing the file 22 of Group 4 | {'kakamigahara'}.
# Processing the file 23 of Group 4 | {'belushya guba'}.
# Processing the file 24 of Group 4 | {'saint george'}.
# Processing the file 25 of Group 4 | {'santa lucia'}.
# Processing the file 26 of Group 4 | {'flinders'}.
# Processing the file 27 of Group 4 | {'ust-kamchatsk'}.
# Processing the file 28 of Group 4 | {'riviere-au-renard'}.
# Processing the file 29 of Group 4 | {'laguna'}.
# Processing the file 30 of Group 4 | {'suraabad'}.
# Processing the file 31 of Group 4 | {'half moon bay'}.
# Processing the file 32 of Group 4 | {'nagua'}.
# Processing the file 33 of Group 4 | {'edson'}.
# Processing the file 34 of Group 4 | {'daru'}.
# Processing the file 35 of Group 4 | {'emerald'}.
# Processing the file 36 of Group 4 | {'hobyo'}.
# Processing the file 37 of Group 4 | {'saskylakh'}.
# Processing the file 38 of Group 4 | {'cherskiy'}.
# Processing the file 39 of Group 4 | {'les cayes'}.
# Processing the file 40 of Group 4 | {'klaksvik'}.
# Processing the file 41 of Group 4 | {'butaritari'}.
# Processing the file 42 of Group 4 | {'cobija'}.
# Processing the file 43 of Group 4 | {'cotonou'}.
# Processing the file 44 of Group 4 | {'ponnani'}.
# Processing the file 45 of Group 4 | {'launceston'}.
# Processing the file 46 of Group 4 | {'bahia blanca'}.
# Processing the file 47 of Group 4 | {'coihaique'}.
# Processing the file 48 of Group 4 | {'swan river'}.
# Processing the file 49 of Group 4 | {'solok'}.
# Processing the file 0 of Group 5 | {'acapulco'}.
# Processing the file 1 of Group 5 | {'inhambane'}.
# Processing the file 2 of Group 5 | {'chapais'}.
# Processing the file 3 of Group 5 | {'richards bay'}.
# Processing the file 4 of Group 5 | {'aflu'}.
# Processing the file 5 of Group 5 | {'kondagaon'}.
# Processing the file 6 of Group 5 | {'atasu'}.
# Processing the file 7 of Group 5 | {'kjollefjord'}.
# Processing the file 8 of Group 5 | {'nouadhibou'}.
# Processing the file 9 of Group 5 | {'abbeville'}.
# Processing the file 10 of Group 5 | {'beloha'}.
# Processing the file 11 of Group 5 | {'mnogovershinnyy'}.
# Processing the file 12 of Group 5 | {'dmytrivka'}.
# Processing the file 13 of Group 5 | {'santa rosa'}.
# Processing the file 14 of Group 5 | {'barrow'}.
# Processing the file 15 of Group 5 | {'qaqortoq'}.
# Processing the file 16 of Group 5 | {'nizhniy odes'}.
# Processing the file 17 of Group 5 | {'saint-philippe'}.
# Processing the file 18 of Group 5 | {'victoria point'}.
# Processing the file 19 of Group 5 | {'anloga'}.
# Processing the file 20 of Group 5 | {'east london'}.
# Processing the file 21 of Group 5 | {'okha'}.
# Processing the file 22 of Group 5 | {'sorong'}.
# Processing the file 23 of Group 5 | {'petatlan'}.
# Processing the file 24 of Group 5 | {'mar del plata'}.
# Processing the file 25 of Group 5 | {'srednekolymsk'}.
# Processing the file 26 of Group 5 | {'nichinan'}.
# Processing the file 27 of Group 5 | {'may pen'}.
# Processing the file 28 of Group 5 | {'sao filipe'}.
# Processing the file 29 of Group 5 | {'huarmey'}.
# Processing the file 30 of Group 5 | {'elhovo'}.
# Processing the file 31 of Group 5 | {'texistepec'}.
# Processing the file 32 of Group 5 | {'thinadhoo'}.
# Processing the file 33 of Group 5 | {'tiksi'}.
# Processing the file 34 of Group 5 | {'shelton'}.
# Processing the file 35 of Group 5 | {'whitstable'}.
# Processing the file 36 of Group 5 | {'lompoc'}.
# Processing the file 37 of Group 5 | {'marsh harbour'}.
# Processing the file 38 of Group 5 | {'meridian'}.
# Processing the file 39 of Group 5 | {'attawapiskat'}.
# Processing the file 40 of Group 5 | {'longyearbyen'}.
# Processing the file 41 of Group 5 | {'bolitoc'}.
# Processing the file 42 of Group 5 | {'alotau'}.
# Processing the file 43 of Group 5 | {'xochistlahuaca'}.
# Processing the file 44 of Group 5 | {'camacha'}.
# Processing the file 45 of Group 5 | {'liberia'}.
# Processing the file 46 of Group 5 | {'tura'}.
# Processing the file 47 of Group 5 | {'khani'}.
# Processing the file 48 of Group 5 | {'zyryanka'}.
# Processing the file 49 of Group 5 | {'hasaki'}.
# Processing the file 0 of Group 6 | {'nokaneng'}.
# Processing the file 1 of Group 6 | {'xinyu'}.
# Processing the file 2 of Group 6 | {'usinsk'}.
# Processing the file 3 of Group 6 | {'prachuap khiri khan'}.
# Processing the file 4 of Group 6 | {'puerto ayora'}.
# Processing the file 5 of Group 6 | {'bendigo'}.
# Processing the file 6 of Group 6 | {'anadyr'}.
# Processing the file 7 of Group 6 | {'tubruq'}.
# Processing the file 8 of Group 6 | {'avera'}.
# Processing the file 9 of Group 6 | {'esperance'}.
# Processing the file 10 of Group 6 | {'agadez'}.
# Processing the file 11 of Group 6 | {'severo-kurilsk'}.
# Processing the file 12 of Group 6 | {'grand river south east'}.
# Processing the file 13 of Group 6 | {'buala'}.
# Processing the file 14 of Group 6 | {'saleaula'}.
# Processing the file 15 of Group 6 | {'karauzyak'}.
# Processing the file 16 of Group 6 | {'jalu'}.
# Processing the file 17 of Group 6 | {'mayo'}.
# Processing the file 18 of Group 6 | {'yar-sale'}.
# Processing the file 19 of Group 6 | {'touros'}.
# Processing the file 20 of Group 6 | {'serra'}.
# Processing the file 21 of Group 6 | {'san cristobal'}.
# Processing the file 22 of Group 6 | {'tsihombe'}.
# Processing the file 23 of Group 6 | {'boyolangu'}.
# Processing the file 24 of Group 6 | {'peniche'}.
# Processing the file 25 of Group 6 | {'pevek'}.
# Processing the file 26 of Group 6 | {'council bluffs'}.
# Processing the file 27 of Group 6 | {'louisbourg'}.
# Processing the file 28 of Group 6 | {'souillac'}.
# Processing the file 29 of Group 6 | {'skegness'}.
# Processing the file 30 of Group 6 | {'le port'}.
# Processing the file 31 of Group 6 | {'leningradskiy'}.
# Processing the file 32 of Group 6 | {'port lincoln'}.
# Processing the file 33 of Group 6 | {'enshi'}.
# Processing the file 34 of Group 6 | {'pizarro'}.
# Processing the file 35 of Group 6 | {'mandera'}.
# Processing the file 36 of Group 6 | {'mullaitivu'}.
# Processing the file 37 of Group 6 | {'banswada'}.
# Processing the file 38 of Group 6 | {'tabou'}.
# Processing the file 39 of Group 6 | {'naron'}.
# Processing the file 40 of Group 6 | {'arman'}.
# Processing the file 41 of Group 6 | {'kushima'}.
# Processing the file 42 of Group 6 | {'pringsewu'}.
# Processing the file 43 of Group 6 | {'cascais'}.
# Processing the file 44 of Group 6 | {'longlac'}.
# Processing the file 45 of Group 6 | {'ambilobe'}.
# Processing the file 46 of Group 6 | {'iquitos'}.
# Processing the file 47 of Group 6 | {'miraflores'}.
# Processing the file 48 of Group 6 | {'mbutuy'}.
# Processing the file 49 of Group 6 | {'maridi'}.
# Processing the file 0 of Group 7 | {'gat'}.
# Processing the file 1 of Group 7 | {'craig'}.
# Processing the file 2 of Group 7 | {'tungkang'}.
# Processing the file 3 of Group 7 | {'korla'}.
# Processing the file 4 of Group 7 | {'lucea'}.
# Processing the file 5 of Group 7 | {'namibe'}.
# Processing the file 6 of Group 7 | {'bafoulabe'}.
# Processing the file 7 of Group 7 | {'ahuimanu'}.
# Processing the file 8 of Group 7 | {'ibra'}.
# Processing the file 9 of Group 7 | {'aksu'}.
# Processing the file 10 of Group 7 | {'dudhani'}.
# Processing the file 11 of Group 7 | {'safwah'}.
# Processing the file 12 of Group 7 | {'ierapetra'}.
# Processing the file 13 of Group 7 | {'eureka'}.
# Processing the file 14 of Group 7 | {'kysyl-syr'}.
# Processing the file 15 of Group 7 | {'ingham'}.
# Processing the file 16 of Group 7 | {'sens'}.
# Processing the file 17 of Group 7 | {'kaukauna'}.
# Processing the file 18 of Group 7 | {'nurobod'}.
# Processing the file 19 of Group 7 | {'satitoa'}.
# Processing the file 20 of Group 7 | {'torbay'}.
# Processing the file 21 of Group 7 | {'agadir'}.
# Processing the file 22 of Group 7 | {'namtsy'}.
# Processing the file 23 of Group 7 | {'shestakovo'}.
# Processing the file 24 of Group 7 | {'umm durman'}.
# Processing the file 25 of Group 7 | {'mecca'}.
# Processing the file 26 of Group 7 | {'bambous virieux'}.
# Processing the file 27 of Group 7 | {'imeni poliny osipenko'}.
# Processing the file 28 of Group 7 | {'acatlan'}.
# Processing the file 29 of Group 7 | {'duz'}.
# Processing the file 30 of Group 7 | {'kismayo'}.
# Processing the file 31 of Group 7 | {'saint-francois'}.
# Processing the file 32 of Group 7 | {'ust-kulom'}.
# Processing the file 33 of Group 7 | {'biak'}.
# Processing the file 34 of Group 7 | {'asau'}.
# Processing the file 35 of Group 7 | {'beringovskiy'}.
# Processing the file 36 of Group 7 | {'ambovombe'}.
# Processing the file 37 of Group 7 | {'butembo'}.
# Processing the file 38 of Group 7 | {'atar'}.
# Processing the file 39 of Group 7 | {'tabasco'}.
# Processing the file 40 of Group 7 | {'altoona'}.
# Processing the file 41 of Group 7 | {'henties bay'}.
# Processing the file 42 of Group 7 | {'vilhena'}.
# Processing the file 43 of Group 7 | {'toamasina'}.
# Processing the file 44 of Group 7 | {'zhigansk'}.
# Processing the file 45 of Group 7 | {'chapada dos guimaraes'}.
# Processing the file 46 of Group 7 | {'carmen'}.
# Processing the file 47 of Group 7 | {'saint-louis'}.
# Processing the file 48 of Group 7 | {'bathsheba'}.
# Processing the file 49 of Group 7 | {'ylivieska'}.
# Processing the file 0 of Group 8 | {'dingle'}.
# Processing the file 1 of Group 8 | {'lodeynoye pole'}.
# Processing the file 2 of Group 8 | {'kumi'}.
# Processing the file 3 of Group 8 | {'lagoa'}.
# Processing the file 4 of Group 8 | {'devin'}.
# Processing the file 5 of Group 8 | {'port-gentil'}.
# Processing the file 6 of Group 8 | {'vardo'}.
# Processing the file 7 of Group 8 | {'mwene-ditu'}.
# Processing the file 8 of Group 8 | {'kaseda'}.
# Processing the file 9 of Group 8 | {'palabuhanratu'}.
# Processing the file 10 of Group 8 | {'samusu'}.
# Processing the file 11 of Group 8 | {'vanimo'}.
# Processing the file 12 of Group 8 | {'navrongo'}.
# Processing the file 13 of Group 8 | {'jieshi'}.
# Processing the file 14 of Group 8 | {'rio branco'}.
# Processing the file 15 of Group 8 | {'tucurui'}.
# Processing the file 16 of Group 8 | {'coquimbo'}.
# Processing the file 17 of Group 8 | {'harnosand'}.
# Processing the file 18 of Group 8 | {'batagay'}.
# Processing the file 19 of Group 8 | {'la paz'}.
# Processing the file 20 of Group 8 | {'moctezuma'}.
# Processing the file 21 of Group 8 | {'vostok'}.
# Processing the file 22 of Group 8 | {'bac lieu'}.
# Processing the file 23 of Group 8 | {'lasa'}.
# Processing the file 24 of Group 8 | {'clyde'}.
# Processing the file 25 of Group 8 | {'kusye-aleksandrovskiy'}.
# Processing the file 26 of Group 8 | {'sentyabrskiy'}.
# Processing the file 27 of Group 8 | {'butterworth'}.
# Processing the file 28 of Group 8 | {'basco'}.
# Processing the file 29 of Group 8 | {'yulara'}.
# Processing the file 30 of Group 8 | {'shubarkuduk'}.
# Processing the file 31 of Group 8 | {'ponta do sol'}.
# Processing the file 32 of Group 8 | {'yei'}.
# Processing the file 33 of Group 8 | {'birao'}.
# Processing the file 34 of Group 8 | {'anito'}.
# Processing the file 35 of Group 8 | {'newport'}.
# Processing the file 36 of Group 8 | {'umm kaddadah'}.
# Processing the file 37 of Group 8 | {'malynivka'}.
# Processing the file 38 of Group 8 | {'dzhusaly'}.
# Processing the file 39 of Group 8 | {'adrar'}.
# Processing the file 40 of Group 8 | {'rocha'}.
# Processing the file 41 of Group 8 | {'fonte boa'}.
# Processing the file 42 of Group 8 | {'toora-khem'}.
# Processing the file 43 of Group 8 | {'bintulu'}.
# Processing the file 44 of Group 8 | {'sitka'}.
# Processing the file 45 of Group 8 | {'artyk'}.
# Processing the file 46 of Group 8 | {'tumannyy'}.
# Processing the file 47 of Group 8 | {'baykit'}.
# Processing the file 48 of Group 8 | {'kurilsk'}.
# Processing the file 49 of Group 8 | {'broken hill'}.
# Processing the file 0 of Group 9 | {'san patricio'}.
# Processing the file 1 of Group 9 | {'praia da vitoria'}.
# Processing the file 2 of Group 9 | {'sinkat'}.
# Processing the file 3 of Group 9 | {'almaznyy'}.
# Processing the file 4 of Group 9 | {'araouane'}.
# Processing the file 5 of Group 9 | {'manta'}.
# Processing the file 6 of Group 9 | {'registro'}.
# Processing the file 7 of Group 9 | {'ishigaki'}.
# Processing the file 8 of Group 9 | {'neiafu'}.
# Processing the file 9 of Group 9 | {'batagay-alyta'}.
# Processing the file 10 of Group 9 | {'colares'}.
# Processing the file 11 of Group 9 | {'diapaga'}.
# Processing the file 12 of Group 9 | {'vanavara'}.
# Processing the file 13 of Group 9 | {'chimore'}.
# Processing the file 14 of Group 9 | {'hawalli'}.
# Processing the file 15 of Group 9 | {'lahat'}.
# Processing the file 16 of Group 9 | {'andreapol'}.
# Processing the file 17 of Group 9 | {'seoul'}.
# Processing the file 18 of Group 9 | {'nova venecia'}.
# Processing the file 19 of Group 9 | {'ostrovnoy'}.
# Processing the file 20 of Group 9 | {'arua'}.
# Processing the file 21 of Group 9 | {'chapleau'}.
# Processing the file 22 of Group 9 | {'lorengau'}.
# Processing the file 23 of Group 9 | {'tautira'}.
# Processing the file 24 of Group 9 | {'whitecourt'}.
# Processing the file 25 of Group 9 | {'kununurra'}.
# Processing the file 26 of Group 9 | {'lhuntshi'}.
# Processing the file 27 of Group 9 | {'nouakchott'}.
# Processing the file 28 of Group 9 | {'nizhneudinsk'}.
# Processing the file 29 of Group 9 | {'geraldton'}.
# Processing the file 30 of Group 9 | {'hami'}.
# Processing the file 31 of Group 9 | {'kahului'}.
# Processing the file 32 of Group 9 | {'revelstoke'}.
# Processing the file 33 of Group 9 | {'omboue'}.
# Processing the file 34 of Group 9 | {'ugoofaaru'}.
# Processing the file 35 of Group 9 | {'mayumba'}.
# Processing the file 36 of Group 9 | {'oistins'}.
# Processing the file 37 of Group 9 | {'gorgan'}.
# Processing the file 38 of Group 9 | {'ibirapitanga'}.
# Processing the file 39 of Group 9 | {'elizabeth city'}.
# Processing the file 40 of Group 9 | {'tommot'}.
# Processing the file 41 of Group 9 | {'sinjar'}.
# Processing the file 42 of Group 9 | {'sisimiut'}.
# Processing the file 43 of Group 9 | {'majene'}.
# Processing the file 44 of Group 9 | {'onega'}.
# Processing the file 45 of Group 9 | {'constitucion'}.
# Processing the file 46 of Group 9 | {'coyah'}.
# Processing the file 47 of Group 9 | {'isla mujeres'}.
# Processing the file 48 of Group 9 | {'tabuk'}.
# Processing the file 49 of Group 9 | {'pokrovsk-uralskiy'}.
# Processing the file 0 of Group 10 | {'rio grande'}.
# Processing the file 1 of Group 10 | {'lubango'}.
# Processing the file 2 of Group 10 | {'santa barbara'}.
# Processing the file 3 of Group 10 | {'mehran'}.
# Processing the file 4 of Group 10 | {'alvorada'}.
# Processing the file 5 of Group 10 | {'qujing'}.
# Processing the file 6 of Group 10 | {'quixada'}.
# Processing the file 7 of Group 10 | {'aranos'}.
# Processing the file 8 of Group 10 | {'vigrestad'}.
# Processing the file 9 of Group 10 | {'atka'}.
# Processing the file 10 of Group 10 | {'kachikau'}.
# Processing the file 11 of Group 10 | {'swellendam'}.
# Processing the file 12 of Group 10 | {'carbonia'}.
# Processing the file 13 of Group 10 | {'monrovia'}.
# Processing the file 14 of Group 10 | {'champerico'}.
# Processing the file 15 of Group 10 | {'sao jose da coroa grande'}.
# Processing the file 16 of Group 10 | {'vitimskiy'}.
# Processing the file 17 of Group 10 | {'san borja'}.
# Processing the file 18 of Group 10 | {'port shepstone'}.
# Processing the file 19 of Group 10 | {'krasnoarmeysk'}.
# Processing the file 20 of Group 10 | {'tezu'}.
# Processing the file 21 of Group 10 | {'makat'}.
# Processing the file 22 of Group 10 | {'barcarena'}.
# Processing the file 23 of Group 10 | {'manavalakurichi'}.
# Processing the file 24 of Group 10 | {'karlskrona'}.
# Processing the file 25 of Group 10 | {'chara'}.
# Processing the file 26 of Group 10 | {'thilogne'}.
# Processing the file 27 of Group 10 | {'faanui'}.
# Processing the file 28 of Group 10 | {'san quintin'}.
# Processing the file 29 of Group 10 | {'banjar'}.
# Processing the file 30 of Group 10 | {'hailar'}.
# Processing the file 31 of Group 10 | {'margate'}.
# Processing the file 32 of Group 10 | {'channel-port aux basques'}.
# Processing the file 33 of Group 10 | {'madgaon'}.
# Processing the file 34 of Group 10 | {'labuhan'}.
# Processing the file 35 of Group 10 | {'kloulklubed'}.
# Processing the file 36 of Group 10 | {'angoche'}.
# Processing the file 37 of Group 10 | {'qasigiannguit'}.
# Processing the file 38 of Group 10 | {'kutum'}.
# Processing the file 39 of Group 10 | {'robertson'}.
# Processing the file 40 of Group 10 | {'diamantino'}.
# Processing the file 41 of Group 10 | {'malanje'}.
# Processing the file 42 of Group 10 | {'gotsu'}.
# Processing the file 43 of Group 10 | {'esso'}.
# Processing the file 44 of Group 10 | {'honningsvag'}.
# Processing the file 45 of Group 10 | {'comodoro rivadavia'}.
# Processing the file 46 of Group 10 | {'kakching'}.
# Processing the file 47 of Group 10 | {'russell'}.
# Processing the file 48 of Group 10 | {'banepa'}.
# Processing the file 49 of Group 10 | {'dolores'}.
# Processing the file 0 of Group 11 | {'la ronge'}.
# Processing the file 1 of Group 11 | {'mogadishu'}.
# Processing the file 2 of Group 11 | {'phan rang'}.
# Processing the file 3 of Group 11 | {'prince rupert'}.
# Processing the file 4 of Group 11 | {'lypova dolyna'}.
# Processing the file 5 of Group 11 | {'sur'}.
# Processing the file 6 of Group 11 | {'acajutla'}.
# Processing the file 7 of Group 11 | {'yaan'}.
# Processing the file 8 of Group 11 | {'tucuma'}.
# Processing the file 9 of Group 11 | {'angra'}.
# Processing the file 10 of Group 11 | {'indramayu'}.
# Processing the file 11 of Group 11 | {'hambantota'}.
# Processing the file 12 of Group 11 | {'ambon'}.
# Processing the file 13 of Group 11 | {'micheweni'}.
# Processing the file 14 of Group 11 | {'halalo'}.
# Processing the file 15 of Group 11 | {'ust-maya'}.
# Processing the file 16 of Group 11 | {'methoni'}.
# Processing the file 17 of Group 11 | {'doctor pedro p. pena'}.
# Processing the file 18 of Group 11 | {'vestmannaeyjar'}.
# Processing the file 19 of Group 11 | {'pokrovsk'}.
# Processing the file 20 of Group 11 | {'novyy urengoy'}.
# Processing the file 21 of Group 11 | {'wrexham'}.
# Processing the file 22 of Group 11 | {'vestmanna'}.
# Processing the file 23 of Group 11 | {'ulaangom'}.
# Processing the file 24 of Group 11 | {'solnechnyy'}.
# Processing the file 25 of Group 11 | {'othonoi'}.
# Processing the file 26 of Group 11 | {'tibati'}.
# Processing the file 27 of Group 11 | {'cajazeiras'}.
# Processing the file 28 of Group 11 | {'saint-georges'}.
# Processing the file 29 of Group 11 | {'stokmarknes'}.
# Processing the file 30 of Group 11 | {'flin flon'}.
# Processing the file 31 of Group 11 | {'sarkand'}.
# Processing the file 32 of Group 11 | {'valparaiso'}.
# Processing the file 33 of Group 11 | {'brejo da madre de deus'}.
# Processing the file 34 of Group 11 | {'port macquarie'}.
# Processing the file 35 of Group 11 | {'bethanien'}.
# Processing the file 36 of Group 11 | {'avila'}.
# Processing the file 37 of Group 11 | {'nyurba'}.
# Processing the file 38 of Group 11 | {'lagunas'}.
# Processing the file 39 of Group 11 | {'port hardy'}.
# Processing the file 40 of Group 11 | {'kondoa'}.
# Processing the file 41 of Group 11 | {'harper'}.
# Processing the file 42 of Group 11 | {'balclutha'}.
# Processing the file 43 of Group 11 | {'itoman'}.
# Processing the file 44 of Group 11 | {'seydi'}.
# Processing the file 45 of Group 11 | {'inderborskiy'}.
# Processing the file 46 of Group 11 | {'darovskoy'}.
# Processing the file 47 of Group 11 | {'astoria'}.
# Processing the file 48 of Group 11 | {'itarema'}.
# Processing the file 49 of Group 11 | {'tochigi'}.
# Processing the file 0 of Group 12 | {'beyneu'}.
# Processing the file 1 of Group 12 | {'lashio'}.
# Processing the file 2 of Group 12 | {'jati'}.
# Processing the file 3 of Group 12 | {'novikovo'}.
# Processing the file 4 of Group 12 | {'yanji'}.
# Processing the file 5 of Group 12 | {'longkou'}.
# Processing the file 6 of Group 12 | {'cap-aux-meules'}.
# Processing the file 7 of Group 12 | {'carora'}.
# Processing the file 8 of Group 12 | {'rurrenabaque'}.
# Processing the file 9 of Group 12 | {'petropavlovsk-kamchatskiy'}.
# Processing the file 10 of Group 12 | {'anshun'}.
# Processing the file 11 of Group 12 | {'hastings'}.
# Processing the file 12 of Group 12 | {'manati'}.
# Processing the file 13 of Group 12 | {'fort dodge'}.
# Processing the file 14 of Group 12 | {'mae hong son'}.
# Processing the file 15 of Group 12 | {'amuntai'}.
# Processing the file 16 of Group 12 | {'cartagena del chaira'}.
# Processing the file 17 of Group 12 | {'frutal'}.
# Processing the file 18 of Group 12 | {'portland'}.
# Processing the file 19 of Group 12 | {'zorritos'}.
# Processing the file 20 of Group 12 | {'puerto maldonado'}.
# Processing the file 21 of Group 12 | {'husavik'}.
# Processing the file 22 of Group 12 | {'aykhal'}.
# Processing the file 23 of Group 12 | {'karaul'}.
# Processing the file 24 of Group 12 | {'paradwip'}.
# Processing the file 25 of Group 12 | {'darnah'}.
# Processing the file 26 of Group 12 | {'lichtenstein'}.
# Processing the file 27 of Group 12 | {'mitsamiouli'}.
# Processing the file 28 of Group 12 | {'ayan'}.
# Processing the file 29 of Group 12 | {'catuday'}.
# Processing the file 30 of Group 12 | {'belmonte'}.
# Processing the file 31 of Group 12 | {'abu samrah'}.
# Processing the file 32 of Group 12 | {'havre-saint-pierre'}.
# Processing the file 33 of Group 12 | {'noyabrsk'}.
# Processing the file 34 of Group 12 | {'chicama'}.
# Processing the file 35 of Group 12 | {'umzimvubu'}.
# Processing the file 36 of Group 12 | {'chimbarongo'}.
# Processing the file 37 of Group 12 | {'hurricane'}.
# Processing the file 38 of Group 12 | {'hualmay'}.
# Processing the file 39 of Group 12 | {'bonavista'}.
# Processing the file 40 of Group 12 | {'dukat'}.
# Processing the file 41 of Group 12 | {'meyungs'}.
# Processing the file 42 of Group 12 | {'port hawkesbury'}.
# Processing the file 43 of Group 12 | {'vila'}.
# Processing the file 44 of Group 12 | {'tekeli'}.
# Processing the file 45 of Group 12 | {'raudeberg'}.
# Processing the file 46 of Group 12 | {'surkhakhi'}.
# Processing the file 47 of Group 12 | {'oktyabrskoye'}.
# Processing the file 48 of Group 12 | {'atsiki'}.
# Processing the file 49 of Group 12 | {'mount isa'}.
# Processing the file 0 of Group 13 | {'olafsvik'}.
# Processing the file 1 of Group 13 | {'quatre cocos'}.
# Processing the file 2 of Group 13 | {'auchi'}.
# Processing the file 3 of Group 13 | {'kadykchan'}.
# Processing the file 4 of Group 13 | {'gornopravdinsk'}.
# Processing the file 5 of Group 13 | {'samarai'}.
# Processing the file 6 of Group 13 | {'brae'}.
# Processing the file 7 of Group 13 | {'axim'}.
# Processing the file 8 of Group 13 | {'surop'}.
# Processing the file 9 of Group 13 | {'bicazu ardelean'}.
# Processing the file 10 of Group 13 | {'alenquer'}.
# Processing the file 11 of Group 13 | {'much'}.
# Processing the file 12 of Group 13 | {'guarda'}.
# Processing the file 13 of Group 13 | {'addi ugri'}.
# Processing the file 14 of Group 13 | {'nago'}.
# Processing the file 15 of Group 13 | {'bandraboua'}.
# Processing the file 16 of Group 13 | {'longonjo'}.
# Processing the file 17 of Group 13 | {'comlosu mare'}.
# Processing the file 18 of Group 13 | {'shanghai'}.
# Processing the file 19 of Group 13 | {'guiratinga'}.
# Processing the file 20 of Group 13 | {'hue'}.
# Processing the file 21 of Group 13 | {'urumqi'}.
# Processing the file 22 of Group 13 | {'aimores'}.
# Processing the file 23 of Group 13 | {'rafaela'}.
# Processing the file 24 of Group 13 | {'porto empedocle'}.
# Processing the file 25 of Group 13 | {'nuuk'}.
# Processing the file 26 of Group 13 | {'paamiut'}.
# Processing the file 27 of Group 13 | {'gurupa'}.
# Processing the file 28 of Group 13 | {'elko'}.
# Processing the file 29 of Group 13 | {'soyo'}.
# Processing the file 30 of Group 13 | {'nauta'}.
# Processing the file 31 of Group 13 | {'kangaatsiaq'}.
# Processing the file 32 of Group 13 | {'pemba'}.
# Processing the file 33 of Group 13 | {'hamilton'}.
# Processing the file 34 of Group 13 | {'cabras'}.
# Processing the file 35 of Group 13 | {'waipawa'}.
# Processing the file 36 of Group 13 | {'fuyu'}.
# Processing the file 37 of Group 13 | {'we'}.
# Processing the file 38 of Group 13 | {'general roca'}.
# Processing the file 39 of Group 13 | {'atambua'}.
# Processing the file 40 of Group 13 | {'kizhinga'}.
# Processing the file 41 of Group 13 | {'bubaque'}.
# Processing the file 42 of Group 13 | {'beregovoy'}.
# Processing the file 43 of Group 13 | {'mme'}.
# Processing the file 44 of Group 13 | {'anchorage'}.
# Processing the file 45 of Group 13 | {'waxahachie'}.
# Processing the file 46 of Group 13 | {'dzaoudzi'}.
# Processing the file 47 of Group 13 | {'oktyabrskiy'}.
# Processing the file 48 of Group 13 | {'maryville'}.
# Processing the file 49 of Group 13 | {'andilamena'}.
# Processing the file 0 of Group 14 | {'tigil'}.
# Processing the file 1 of Group 14 | {'ossora'}.
# Processing the file 2 of Group 14 | {'cocorit'}.
# Processing the file 3 of Group 14 | {'raga'}.
# Processing the file 4 of Group 14 | {'bocana'}.
# Processing the file 5 of Group 14 | {'dujuma'}.
# Processing the file 6 of Group 14 | {'la libertad'}.
# Processing the file 7 of Group 14 | {'najran'}.
# Processing the file 8 of Group 14 | {'marathopolis'}.
# Processing the file 9 of Group 14 | {'toma'}.
# Processing the file 10 of Group 14 | {'prieska'}.
# Processing the file 11 of Group 14 | {'komsomolskiy'}.
# Processing the file 12 of Group 14 | {'alacranes'}.
# Processing the file 13 of Group 14 | {'yarada'}.
# Processing the file 14 of Group 14 | {'victor harbor'}.
# Processing the file 15 of Group 14 | {'acarau'}.
# Processing the file 16 of Group 14 | {'lavrentiya'}.
# Processing the file 17 of Group 14 | {'grindavik'}.
# Processing the file 18 of Group 14 | {'ust-nera'}.
# Processing the file 19 of Group 14 | {'poptun'}.
# Processing the file 20 of Group 14 | {'sungairaya'}.
# Processing the file 21 of Group 14 | {'ashqelon'}.
# Processing the file 22 of Group 14 | {'porto murtinho'}.
# Processing the file 23 of Group 14 | {'crab hill'}.
# Processing the file 24 of Group 14 | {'bacolod'}.
# Processing the file 25 of Group 14 | {'almonte'}.
# Processing the file 26 of Group 14 | {'kaitong'}.
# Processing the file 27 of Group 14 | {'mayor pablo lagerenza'}.
# Processing the file 28 of Group 14 | {'kailua'}.
# Processing the file 29 of Group 14 | {'neyvo-shaytanskiy'}.
# Processing the file 30 of Group 14 | {'tucuman'}.
# Processing the file 31 of Group 14 | {'pasni'}.
# Processing the file 32 of Group 14 | {'juneau'}.
# Processing the file 33 of Group 14 | {'los llanos de aridane'}.
# Processing the file 34 of Group 14 | {'halapitan'}.
# Processing the file 35 of Group 14 | {'sawang daen din'}.
# Processing the file 36 of Group 14 | {'turayf'}.
# Processing the file 37 of Group 14 | {'gayny'}.
# Processing the file 38 of Group 14 | {'killarney'}.
# Processing the file 39 of Group 14 | {'sosnovo-ozerskoye'}.
# Processing the file 40 of Group 14 | {'worcester'}.
# Processing the file 41 of Group 14 | {'sept-iles'}.
# Processing the file 42 of Group 14 | {'hartselle'}.
# Processing the file 43 of Group 14 | {'north bend'}.
# Processing the file 44 of Group 14 | {'marawi'}.
# Processing the file 45 of Group 14 | {'da nang'}.
# Processing the file 46 of Group 14 | {'fort-shevchenko'}.
# Processing the file 47 of Group 14 | {'staryy nadym'}.
# Processing the file 48 of Group 14 | {'kerouane'}.
# Processing the file 49 of Group 14 | {'asfi'}.
# Processing the file 0 of Group 15 | {'bur gabo'}.
# Processing the file 1 of Group 15 | {'ouadda'}.
# Processing the file 2 of Group 15 | {'challapata'}.
# Processing the file 3 of Group 15 | {'nicoya'}.
# Processing the file 4 of Group 15 | {'bilibino'}.
# Processing the file 5 of Group 15 | {'vicente guerrero'}.
# Processing the file 6 of Group 15 | {'poya'}.
# Processing the file 7 of Group 15 | {'wote'}.
# Processing the file 8 of Group 15 | {'puro'}.
# Processing the file 9 of Group 15 | {'bowen'}.
# Processing the file 10 of Group 15 | {'khandyga'}.
# Processing the file 11 of Group 15 | {'nalut'}.
# Processing the file 12 of Group 15 | {'makakilo city'}.
# Processing the file 13 of Group 15 | {'saeby'}.
# Processing the file 14 of Group 15 | {'sola'}.
# Processing the file 15 of Group 15 | {'sturgis'}.
# Processing the file 16 of Group 15 | {'qandala'}.
# Processing the file 17 of Group 15 | {'limbang'}.
# Processing the file 18 of Group 15 | {'teya'}.
# Processing the file 19 of Group 15 | {'urubicha'}.
# Processing the file 20 of Group 15 | {'college'}.
# Processing the file 21 of Group 15 | {'yumen'}.
# Processing the file 22 of Group 15 | {'guanhaes'}.
# Processing the file 23 of Group 15 | {'fairmont'}.
# Processing the file 24 of Group 15 | {'nova aurora'}.
# Processing the file 25 of Group 15 | {'berlevag'}.
# Processing the file 26 of Group 15 | {'madimba'}.
# Processing the file 27 of Group 15 | {'kupang'}.
# Processing the file 28 of Group 15 | {'calobre'}.
# Processing the file 29 of Group 15 | {'punta de piedra'}.
# Processing the file 30 of Group 15 | {'gondar'}.
# Processing the file 31 of Group 15 | {'phangnga'}.
# Processing the file 32 of Group 15 | {'balabac'}.
# Processing the file 33 of Group 15 | {'buinsk'}.
# Processing the file 34 of Group 15 | {'cabedelo'}.
# Processing the file 35 of Group 15 | {'navirai'}.
# -------------------------------
# API Retrieval is complete
# http://api.openweathermap.org/data/2.5/weather?appid=f4243e09885630e9dced03c5ef1f7560&units=metric&q=
# city name: []
# The latitude information received is: []
# The temperature information received is: []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print (len(cld))
# Out:
# 0

# %%
weather_by_city_dict = {"City": place, "Country": country, "Latitude": lat, "Longtitude": lng, "Max Temp": temp, "Humidity": hum, "Cloudiness": cld, "Wind Speed": wind, "Date":dt}

weather_by_city_df = pd.DataFrame.from_dict(weather_by_city_dict, orient = "index")

weather_by_city_df = weather_by_city_df.transpose()
weather_by_city_df
# Out:
#        City Country Latitude Longtitude Max Temp Humidity Cloudiness  \
# 0  coquimbo    None     None       None     None     None       None
#
#   Wind Speed  Date
# 0       None  None

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float),  alpha=.5, facecolor="red", edgecolors="black", marker ="o")
plt.title(f"Latitude vs Max Temperature in F")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)") 
print(f"The max temperatures are highest near the equator.")
plt.show()

# %%
# Save figure to Images folder dont run this right now ##########
plt.savefig("Images/Latitude vs Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(pd.to_numeric(city_weather["Latitude"]).astype(float), pd.to_numeric(city_weather["Humidity (%)"]).astype(float), facecolors="skyblue", edgecolors="purple", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"Latitude vs Humidity as at 14/09/2021")
plt.show()

# %%
plt.savefig("Images/Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.savefig("Images/latitude_cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.savefig("Images/latitude vs wind speed.png")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
